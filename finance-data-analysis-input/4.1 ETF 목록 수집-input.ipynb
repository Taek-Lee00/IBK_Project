# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/corazzon/finance-data-analysis/blob/main/4.1%20ETF%20%EB%AA%A9%EB%A1%9D%20%EC%88%98%EC%A7%91-input.ipynb)
#
#
# ## ETF란?
# * ETF(상장지수펀드)는 기초지수의 성과를 추적하는 것이 목표인 인덱스펀드로, 거래소에 상장되어 있어서 개별주식과 마찬가지로 기존의 주식계좌를 통해 거래를 할 수 있습니다. 그 구성종목과 수량 등 자산구성내역(PDF)이 투명하게 공개되어 있고, 장중에는 실시간으로 순자산가치(NAV)가 제공되어 거래에 참고하실 수 있습니다. ETF는 1좌를 거래할 수 있는 최소한의 금액만으로 분산투자 효과를 누릴 수 있어 효율적인 투자수단이며, 펀드보다 운용보수가 낮고 주식에 적용되는 거래세도 붙지 않습니다.
#     * 출처 : [ETF : 네이버 금융](https://finance.naver.com/sise/etf.nhn)
#
#
# ## 크롬 브라우저의 네트워크 정보를 통한 데이터 수집
# * json 데이터 수집과 파일저장 방법
#
# * [ETF : 네이버 금융](https://finance.naver.com/sise/etf.nhn)

# %%
# 라이브러리를 불러옵니다.
# 데이터 분석을 위한 pandas, 수치계산을 위한 numpy, http 요청을 위한 requests를 받아옵니다.
import pandas as pd
import numpy as np
import requests

# %%
# 수집할 url을 가져옵니다.
url = "https://finance.naver.com/api/sise/etfItemList.nhn?etfType=0&targetColumn=market_sum&sortOrder=desc"

# %% [markdown]
# ## Pandas를 통한 요청

# %%
pd.read_html(url)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-5d8f83db45ac> in <module>()
# ----> 1 pd.read_html(url)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1111         na_values=na_values,
#    1112         keep_default_na=keep_default_na,
# -> 1113         displayed_only=displayed_only,
#    1114     )
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     924     else:
#     925         assert retained is not None  # for mypy
# --> 926         raise retained
#     927
#     928     ret = []
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     904
#     905         try:
# --> 906             tables = p.parse_tables()
#     907         except ValueError as caught:
#     908             # if `io` is an io-like object, check if it's seekable
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/html.py in parse_tables(self)
#     220         list of parsed (header, body, footer) tuples from tables.
#     221         """
# --> 222         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     223         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     224
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/html.py in _parse_tables(self, doc, match, attrs)
#     550
#     551         if not tables:
# --> 552             raise ValueError("No tables found")
#     553
#     554         result = []
#
# ValueError: No tables found

# %% [markdown]
# ## JSON
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c9/JSON_vector_logo.svg/300px-JSON_vector_logo.svg.png" width="100">
#
# JSON(제이슨, JavaScript Object Notation)은 속성-값 쌍( attribute–value pairs and array data types (or any other serializable value)) 또는 "키-값 쌍"으로 이루어진 데이터 오브젝트를 전달하기 위해 인간이 읽을 수 있는 텍스트를 사용하는 개방형 표준 포맷이다. 비동기 브라우저/서버 통신 (AJAX)을 위해, 넓게는 XML(AJAX가 사용)을 대체하는 주요 데이터 포맷이다. 특히, 인터넷에서 자료를 주고 받을 때 그 자료를 표현하는 방법으로 알려져 있다. 자료의 종류에 큰 제한은 없으며, 특히 컴퓨터 프로그램의 변수값을 표현하는 데 적합하다.
# 본래는 자바스크립트 언어로부터 파생되어 자바스크립트의 구문 형식을 따르지만 언어 독립형 데이터 포맷이다. 즉, 프로그래밍 언어나 플랫폼에 독립적이므로, 구문 분석 및 JSON 데이터 생성을 위한 코드는 C, C++, C#, 자바, 자바스크립트, 펄, 파이썬 등 수많은 프로그래밍 언어에서 쉽게 이용할 수 있다.
#
# * 출처 : [JSON - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/JSON)

# %% [markdown]
# ## requests를 통한 HTTP 요청
# * [Requests: HTTP for Humans™ — Requests documentation](https://requests.readthedocs.io/en/master/)

# %%
# requests 라이브러리를 통해 url을 받아옵니다.
response = requests.get(url)
str(response)
# Out:
# '<Response [200]>'

# %%
response.json()
# Out:
# {'result': {'etfItemList': [{'amonut': 145311,
#     'changeRate': 1.0,
#     'changeVal': 345,
#     'etfTabCode': 1,
#     'itemcode': '069500',
#     'itemname': 'KODEX 200',
#     'marketSum': 47195,
#     'nav': 35084.0,
#     'nowVal': 34985,
#     'quant': 4180043,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.4674},
#    {'amonut': 107221,
#     'changeRate': 0.81,
#     'changeVal': 95,
#     'etfTabCode': 4,
#     'itemcode': '371460',
#     'itemname': 'TIGER 차이나전기차SOLACTIVE',
#     'marketSum': 29425,
#     'nav': 11894.0,
#     'nowVal': 11890,
#     'quant': 8956866,
#     'risefall': '2',
#     'threeMonthEarnRate': -25.5132},
#    {'amonut': 309205,
#     'changeRate': 1.98,
#     'changeVal': 360,
#     'etfTabCode': 3,
#     'itemcode': '122630',
#     'itemname': 'KODEX 레버리지',
#     'marketSum': 21122,
#     'nav': 18679.0,
#     'nowVal': 18585,
#     'quant': 16856345,
#     'risefall': '2',
#     'threeMonthEarnRate': -2.6183},
#    {'amonut': 8789,
#     'changeRate': 1.35,
#     'changeVal': 1000,
#     'etfTabCode': 4,
#     'itemcode': '133690',
#     'itemname': 'TIGER 미국나스닥100',
#     'marketSum': 20964,
#     'nav': 74008.0,
#     'nowVal': 75220,
#     'quant': 117485,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.9795},
#    {'amonut': 380833,
#     'changeRate': -1.85,
#     'changeVal': -50,
#     'etfTabCode': 3,
#     'itemcode': '252670',
#     'itemname': 'KODEX 200선물인버스2X',
#     'marketSum': 19202,
#     'nav': 2646.0,
#     'nowVal': 2650,
#     'quant': 141997440,
#     'risefall': '5',
#     'threeMonthEarnRate': -1.099},
#    {'amonut': 54652,
#     'changeRate': 0.95,
#     'changeVal': 330,
#     'etfTabCode': 1,
#     'itemcode': '102110',
#     'itemname': 'TIGER 200',
#     'marketSum': 18126,
#     'nav': 35137.0,
#     'nowVal': 35060,
#     'quant': 1568552,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.3681},
#    {'amonut': 98417,
#     'changeRate': 0.01,
#     'changeVal': 15,
#     'etfTabCode': 6,
#     'itemcode': '157450',
#     'itemname': 'TIGER 단기통안채',
#     'marketSum': 18098,
#     'nav': 100796.0,
#     'nowVal': 100790,
#     'quant': 976423,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.2187},
#    {'amonut': 13082,
#     'changeRate': 0.02,
#     'changeVal': 25,
#     'etfTabCode': 6,
#     'itemcode': '214980',
#     'itemname': 'KODEX 단기채권PLUS',
#     'marketSum': 17960,
#     'nav': 103846.0,
#     'nowVal': 103840,
#     'quant': 125979,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.2946},
#    {'amonut': 8935,
#     'changeRate': 1.16,
#     'changeVal': 155,
#     'etfTabCode': 4,
#     'itemcode': '360750',
#     'itemname': 'TIGER 미국S&P500',
#     'marketSum': 16097,
#     'nav': 13364.0,
#     'nowVal': 13510,
#     'quant': 665897,
#     'risefall': '2',
#     'threeMonthEarnRate': 3.3166},
#    {'amonut': 2669,
#     'changeRate': 1.88,
#     'changeVal': 165,
#     'etfTabCode': 2,
#     'itemcode': '102780',
#     'itemname': 'KODEX 삼성그룹',
#     'marketSum': 15276,
#     'nav': 8988.0,
#     'nowVal': 8965,
#     'quant': 299740,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.7315},
#    {'amonut': 280122,
#     'changeRate': 0.01,
#     'changeVal': 15,
#     'etfTabCode': 6,
#     'itemcode': '153130',
#     'itemname': 'KODEX 단기채권',
#     'marketSum': 14787,
#     'nav': 103372.0,
#     'nowVal': 103375,
#     'quant': 2709886,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.1987},
#    {'amonut': 555,
#     'changeRate': 0.02,
#     'changeVal': 25,
#     'etfTabCode': 6,
#     'itemcode': '273130',
#     'itemname': 'KODEX 종합채권(AA-이상)액티브',
#     'marketSum': 14344,
#     'nav': 103600.0,
#     'nowVal': 103640,
#     'quant': 5364,
#     'risefall': '2',
#     'threeMonthEarnRate': -2.8913},
#    {'amonut': 12383,
#     'changeRate': 1.58,
#     'changeVal': 175,
#     'etfTabCode': 4,
#     'itemcode': '381170',
#     'itemname': 'TIGER 미국테크TOP10 INDXX',
#     'marketSum': 13529,
#     'nav': 11011.0,
#     'nowVal': 11260,
#     'quant': 1106429,
#     'risefall': '2',
#     'threeMonthEarnRate': -2.1193},
#    {'amonut': 36922,
#     'changeRate': -0.13,
#     'changeVal': -25,
#     'etfTabCode': 2,
#     'itemcode': '305720',
#     'itemname': 'KODEX 2차전지산업',
#     'marketSum': 13323,
#     'nav': 19704.0,
#     'nowVal': 19650,
#     'quant': 1884877,
#     'risefall': '5',
#     'threeMonthEarnRate': 6.6144},
#    {'amonut': 32832,
#     'changeRate': -0.35,
#     'changeVal': -70,
#     'etfTabCode': 2,
#     'itemcode': '305540',
#     'itemname': 'TIGER 2차전지테마',
#     'marketSum': 13054,
#     'nav': 20174.0,
#     'nowVal': 20145,
#     'quant': 1633729,
#     'risefall': '5',
#     'threeMonthEarnRate': 7.1807},
#    {'amonut': 6840,
#     'changeRate': 1.56,
#     'changeVal': 155,
#     'etfTabCode': 4,
#     'itemcode': '381180',
#     'itemname': 'TIGER 미국필라델피아반도체나스닥',
#     'marketSum': 13024,
#     'nav': 9892.0,
#     'nowVal': 10065,
#     'quant': 683975,
#     'risefall': '2',
#     'threeMonthEarnRate': -8.013},
#    {'amonut': 4,
#     'changeRate': 1.25,
#     'changeVal': 175,
#     'etfTabCode': 1,
#     'itemcode': '310970',
#     'itemname': 'TIGER MSCI Korea TR',
#     'marketSum': 12800,
#     'nav': 14206.0,
#     'nowVal': 14175,
#     'quant': 309,
#     'risefall': '2',
#     'threeMonthEarnRate': -2.0294},
#    {'amonut': 3288,
#     'changeRate': 1.28,
#     'changeVal': 145,
#     'etfTabCode': 2,
#     'itemcode': '292150',
#     'itemname': 'TIGER TOP10',
#     'marketSum': 11777,
#     'nav': 11448.0,
#     'nowVal': 11445,
#     'quant': 289181,
#     'risefall': '2',
#     'threeMonthEarnRate': -4.3115},
#    {'amonut': 342,
#     'changeRate': 0.95,
#     'changeVal': 110,
#     'etfTabCode': 1,
#     'itemcode': '278530',
#     'itemname': 'KODEX 200TR',
#     'marketSum': 11109,
#     'nav': 11684.0,
#     'nowVal': 11645,
#     'quant': 29578,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.3026},
#    {'amonut': 3487,
#     'changeRate': 1.12,
#     'changeVal': 125,
#     'etfTabCode': 1,
#     'itemcode': '278540',
#     'itemname': 'KODEX MSCI Korea TR',
#     'marketSum': 10489,
#     'nav': 11311.0,
#     'nowVal': 11315,
#     'quant': 310150,
#     'risefall': '2',
#     'threeMonthEarnRate': -1.9282},
#    {'amonut': 6979,
#     'changeRate': 1.1,
#     'changeVal': 385,
#     'etfTabCode': 1,
#     'itemcode': '148020',
#     'itemname': 'KBSTAR 200',
#     'marketSum': 9882,
#     'nav': 35303.0,
#     'nowVal': 35230,
#     'quant': 199121,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.3105},
#    {'amonut': 84067,
#     'changeRate': -0.37,
#     'changeVal': -40,
#     'etfTabCode': 3,
#     'itemcode': '233740',
#     'itemname': 'KODEX 코스닥150레버리지',
#     'marketSum': 8903,
#     'nav': 10844.0,
#     'nowVal': 10675,
#     'quant': 7883654,
#     'risefall': '5',
#     'threeMonthEarnRate': 2.5358},
#    {'amonut': 135717,
#     'changeRate': -1.11,
#     'changeVal': -50,
#     'etfTabCode': 3,
#     'itemcode': '114800',
#     'itemname': 'KODEX 인버스',
#     'marketSum': 8358,
#     'nav': 4460.0,
#     'nowVal': 4460,
#     'quant': 30231835,
#     'risefall': '5',
#     'threeMonthEarnRate': 0.1109},
#    {'amonut': 7598,
#     'changeRate': 0.3,
#     'changeVal': 95,
#     'etfTabCode': 2,
#     'itemcode': '139260',
#     'itemname': 'TIGER 200 IT',
#     'marketSum': 8316,
#     'nav': 31709.0,
#     'nowVal': 31620,
#     'quant': 240838,
#     'risefall': '2',
#     'threeMonthEarnRate': -4.2608},
#    {'amonut': 8716,
#     'changeRate': 1.05,
#     'changeVal': 195,
#     'etfTabCode': 2,
#     'itemcode': '091180',
#     'itemname': 'KODEX 자동차',
#     'marketSum': 7321,
#     'nav': 18862.0,
#     'nowVal': 18845,
#     'quant': 465039,
#     'risefall': '2',
#     'threeMonthEarnRate': 1.7116},
#    {'amonut': 127,
#     'changeRate': 1.08,
#     'changeVal': 375,
#     'etfTabCode': 1,
#     'itemcode': '293180',
#     'itemname': 'HANARO 200',
#     'marketSum': 6633,
#     'nav': 35162.0,
#     'nowVal': 35095,
#     'quant': 3645,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.551},
#    {'amonut': 4883,
#     'changeRate': 1.11,
#     'changeVal': 385,
#     'etfTabCode': 1,
#     'itemcode': '105190',
#     'itemname': 'KINDEX 200',
#     'marketSum': 6578,
#     'nav': 35175.0,
#     'nowVal': 35085,
#     'quant': 139493,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.7852},
#    {'amonut': 24167,
#     'changeRate': 0.99,
#     'changeVal': 350,
#     'etfTabCode': 1,
#     'itemcode': '152100',
#     'itemname': 'ARIRANG 200',
#     'marketSum': 6363,
#     'nav': 35618.0,
#     'nowVal': 35545,
#     'quant': 681283,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.1114},
#    {'amonut': 1393,
#     'changeRate': 0.98,
#     'changeVal': 90,
#     'etfTabCode': 4,
#     'itemcode': '394670',
#     'itemname': 'TIGER 글로벌리튬&2차전지SOLACTIVE(합성)',
#     'marketSum': 6294,
#     'nav': 9278.0,
#     'nowVal': 9250,
#     'quant': 150402,
#     'risefall': '2',
#     'threeMonthEarnRate': -10.7648},
#    {'amonut': 253,
#     'changeRate': 1.31,
#     'changeVal': 220,
#     'etfTabCode': 2,
#     'itemcode': '315930',
#     'itemname': 'KODEX Top5PlusTR',
#     'marketSum': 6060,
#     'nav': 17070.0,
#     'nowVal': 17070,
#     'quant': 15013,
#     'risefall': '2',
#     'threeMonthEarnRate': -3.7693},
#    {'amonut': 2452,
#     'changeRate': 1.26,
#     'changeVal': 170,
#     'etfTabCode': 4,
#     'itemcode': '360200',
#     'itemname': 'KINDEX 미국S&P500',
#     'marketSum': 5736,
#     'nav': 13472.0,
#     'nowVal': 13625,
#     'quant': 181609,
#     'risefall': '2',
#     'threeMonthEarnRate': 3.3703},
#    {'amonut': 48443,
#     'changeRate': -0.12,
#     'changeVal': -15,
#     'etfTabCode': 1,
#     'itemcode': '229200',
#     'itemname': 'KODEX 코스닥150',
#     'marketSum': 5661,
#     'nav': 12378.0,
#     'nowVal': 12175,
#     'quant': 3982817,
#     'risefall': '5',
#     'threeMonthEarnRate': 1.9966},
#    {'amonut': 6844,
#     'changeRate': 0.02,
#     'changeVal': 20,
#     'etfTabCode': 6,
#     'itemcode': '196230',
#     'itemname': 'KBSTAR 단기통안채',
#     'marketSum': 5585,
#     'nav': 105104.0,
#     'nowVal': 105100,
#     'quant': 65125,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.205},
#    {'amonut': 205,
#     'changeRate': 1.06,
#     'changeVal': 445,
#     'etfTabCode': 1,
#     'itemcode': '294400',
#     'itemname': 'KOSEF 200TR',
#     'marketSum': 5361,
#     'nav': 42461.0,
#     'nowVal': 42380,
#     'quant': 4872,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.2854},
#    {'amonut': 78,
#     'changeRate': 0.02,
#     'changeVal': 20,
#     'etfTabCode': 6,
#     'itemcode': '190620',
#     'itemname': 'KINDEX 단기통안채',
#     'marketSum': 4570,
#     'nav': 100428.0,
#     'nowVal': 100430,
#     'quant': 778,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.2496},
#    {'amonut': 15792,
#     'changeRate': 1.61,
#     'changeVal': 225,
#     'etfTabCode': 2,
#     'itemcode': '364980',
#     'itemname': 'TIGER KRX2차전지K-뉴딜',
#     'marketSum': 4501,
#     'nav': 14214.0,
#     'nowVal': 14200,
#     'quant': 1121933,
#     'risefall': '2',
#     'threeMonthEarnRate': -3.7432},
#    {'amonut': 1088,
#     'changeRate': 0.56,
#     'changeVal': 115,
#     'etfTabCode': 4,
#     'itemcode': '251350',
#     'itemname': 'KODEX 선진국MSCI World',
#     'marketSum': 4483,
#     'nav': 20394.0,
#     'nowVal': 20565,
#     'quant': 53113,
#     'risefall': '2',
#     'threeMonthEarnRate': 2.5319},
#    {'amonut': 118486,
#     'changeRate': 0.32,
#     'changeVal': 15,
#     'etfTabCode': 3,
#     'itemcode': '251340',
#     'itemname': 'KODEX 코스닥150선물인버스',
#     'marketSum': 4286,
#     'nav': 4712.0,
#     'nowVal': 4725,
#     'quant': 25084202,
#     'risefall': '2',
#     'threeMonthEarnRate': -5.8},
#    {'amonut': 3456,
#     'changeRate': 1.28,
#     'changeVal': 150,
#     'etfTabCode': 4,
#     'itemcode': '379800',
#     'itemname': 'KODEX 미국S&P500TR',
#     'marketSum': 4163,
#     'nav': 11785.0,
#     'nowVal': 11910,
#     'quant': 292341,
#     'risefall': '2',
#     'threeMonthEarnRate': 3.2938},
#    {'amonut': 21967,
#     'changeRate': 1.1,
#     'changeVal': 380,
#     'etfTabCode': 1,
#     'itemcode': '069660',
#     'itemname': 'KOSEF 200',
#     'marketSum': 4020,
#     'nav': 35020.0,
#     'nowVal': 34960,
#     'quant': 630416,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.6509},
#    {'amonut': 1614,
#     'changeRate': 2.02,
#     'changeVal': 420,
#     'etfTabCode': 4,
#     'itemcode': '314250',
#     'itemname': 'KODEX 미국FANG플러스(H)',
#     'marketSum': 3979,
#     'nav': 20670.0,
#     'nowVal': 21255,
#     'quant': 76107,
#     'risefall': '2',
#     'threeMonthEarnRate': -16.7433},
#    {'amonut': 2538,
#     'changeRate': 1.33,
#     'changeVal': 170,
#     'etfTabCode': 4,
#     'itemcode': '367380',
#     'itemname': 'KINDEX 미국나스닥100',
#     'marketSum': 3976,
#     'nav': 12709.0,
#     'nowVal': 12910,
#     'quant': 198484,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.8936},
#    {'amonut': 1,
#     'changeRate': 0.01,
#     'changeVal': 5,
#     'etfTabCode': 6,
#     'itemcode': '385540',
#     'itemname': 'KBSTAR KIS종합채권(A-이상)액티브',
#     'marketSum': 3843,
#     'nav': 95587.0,
#     'nowVal': 95620,
#     'quant': 19,
#     'risefall': '2',
#     'threeMonthEarnRate': -2.7908},
#    {'amonut': 7868,
#     'changeRate': -2.49,
#     'changeVal': -245,
#     'etfTabCode': 2,
#     'itemcode': '400970',
#     'itemname': 'TIGER Fn메타버스',
#     'marketSum': 3825,
#     'nav': 9624.0,
#     'nowVal': 9610,
#     'quant': 814803,
#     'risefall': '5',
#     'threeMonthEarnRate': 0.8682},
#    {'amonut': 7613,
#     'changeRate': -1.15,
#     'changeVal': -110,
#     'etfTabCode': 2,
#     'itemcode': '401470',
#     'itemname': 'KODEX K-메타버스액티브',
#     'marketSum': 3811,
#     'nav': 9487.0,
#     'nowVal': 9480,
#     'quant': 801733,
#     'risefall': '5',
#     'threeMonthEarnRate': -4.5252},
#    {'amonut': 2680,
#     'changeRate': 0.02,
#     'changeVal': 25,
#     'etfTabCode': 6,
#     'itemcode': '148070',
#     'itemname': 'KOSEF 국고채10년',
#     'marketSum': 3400,
#     'nav': 111704.0,
#     'nowVal': 111830,
#     'quant': 23976,
#     'risefall': '2',
#     'threeMonthEarnRate': -3.716},
#    {'amonut': 150,
#     'changeRate': 0.04,
#     'changeVal': 20,
#     'etfTabCode': 6,
#     'itemcode': '272580',
#     'itemname': 'TIGER 단기채권액티브',
#     'marketSum': 3382,
#     'nav': 50478.0,
#     'nowVal': 50485,
#     'quant': 2980,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.308},
#    {'amonut': 2756,
#     'changeRate': 1.37,
#     'changeVal': 150,
#     'etfTabCode': 4,
#     'itemcode': '379810',
#     'itemname': 'KODEX 미국나스닥100TR',
#     'marketSum': 3336,
#     'nav': 10897.0,
#     'nowVal': 11065,
#     'quant': 250746,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.9529},
#    {'amonut': 3833,
#     'changeRate': 1.08,
#     'changeVal': 60,
#     'etfTabCode': 4,
#     'itemcode': '371160',
#     'itemname': 'TIGER 차이나항셍테크',
#     'marketSum': 3301,
#     'nav': 5641.0,
#     'nowVal': 5600,
#     'quant': 684234,
#     'risefall': '2',
#     'threeMonthEarnRate': -22.6257},
#    {'amonut': 2014,
#     'changeRate': 0.7,
#     'changeVal': 75,
#     'etfTabCode': 6,
#     'itemcode': '329750',
#     'itemname': 'TIGER 미국달러단기채권액티브',
#     'marketSum': 3190,
#     'nav': 10843.0,
#     'nowVal': 10850,
#     'quant': 186027,
#     'risefall': '2',
#     'threeMonthEarnRate': 4.8151},
#    {'amonut': 628,
#     'changeRate': 1.01,
#     'changeVal': 270,
#     'etfTabCode': 1,
#     'itemcode': '226490',
#     'itemname': 'KODEX 코스피',
#     'marketSum': 3154,
#     'nav': 26978.0,
#     'nowVal': 26960,
#     'quant': 23467,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.9683},
#    {'amonut': 48848,
#     'changeRate': 0.03,
#     'changeVal': 30,
#     'etfTabCode': 6,
#     'itemcode': '385550',
#     'itemname': 'KBSTAR KIS단기종합채권(AA-이상)액티브',
#     'marketSum': 3136,
#     'nav': 100816.0,
#     'nowVal': 100830,
#     'quant': 484524,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.3734},
#    {'amonut': 1307,
#     'changeRate': 0.67,
#     'changeVal': 330,
#     'etfTabCode': 4,
#     'itemcode': '143850',
#     'itemname': 'TIGER 미국S&P500선물(H)',
#     'marketSum': 3117,
#     'nav': 49689.0,
#     'nowVal': 49670,
#     'quant': 26368,
#     'risefall': '2',
#     'threeMonthEarnRate': -1.723},
#    {'amonut': 663,
#     'changeRate': 1.47,
#     'changeVal': 145,
#     'etfTabCode': 2,
#     'itemcode': '367770',
#     'itemname': 'KBSTAR Fn수소경제테마',
#     'marketSum': 2929,
#     'nav': 10000.0,
#     'nowVal': 9995,
#     'quant': 67288,
#     'risefall': '2',
#     'threeMonthEarnRate': 2.9215},
#    {'amonut': 0,
#     'changeRate': 0.82,
#     'changeVal': 115,
#     'etfTabCode': 1,
#     'itemcode': '332940',
#     'itemname': 'HANARO MSCI Korea TR',
#     'marketSum': 2844,
#     'nav': 14195.0,
#     'nowVal': 14150,
#     'quant': 51,
#     'risefall': '2',
#     'threeMonthEarnRate': -1.6124},
#    {'amonut': 289,
#     'changeRate': 1.42,
#     'changeVal': 165,
#     'etfTabCode': 2,
#     'itemcode': '290130',
#     'itemname': 'KBSTAR ESG사회책임투자',
#     'marketSum': 2844,
#     'nav': 11776.0,
#     'nowVal': 11775,
#     'quant': 24858,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.3387},
#    {'amonut': 2559,
#     'changeRate': 0.76,
#     'changeVal': 65,
#     'etfTabCode': 2,
#     'itemcode': '364960',
#     'itemname': 'TIGER KRX BBIG K-뉴딜',
#     'marketSum': 2695,
#     'nav': 8571.0,
#     'nowVal': 8570,
#     'quant': 300961,
#     'risefall': '2',
#     'threeMonthEarnRate': -7.4498},
#    {'amonut': 8545,
#     'changeRate': -0.93,
#     'changeVal': -60,
#     'etfTabCode': 2,
#     'itemcode': '329200',
#     'itemname': 'TIGER 리츠부동산인프라',
#     'marketSum': 2569,
#     'nav': 6386.0,
#     'nowVal': 6390,
#     'quant': 1337718,
#     'risefall': '5',
#     'threeMonthEarnRate': 13.8648},
#    {'amonut': 17,
#     'changeRate': 1.67,
#     'changeVal': 145,
#     'etfTabCode': 2,
#     'itemcode': '213610',
#     'itemname': 'KODEX 삼성그룹밸류',
#     'marketSum': 2493,
#     'nav': 8844.0,
#     'nowVal': 8840,
#     'quant': 1954,
#     'risefall': '2',
#     'threeMonthEarnRate': 5.3222},
#    {'amonut': 5544,
#     'changeRate': -0.78,
#     'changeVal': -275,
#     'etfTabCode': 2,
#     'itemcode': '091160',
#     'itemname': 'KODEX 반도체',
#     'marketSum': 2489,
#     'nav': 35114.0,
#     'nowVal': 35055,
#     'quant': 157860,
#     'risefall': '5',
#     'threeMonthEarnRate': 2.3275},
#    {'amonut': 1,
#     'changeRate': 0.05,
#     'changeVal': 25,
#     'etfTabCode': 7,
#     'itemcode': '357870',
#     'itemname': 'TIGER CD금리투자KIS(합성)',
#     'marketSum': 2471,
#     'nav': 50788.0,
#     'nowVal': 50805,
#     'quant': 26,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.3458},
#    {'amonut': 10808,
#     'changeRate': 2.61,
#     'changeVal': 195,
#     'etfTabCode': 2,
#     'itemcode': '091170',
#     'itemname': 'KODEX 은행',
#     'marketSum': 2400,
#     'nav': 7636.0,
#     'nowVal': 7680,
#     'quant': 1438903,
#     'risefall': '2',
#     'threeMonthEarnRate': 4.8032},
#    {'amonut': 362,
#     'changeRate': 1.38,
#     'changeVal': 135,
#     'etfTabCode': 4,
#     'itemcode': '394660',
#     'itemname': 'TIGER 글로벌자율주행&전기차SOLACTIVE',
#     'marketSum': 2398,
#     'nav': 9806.0,
#     'nowVal': 9910,
#     'quant': 36731,
#     'risefall': '2',
#     'threeMonthEarnRate': -7.3021},
#    {'amonut': 6840,
#     'changeRate': 1.72,
#     'changeVal': 215,
#     'etfTabCode': 2,
#     'itemcode': '325020',
#     'itemname': 'KODEX 배당가치',
#     'marketSum': 2350,
#     'nav': 12705.0,
#     'nowVal': 12705,
#     'quant': 541965,
#     'risefall': '2',
#     'threeMonthEarnRate': 3.2477},
#    {'amonut': 3127,
#     'changeRate': 0.0,
#     'changeVal': 0,
#     'etfTabCode': 2,
#     'itemcode': '228800',
#     'itemname': 'TIGER 여행레저',
#     'marketSum': 2311,
#     'nav': 4893.0,
#     'nowVal': 4885,
#     'quant': 642084,
#     'risefall': '3',
#     'threeMonthEarnRate': 16.7064},
#    {'amonut': 384,
#     'changeRate': -0.5,
#     'changeVal': -35,
#     'etfTabCode': 4,
#     'itemcode': '414780',
#     'itemname': 'TIGER 차이나과창판STAR50(합성)',
#     'marketSum': 2268,
#     'nav': 7070.0,
#     'nowVal': 6935,
#     'quant': 55487,
#     'risefall': '5',
#     'threeMonthEarnRate': -26.438},
#    {'amonut': 0,
#     'changeRate': 1.39,
#     'changeVal': 115,
#     'etfTabCode': 1,
#     'itemcode': '407310',
#     'itemname': 'HANARO 200 TOP10',
#     'marketSum': 2210,
#     'nav': 8400.0,
#     'nowVal': 8370,
#     'quant': 57,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.1794},
#    {'amonut': 461,
#     'changeRate': 4.03,
#     'changeVal': 880,
#     'etfTabCode': 4,
#     'itemcode': '245710',
#     'itemname': 'KINDEX 베트남VN30(합성)',
#     'marketSum': 2112,
#     'nav': 22595.0,
#     'nowVal': 22715,
#     'quant': 20559,
#     'risefall': '2',
#     'threeMonthEarnRate': -5.8837},
#    {'amonut': 274,
#     'changeRate': 1.38,
#     'changeVal': 170,
#     'etfTabCode': 4,
#     'itemcode': '368590',
#     'itemname': 'KBSTAR 미국나스닥100',
#     'marketSum': 2105,
#     'nav': 12332.0,
#     'nowVal': 12530,
#     'quant': 22081,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.9604},
#    {'amonut': 606,
#     'changeRate': -0.25,
#     'changeVal': -40,
#     'etfTabCode': 7,
#     'itemcode': '182480',
#     'itemname': 'TIGER 미국MSCI리츠(합성 H)',
#     'marketSum': 2013,
#     'nav': 15601.0,
#     'nowVal': 15785,
#     'quant': 38499,
#     'risefall': '5',
#     'threeMonthEarnRate': 6.2333},
#    {'amonut': 96,
#     'changeRate': 1.13,
#     'changeVal': 135,
#     'etfTabCode': 1,
#     'itemcode': '295040',
#     'itemname': 'SOL 200TR',
#     'marketSum': 2001,
#     'nav': 12157.0,
#     'nowVal': 12130,
#     'quant': 7980,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.3738},
#    {'amonut': 7,
#     'changeRate': 0.01,
#     'changeVal': 10,
#     'etfTabCode': 7,
#     'itemcode': '423160',
#     'itemname': 'KODEX KOFR금리액티브(합성)',
#     'marketSum': 2000,
#     'nav': 100008.0,
#     'nowVal': 100020,
#     'quant': 72,
#     'risefall': '2',
#     'threeMonthEarnRate': None},
#    {'amonut': 2830,
#     'changeRate': -0.83,
#     'changeVal': -105,
#     'etfTabCode': 2,
#     'itemcode': '161510',
#     'itemname': 'ARIRANG 고배당주',
#     'marketSum': 1977,
#     'nav': 12551.0,
#     'nowVal': 12530,
#     'quant': 228260,
#     'risefall': '5',
#     'threeMonthEarnRate': 9.9958},
#    {'amonut': 0,
#     'changeRate': 0.0,
#     'changeVal': 0,
#     'etfTabCode': 6,
#     'itemcode': '390950',
#     'itemname': 'HANARO 단기채권액티브',
#     'marketSum': 1976,
#     'nav': 100621.0,
#     'nowVal': 100595,
#     'quant': 0,
#     'risefall': '3',
#     'threeMonthEarnRate': 0.2141},
#    {'amonut': 646,
#     'changeRate': -1.41,
#     'changeVal': -125,
#     'etfTabCode': 2,
#     'itemcode': '401170',
#     'itemname': 'KBSTAR iSelect메타버스',
#     'marketSum': 1966,
#     'nav': 8745.0,
#     'nowVal': 8745,
#     'quant': 73795,
#     'risefall': '5',
#     'threeMonthEarnRate': -5.5733},
#    {'amonut': 1609,
#     'changeRate': -1.33,
#     'changeVal': -170,
#     'etfTabCode': 5,
#     'itemcode': '132030',
#     'itemname': 'KODEX 골드선물(H)',
#     'marketSum': 1896,
#     'nav': 12684.0,
#     'nowVal': 12640,
#     'quant': 127111,
#     'risefall': '5',
#     'threeMonthEarnRate': 4.7852},
#    {'amonut': 1149,
#     'changeRate': 0.47,
#     'changeVal': 35,
#     'etfTabCode': 4,
#     'itemcode': '412770',
#     'itemname': 'TIGER 글로벌메타버스액티브',
#     'marketSum': 1889,
#     'nav': 7475.0,
#     'nowVal': 7530,
#     'quant': 153504,
#     'risefall': '2',
#     'threeMonthEarnRate': -11.0914},
#    {'amonut': 380,
#     'changeRate': 1.39,
#     'changeVal': 215,
#     'etfTabCode': 4,
#     'itemcode': '275980',
#     'itemname': 'TIGER 글로벌4차산업혁신기술(합성 H)',
#     'marketSum': 1822,
#     'nav': 15463.0,
#     'nowVal': 15730,
#     'quant': 24439,
#     'risefall': '2',
#     'threeMonthEarnRate': -6.7048},
#    {'amonut': 135,
#     'changeRate': -0.05,
#     'changeVal': -10,
#     'etfTabCode': 2,
#     'itemcode': '326240',
#     'itemname': 'KBSTAR IT플러스',
#     'marketSum': 1719,
#     'nav': 18203.0,
#     'nowVal': 18205,
#     'quant': 7471,
#     'risefall': '5',
#     'threeMonthEarnRate': -3.5292},
#    {'amonut': 895,
#     'changeRate': -0.42,
#     'changeVal': -110,
#     'etfTabCode': 4,
#     'itemcode': '168580',
#     'itemname': 'KINDEX 중국본토CSI300',
#     'marketSum': 1709,
#     'nav': 26573.0,
#     'nowVal': 26285,
#     'quant': 34203,
#     'risefall': '5',
#     'threeMonthEarnRate': -15.2649},
#    {'amonut': 467,
#     'changeRate': 0.61,
#     'changeVal': 60,
#     'etfTabCode': 4,
#     'itemcode': '192090',
#     'itemname': 'TIGER 차이나CSI300',
#     'marketSum': 1673,
#     'nav': 9887.0,
#     'nowVal': 9900,
#     'quant': 47302,
#     'risefall': '2',
#     'threeMonthEarnRate': -14.3604},
#    {'amonut': 41,
#     'changeRate': -0.07,
#     'changeVal': -5,
#     'etfTabCode': 4,
#     'itemcode': '415340',
#     'itemname': 'KODEX 차이나과창판STAR50(합성)',
#     'marketSum': 1645,
#     'nav': 7163.0,
#     'nowVal': 7000,
#     'quant': 5977,
#     'risefall': '5',
#     'threeMonthEarnRate': -27.0693},
#    {'amonut': 305,
#     'changeRate': 1.33,
#     'changeVal': 155,
#     'etfTabCode': 4,
#     'itemcode': '379780',
#     'itemname': 'KBSTAR 미국S&P500',
#     'marketSum': 1640,
#     'nav': 11651.0,
#     'nowVal': 11795,
#     'quant': 26104,
#     'risefall': '2',
#     'threeMonthEarnRate': 3.3215},
#    {'amonut': 2848,
#     'changeRate': 1.09,
#     'changeVal': 35,
#     'etfTabCode': 5,
#     'itemcode': '217770',
#     'itemname': 'TIGER 원유선물인버스(H)',
#     'marketSum': 1611,
#     'nav': 3259.0,
#     'nowVal': 3255,
#     'quant': 873807,
#     'risefall': '2',
#     'threeMonthEarnRate': -27.3958},
#    {'amonut': 13,
#     'changeRate': 1.08,
#     'changeVal': 290,
#     'etfTabCode': 1,
#     'itemcode': '302450',
#     'itemname': 'KBSTAR 코스피',
#     'marketSum': 1591,
#     'nav': 27186.0,
#     'nowVal': 27190,
#     'quant': 506,
#     'risefall': '2',
#     'threeMonthEarnRate': 1.116},
#    {'amonut': 438,
#     'changeRate': 0.18,
#     'changeVal': 20,
#     'etfTabCode': 7,
#     'itemcode': '329650',
#     'itemname': 'KODEX TRF3070',
#     'marketSum': 1535,
#     'nav': 10980.0,
#     'nowVal': 11040,
#     'quant': 39790,
#     'risefall': '2',
#     'threeMonthEarnRate': -1.6511},
#    {'amonut': 157,
#     'changeRate': 0.02,
#     'changeVal': 20,
#     'etfTabCode': 6,
#     'itemcode': '130730',
#     'itemname': 'KOSEF 단기자금',
#     'marketSum': 1533,
#     'nav': 101312.0,
#     'nowVal': 101305,
#     'quant': 1550,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.3219},
#    {'amonut': 439,
#     'changeRate': 1.28,
#     'changeVal': 385,
#     'etfTabCode': 2,
#     'itemcode': '143860',
#     'itemname': 'TIGER 헬스케어',
#     'marketSum': 1524,
#     'nav': 30774.0,
#     'nowVal': 30480,
#     'quant': 14443,
#     'risefall': '2',
#     'threeMonthEarnRate': 4.3508},
#    {'amonut': 1391,
#     'changeRate': -0.82,
#     'changeVal': -70,
#     'etfTabCode': 2,
#     'itemcode': '228810',
#     'itemname': 'TIGER 미디어컨텐츠',
#     'marketSum': 1443,
#     'nav': 8539.0,
#     'nowVal': 8515,
#     'quant': 162868,
#     'risefall': '5',
#     'threeMonthEarnRate': 13.4387},
#    {'amonut': 477,
#     'changeRate': 1.55,
#     'changeVal': 355,
#     'etfTabCode': 2,
#     'itemcode': '138540',
#     'itemname': 'TIGER 현대차그룹+펀더멘털',
#     'marketSum': 1437,
#     'nav': 23414.0,
#     'nowVal': 23330,
#     'quant': 20534,
#     'risefall': '2',
#     'threeMonthEarnRate': 4.4439},
#    {'amonut': 1877,
#     'changeRate': -1.3,
#     'changeVal': -475,
#     'etfTabCode': 2,
#     'itemcode': '091230',
#     'itemname': 'TIGER 반도체',
#     'marketSum': 1418,
#     'nav': 35973.0,
#     'nowVal': 36000,
#     'quant': 52148,
#     'risefall': '5',
#     'threeMonthEarnRate': 3.0048},
#    {'amonut': 607,
#     'changeRate': 0.69,
#     'changeVal': 140,
#     'etfTabCode': 4,
#     'itemcode': '219480',
#     'itemname': 'KODEX 미국S&P500선물(H)',
#     'marketSum': 1359,
#     'nav': 20440.0,
#     'nowVal': 20435,
#     'quant': 29827,
#     'risefall': '2',
#     'threeMonthEarnRate': -1.8618},
#    {'amonut': 6479,
#     'changeRate': 1.3,
#     'changeVal': 60,
#     'etfTabCode': 5,
#     'itemcode': '271050',
#     'itemname': 'KODEX WTI원유선물인버스(H)',
#     'marketSum': 1345,
#     'nav': 4658.0,
#     'nowVal': 4670,
#     'quant': 1387680,
#     'risefall': '2',
#     'threeMonthEarnRate': -27.3444},
#    {'amonut': 1506,
#     'changeRate': 1.53,
#     'changeVal': 85,
#     'etfTabCode': 4,
#     'itemcode': '372330',
#     'itemname': 'KODEX 차이나항셍테크',
#     'marketSum': 1324,
#     'nav': 5652.0,
#     'nowVal': 5645,
#     'quant': 267739,
#     'risefall': '2',
#     'threeMonthEarnRate': -22.3464},
#    {'amonut': 24,
#     'changeRate': 1.83,
#     'changeVal': 140,
#     'etfTabCode': 2,
#     'itemcode': '150460',
#     'itemname': 'TIGER 중국소비테마',
#     'marketSum': 1300,
#     'nav': 7829.0,
#     'nowVal': 7795,
#     'quant': 3112,
#     'risefall': '2',
#     'threeMonthEarnRate': 12.7192},
#    {'amonut': 27,
#     'changeRate': -0.04,
#     'changeVal': -5,
#     'etfTabCode': 1,
#     'itemcode': '270810',
#     'itemname': 'KBSTAR 코스닥150',
#     'marketSum': 1297,
#     'nav': 12348.0,
#     'nowVal': 12190,
#     'quant': 2241,
#     'risefall': '5',
#     'threeMonthEarnRate': 2.1702},
#    {'amonut': 443,
#     'changeRate': 1.21,
#     'changeVal': 90,
#     'etfTabCode': 4,
#     'itemcode': '411420',
#     'itemname': 'KODEX 미국메타버스나스닥액티브',
#     'marketSum': 1275,
#     'nav': 7334.0,
#     'nowVal': 7500,
#     'quant': 59447,
#     'risefall': '2',
#     'threeMonthEarnRate': -8.1216},
#    {'amonut': 4,
#     'changeRate': 1.0,
#     'changeVal': 420,
#     'etfTabCode': 1,
#     'itemcode': '332930',
#     'itemname': 'HANARO 200TR',
#     'marketSum': 1271,
#     'nav': 42517.0,
#     'nowVal': 42375,
#     'quant': 107,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.4391},
#    {'amonut': 6697,
#     'changeRate': 1.7,
#     'changeVal': 105,
#     'etfTabCode': 4,
#     'itemcode': '409820',
#     'itemname': 'KODEX 미국나스닥100레버리지(합성 H)',
#     'marketSum': 1269,
#     'nav': 6076.0,
#     'nowVal': 6280,
#     'quant': 1075244,
#     'risefall': '2',
#     'threeMonthEarnRate': -14.2362},
#    {'amonut': 1390,
#     'changeRate': -0.04,
#     'changeVal': -5,
#     'etfTabCode': 1,
#     'itemcode': '232080',
#     'itemname': 'TIGER 코스닥150',
#     'marketSum': 1261,
#     'nav': 12666.0,
#     'nowVal': 12485,
#     'quant': 111504,
#     'risefall': '5',
#     'threeMonthEarnRate': 2.0408},
#    {'amonut': 634,
#     'changeRate': 1.46,
#     'changeVal': 260,
#     'etfTabCode': 4,
#     'itemcode': '309230',
#     'itemname': 'KINDEX 미국WideMoat가치주',
#     'marketSum': 1231,
#     'nav': 17888.0,
#     'nowVal': 18100,
#     'quant': 35177,
#     'risefall': '2',
#     'threeMonthEarnRate': 2.8835},
#    {'amonut': 2014,
#     'changeRate': -1.27,
#     'changeVal': -215,
#     'etfTabCode': 5,
#     'itemcode': '261220',
#     'itemname': 'KODEX WTI원유선물(H)',
#     'marketSum': 1203,
#     'nav': 16724.0,
#     'nowVal': 16710,
#     'quant': 120663,
#     'risefall': '5',
#     'threeMonthEarnRate': 24.7696},
#    {'amonut': 4784,
#     'changeRate': 2.47,
#     'changeVal': 240,
#     'etfTabCode': 4,
#     'itemcode': '423920',
#     'itemname': 'TIGER 미국필라델피아반도체레버리지(합성)',
#     'marketSum': 1182,
#     'nav': 9655.0,
#     'nowVal': 9940,
#     'quant': 487110,
#     'risefall': '2',
#     'threeMonthEarnRate': None},
#    {'amonut': 74,
#     'changeRate': -0.23,
#     'changeVal': -130,
#     'etfTabCode': 6,
#     'itemcode': '114260',
#     'itemname': 'KODEX 국고채3년',
#     'marketSum': 1182,
#     'nav': 56425.0,
#     'nowVal': 56375,
#     'quant': 1315,
#     'risefall': '5',
#     'threeMonthEarnRate': -1.2064},
#    {'amonut': 116,
#     'changeRate': -0.52,
#     'changeVal': -60,
#     'etfTabCode': 3,
#     'itemcode': '278240',
#     'itemname': 'KBSTAR 코스닥150선물레버리지',
#     'marketSum': 1161,
#     'nav': 11501.0,
#     'nowVal': 11440,
#     'quant': 10291,
#     'risefall': '5',
#     'threeMonthEarnRate': 5.553},
#    {'amonut': 30790,
#     'changeRate': -2.12,
#     'changeVal': -60,
#     'etfTabCode': 3,
#     'itemcode': '252710',
#     'itemname': 'TIGER 200선물인버스2X',
#     'marketSum': 1147,
#     'nav': 2764.0,
#     'nowVal': 2770,
#     'quant': 10968539,
#     'risefall': '5',
#     'threeMonthEarnRate': -0.5273},
#    {'amonut': 48,
#     'changeRate': 0.02,
#     'changeVal': 25,
#     'etfTabCode': 6,
#     'itemcode': '273140',
#     'itemname': 'KODEX 단기변동금리부채권액티브',
#     'marketSum': 1146,
#     'nav': 103463.0,
#     'nowVal': 103460,
#     'quant': 467,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.3687},
#    {'amonut': 636,
#     'changeRate': 1.03,
#     'changeVal': 140,
#     'etfTabCode': 1,
#     'itemcode': '328370',
#     'itemname': 'ARIRANG 코스피TR',
#     'marketSum': 1128,
#     'nav': 13749.0,
#     'nowVal': 13750,
#     'quant': 46513,
#     'risefall': '2',
#     'threeMonthEarnRate': 1.4914},
#    {'amonut': 4,
#     'changeRate': 0.17,
#     'changeVal': 175,
#     'etfTabCode': 3,
#     'itemcode': '282000',
#     'itemname': 'KBSTAR 국고채3년선물인버스',
#     'marketSum': 1125,
#     'nav': 103390.0,
#     'nowVal': 103405,
#     'quant': 48,
#     'risefall': '2',
#     'threeMonthEarnRate': 1.5144},
#    {'amonut': 2207,
#     'changeRate': 1.72,
#     'changeVal': 145,
#     'etfTabCode': 2,
#     'itemcode': '395750',
#     'itemname': 'ARIRANG ESG가치주액티브',
#     'marketSum': 1079,
#     'nav': 8569.0,
#     'nowVal': 8595,
#     'quant': 259423,
#     'risefall': '2',
#     'threeMonthEarnRate': 1.1196},
#    {'amonut': 470,
#     'changeRate': 0.4,
#     'changeVal': 315,
#     'etfTabCode': 6,
#     'itemcode': '385560',
#     'itemname': 'KBSTAR KIS국고채30년Enhanced',
#     'marketSum': 1052,
#     'nav': 79007.0,
#     'nowVal': 79130,
#     'quant': 5971,
#     'risefall': '2',
#     'threeMonthEarnRate': -14.7375},
#    {'amonut': 1618,
#     'changeRate': 4.11,
#     'changeVal': 120,
#     'etfTabCode': 2,
#     'itemcode': '139220',
#     'itemname': 'TIGER 200 건설',
#     'marketSum': 1049,
#     'nav': 3036.0,
#     'nowVal': 3040,
#     'quant': 539374,
#     'risefall': '2',
#     'threeMonthEarnRate': 14.5348},
#    {'amonut': 736,
#     'changeRate': 0.98,
#     'changeVal': 125,
#     'etfTabCode': 4,
#     'itemcode': '400570',
#     'itemname': 'KODEX 유럽탄소배출권선물ICE(H)',
#     'marketSum': 1045,
#     'nav': 12890.0,
#     'nowVal': 12900,
#     'quant': 57291,
#     'risefall': '2',
#     'threeMonthEarnRate': -8.6195},
#    {'amonut': 219,
#     'changeRate': -1.04,
#     'changeVal': -100,
#     'etfTabCode': 2,
#     'itemcode': '367760',
#     'itemname': 'KBSTAR Fn5G테크',
#     'marketSum': 1039,
#     'nav': 9486.0,
#     'nowVal': 9490,
#     'quant': 23129,
#     'risefall': '5',
#     'threeMonthEarnRate': 2.2128},
#    {'amonut': 27,
#     'changeRate': 1.18,
#     'changeVal': 90,
#     'etfTabCode': 2,
#     'itemcode': '395170',
#     'itemname': 'KODEX Fn Top10동일가중',
#     'marketSum': 1037,
#     'nav': 7768.0,
#     'nowVal': 7740,
#     'quant': 3585,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.7843},
#    {'amonut': 2,
#     'changeRate': -0.33,
#     'changeVal': -290,
#     'etfTabCode': 6,
#     'itemcode': '363570',
#     'itemname': 'KODEX 장기종합채권(AA-이상)액티브KAP',
#     'marketSum': 1022,
#     'nav': 88245.0,
#     'nowVal': 87980,
#     'quant': 28,
#     'risefall': '5',
#     'threeMonthEarnRate': -4.9379},
#    {'amonut': 0,
#     'changeRate': 0.0,
#     'changeVal': 0,
#     'etfTabCode': 6,
#     'itemcode': '363510',
#     'itemname': 'SOL KIS단기통안채',
#     'marketSum': 1018,
#     'nav': 100864.0,
#     'nowVal': 100850,
#     'quant': 0,
#     'risefall': '3',
#     'threeMonthEarnRate': 0.2086},
#    {'amonut': 530,
#     'changeRate': 0.61,
#     'changeVal': 130,
#     'etfTabCode': 4,
#     'itemcode': '245340',
#     'itemname': 'TIGER 미국다우존스30',
#     'marketSum': 975,
#     'nav': 21228.0,
#     'nowVal': 21380,
#     'quant': 25053,
#     'risefall': '2',
#     'threeMonthEarnRate': 4.7139},
#    {'amonut': 12,
#     'changeRate': 0.22,
#     'changeVal': 115,
#     'etfTabCode': 6,
#     'itemcode': '176950',
#     'itemname': 'KODEX 국채선물10년인버스',
#     'marketSum': 939,
#     'nav': 51235.0,
#     'nowVal': 51285,
#     'quant': 250,
#     'risefall': '2',
#     'threeMonthEarnRate': 3.9934},
#    {'amonut': 12,
#     'changeRate': 1.11,
#     'changeVal': 240,
#     'etfTabCode': 1,
#     'itemcode': '332500',
#     'itemname': 'KINDEX 200TR',
#     'marketSum': 936,
#     'nav': 21815.0,
#     'nowVal': 21765,
#     'quant': 569,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.5085},
#    {'amonut': 102,
#     'changeRate': 1.34,
#     'changeVal': 120,
#     'etfTabCode': 4,
#     'itemcode': '245360',
#     'itemname': 'TIGER 차이나HSCEI',
#     'marketSum': 932,
#     'nav': 9085.0,
#     'nowVal': 9050,
#     'quant': 11312,
#     'risefall': '2',
#     'threeMonthEarnRate': -14.2583},
#    {'amonut': 32,
#     'changeRate': 0.94,
#     'changeVal': 255,
#     'etfTabCode': 1,
#     'itemcode': '277630',
#     'itemname': 'TIGER 코스피',
#     'marketSum': 930,
#     'nav': 27428.0,
#     'nowVal': 27360,
#     'quant': 1192,
#     'risefall': '2',
#     'threeMonthEarnRate': 1.4465},
#    {'amonut': 8560,
#     'changeRate': 1.92,
#     'changeVal': 265,
#     'etfTabCode': 3,
#     'itemcode': '267770',
#     'itemname': 'TIGER 200선물레버리지',
#     'marketSum': 927,
#     'nav': 14078.0,
#     'nowVal': 14045,
#     'quant': 620903,
#     'risefall': '2',
#     'threeMonthEarnRate': -2.0264},
#    {'amonut': 1031,
#     'changeRate': -0.25,
#     'changeVal': -30,
#     'etfTabCode': 4,
#     'itemcode': '283580',
#     'itemname': 'KODEX 차이나CSI300',
#     'marketSum': 914,
#     'nav': 12125.0,
#     'nowVal': 12020,
#     'quant': 85737,
#     'risefall': '5',
#     'threeMonthEarnRate': -14.841},
#    {'amonut': 2094,
#     'changeRate': 0.78,
#     'changeVal': 165,
#     'etfTabCode': 4,
#     'itemcode': '204480',
#     'itemname': 'TIGER 차이나CSI300레버리지(합성)',
#     'marketSum': 911,
#     'nav': 21698.0,
#     'nowVal': 21390,
#     'quant': 97514,
#     'risefall': '2',
#     'threeMonthEarnRate': -29.567},
#    {'amonut': 34,
#     'changeRate': 0.79,
#     'changeVal': 120,
#     'etfTabCode': 2,
#     'itemcode': '322400',
#     'itemname': 'HANARO e커머스',
#     'marketSum': 911,
#     'nav': 15301.0,
#     'nowVal': 15305,
#     'quant': 2263,
#     'risefall': '2',
#     'threeMonthEarnRate': 4.1016},
#    {'amonut': 1602,
#     'changeRate': 0.67,
#     'changeVal': 75,
#     'etfTabCode': 7,
#     'itemcode': '261240',
#     'itemname': 'KODEX 미국달러선물',
#     'marketSum': 899,
#     'nav': 11239.0,
#     'nowVal': 11250,
#     'quant': 142755,
#     'risefall': '2',
#     'threeMonthEarnRate': 5.0775},
#    {'amonut': 442,
#     'changeRate': -0.07,
#     'changeVal': -45,
#     'etfTabCode': 6,
#     'itemcode': '152380',
#     'itemname': 'KODEX 국채선물10년',
#     'marketSum': 898,
#     'nav': 64222.0,
#     'nowVal': 64215,
#     'quant': 6899,
#     'risefall': '5',
#     'threeMonthEarnRate': -3.7736},
#    {'amonut': 7808,
#     'changeRate': 1.79,
#     'changeVal': 125,
#     'etfTabCode': 2,
#     'itemcode': '364970',
#     'itemname': 'TIGER KRX바이오K-뉴딜',
#     'marketSum': 891,
#     'nav': 7099.0,
#     'nowVal': 7100,
#     'quant': 1108901,
#     'risefall': '2',
#     'threeMonthEarnRate': 6.6462},
#    {'amonut': 579,
#     'changeRate': 0.25,
#     'changeVal': 30,
#     'etfTabCode': 6,
#     'itemcode': '305080',
#     'itemname': 'TIGER 미국채10년선물',
#     'marketSum': 864,
#     'nav': 11857.0,
#     'nowVal': 11830,
#     'quant': 49165,
#     'risefall': '2',
#     'threeMonthEarnRate': -1.2139},
#    {'amonut': 2228,
#     'changeRate': 2.61,
#     'changeVal': 85,
#     'etfTabCode': 2,
#     'itemcode': '117700',
#     'itemname': 'KODEX 건설',
#     'marketSum': 850,
#     'nav': 3358.0,
#     'nowVal': 3345,
#     'quant': 673555,
#     'risefall': '2',
#     'threeMonthEarnRate': 12.4573},
#    {'amonut': 779,
#     'changeRate': 0.96,
#     'changeVal': 160,
#     'etfTabCode': 4,
#     'itemcode': '304940',
#     'itemname': 'KODEX 미국나스닥100선물(H)',
#     'marketSum': 847,
#     'nav': 16488.0,
#     'nowVal': 16765,
#     'quant': 46653,
#     'risefall': '2',
#     'threeMonthEarnRate': -5.8941},
#    {'amonut': 13,
#     'changeRate': 1.17,
#     'changeVal': 150,
#     'etfTabCode': 2,
#     'itemcode': '337160',
#     'itemname': 'KODEX 200ESG',
#     'marketSum': 841,
#     'nav': 12936.0,
#     'nowVal': 12940,
#     'quant': 1024,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.1158},
#    {'amonut': 3073,
#     'changeRate': 1.56,
#     'changeVal': 50,
#     'etfTabCode': 2,
#     'itemcode': '139230',
#     'itemname': 'TIGER 200 중공업',
#     'marketSum': 832,
#     'nav': 3253.0,
#     'nowVal': 3255,
#     'quant': 951810,
#     'risefall': '2',
#     'threeMonthEarnRate': 20.1117},
#    {'amonut': 66,
#     'changeRate': 2.15,
#     'changeVal': 215,
#     'etfTabCode': 2,
#     'itemcode': '139280',
#     'itemname': 'TIGER 경기방어',
#     'marketSum': 831,
#     'nav': 10231.0,
#     'nowVal': 10230,
#     'quant': 6570,
#     'risefall': '2',
#     'threeMonthEarnRate': 9.902},
#    {'amonut': 43,
#     'changeRate': -0.02,
#     'changeVal': -25,
#     'etfTabCode': 6,
#     'itemcode': '272560',
#     'itemname': 'KBSTAR 단기국공채액티브',
#     'marketSum': 828,
#     'nav': 102468.0,
#     'nowVal': 102465,
#     'quant': 426,
#     'risefall': '5',
#     'threeMonthEarnRate': 0.0976},
#    {'amonut': 1,
#     'changeRate': 0.72,
#     'changeVal': 105,
#     'etfTabCode': 2,
#     'itemcode': '325010',
#     'itemname': 'KODEX Fn성장',
#     'marketSum': 827,
#     'nav': 14775.0,
#     'nowVal': 14770,
#     'quant': 122,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.7057},
#    {'amonut': 5727,
#     'changeRate': 3.99,
#     'changeVal': 115,
#     'etfTabCode': 2,
#     'itemcode': '228790',
#     'itemname': 'TIGER 화장품',
#     'marketSum': 815,
#     'nav': 2993.0,
#     'nowVal': 2995,
#     'quant': 1926875,
#     'risefall': '2',
#     'threeMonthEarnRate': 19.9584},
#    {'amonut': 1565,
#     'changeRate': -2.29,
#     'changeVal': -110,
#     'etfTabCode': 5,
#     'itemcode': '144600',
#     'itemname': 'KODEX 은선물(H)',
#     'marketSum': 808,
#     'nav': 4728.0,
#     'nowVal': 4700,
#     'quant': 332002,
#     'risefall': '5',
#     'threeMonthEarnRate': 1.5839},
#    {'amonut': 0,
#     'changeRate': 0.46,
#     'changeVal': 55,
#     'etfTabCode': 2,
#     'itemcode': '363580',
#     'itemname': 'KODEX 200IT TR',
#     'marketSum': 808,
#     'nav': 12048.0,
#     'nowVal': 12055,
#     'quant': 36,
#     'risefall': '2',
#     'threeMonthEarnRate': -4.4206},
#    {'amonut': 1,
#     'changeRate': 0.14,
#     'changeVal': 75,
#     'etfTabCode': 6,
#     'itemcode': '397410',
#     'itemname': 'KBSTAR 국채선물5년추종인버스',
#     'marketSum': 807,
#     'nav': 52897.0,
#     'nowVal': 52925,
#     'quant': 24,
#     'risefall': '2',
#     'threeMonthEarnRate': 2.2936},
#    {'amonut': 1334,
#     'changeRate': 0.45,
#     'changeVal': 45,
#     'etfTabCode': 2,
#     'itemcode': '417630',
#     'itemname': 'TIGER KEDI혁신기업ESG30',
#     'marketSum': 771,
#     'nav': 10033.0,
#     'nowVal': 10010,
#     'quant': 133754,
#     'risefall': '2',
#     'threeMonthEarnRate': None},
#    {'amonut': 759,
#     'changeRate': 0.49,
#     'changeVal': 60,
#     'etfTabCode': 2,
#     'itemcode': '157490',
#     'itemname': 'TIGER 소프트웨어',
#     'marketSum': 770,
#     'nav': 12206.0,
#     'nowVal': 12185,
#     'quant': 62555,
#     'risefall': '2',
#     'threeMonthEarnRate': -8.8599},
#    {'amonut': 301,
#     'changeRate': 1.39,
#     'changeVal': 400,
#     'etfTabCode': 4,
#     'itemcode': '225040',
#     'itemname': 'TIGER 미국S&P500레버리지(합성 H)',
#     'marketSum': 770,
#     'nav': 28594.0,
#     'nowVal': 29150,
#     'quant': 10401,
#     'risefall': '2',
#     'threeMonthEarnRate': -6.2908},
#    {'amonut': 1,
#     'changeRate': -0.24,
#     'changeVal': -125,
#     'etfTabCode': 6,
#     'itemcode': '298340',
#     'itemname': 'ARIRANG 국채선물3년',
#     'marketSum': 760,
#     'nav': 52078.0,
#     'nowVal': 52075,
#     'quant': 24,
#     'risefall': '5',
#     'threeMonthEarnRate': -1.0802},
#    {'amonut': 91,
#     'changeRate': 0.9,
#     'changeVal': 115,
#     'etfTabCode': 4,
#     'itemcode': '195930',
#     'itemname': 'TIGER 유로스탁스50(합성 H)',
#     'marketSum': 734,
#     'nav': 12784.0,
#     'nowVal': 12870,
#     'quant': 7212,
#     'risefall': '2',
#     'threeMonthEarnRate': -7.9726},
#    {'amonut': 0,
#     'changeRate': 1.31,
#     'changeVal': 110,
#     'etfTabCode': 1,
#     'itemcode': '411540',
#     'itemname': 'SOL 200 Top10',
#     'marketSum': 733,
#     'nav': 8590.0,
#     'nowVal': 8520,
#     'quant': 13,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.9423},
#    {'amonut': 498,
#     'changeRate': 0.0,
#     'changeVal': 0,
#     'etfTabCode': 4,
#     'itemcode': '195980',
#     'itemname': 'ARIRANG 신흥국MSCI(합성 H)',
#     'marketSum': 723,
#     'nav': 9934.0,
#     'nowVal': 9875,
#     'quant': 50433,
#     'risefall': '3',
#     'threeMonthEarnRate': -12.9956},
#    {'amonut': 470,
#     'changeRate': 0.09,
#     'changeVal': 80,
#     'etfTabCode': 6,
#     'itemcode': '365780',
#     'itemname': 'KINDEX 국고채10년',
#     'marketSum': 714,
#     'nav': 88749.0,
#     'nowVal': 88845,
#     'quant': 5305,
#     'risefall': '2',
#     'threeMonthEarnRate': -3.6368},
#    {'amonut': 1246,
#     'changeRate': 0.64,
#     'changeVal': 55,
#     'etfTabCode': 4,
#     'itemcode': '414270',
#     'itemname': 'KINDEX G2전기차&자율주행액티브',
#     'marketSum': 712,
#     'nav': 8630.0,
#     'nowVal': 8680,
#     'quant': 143912,
#     'risefall': '2',
#     'threeMonthEarnRate': None},
#    {'amonut': 39,
#     'changeRate': 0.59,
#     'changeVal': 105,
#     'etfTabCode': 4,
#     'itemcode': '298770',
#     'itemname': 'KODEX 한국대만IT프리미어',
#     'marketSum': 701,
#     'nav': 17940.0,
#     'nowVal': 17985,
#     'quant': 2217,
#     'risefall': '2',
#     'threeMonthEarnRate': -9.8791},
#    {'amonut': 230,
#     'changeRate': -0.19,
#     'changeVal': -20,
#     'etfTabCode': 2,
#     'itemcode': '385510',
#     'itemname': 'KODEX K-신재생에너지액티브',
#     'marketSum': 690,
#     'nav': 10457.0,
#     'nowVal': 10455,
#     'quant': 22147,
#     'risefall': '5',
#     'threeMonthEarnRate': 11.7428},
#    {'amonut': 272,
#     'changeRate': -0.38,
#     'changeVal': -40,
#     'etfTabCode': 2,
#     'itemcode': '385520',
#     'itemname': 'KODEX K-미래차액티브',
#     'marketSum': 690,
#     'nav': 10451.0,
#     'nowVal': 10450,
#     'quant': 26168,
#     'risefall': '5',
#     'threeMonthEarnRate': 4.743},
#    {'amonut': 73,
#     'changeRate': 1.32,
#     'changeVal': 160,
#     'etfTabCode': 2,
#     'itemcode': '266160',
#     'itemname': 'KBSTAR 고배당',
#     'marketSum': 689,
#     'nav': 12330.0,
#     'nowVal': 12300,
#     'quant': 6033,
#     'risefall': '2',
#     'threeMonthEarnRate': 2.204},
#    {'amonut': 96,
#     'changeRate': 0.33,
#     'changeVal': 30,
#     'etfTabCode': 2,
#     'itemcode': '388280',
#     'itemname': 'KBSTAR Fn컨택트대표',
#     'marketSum': 684,
#     'nav': 9146.0,
#     'nowVal': 9150,
#     'quant': 10585,
#     'risefall': '2',
#     'threeMonthEarnRate': 12.4235},
#    {'amonut': 541,
#     'changeRate': 0.55,
#     'changeVal': 45,
#     'etfTabCode': 4,
#     'itemcode': '419430',
#     'itemname': 'KODEX 차이나2차전지MSCI(합성)',
#     'marketSum': 652,
#     'nav': 8184.0,
#     'nowVal': 8155,
#     'quant': 66330,
#     'risefall': '2',
#     'threeMonthEarnRate': None},
#    {'amonut': 409,
#     'changeRate': 1.16,
#     'changeVal': 215,
#     'etfTabCode': 4,
#     'itemcode': '200250',
#     'itemname': 'KOSEF 인도Nifty50(합성)',
#     'marketSum': 649,
#     'nav': 19043.0,
#     'nowVal': 18815,
#     'quant': 21880,
#     'risefall': '2',
#     'threeMonthEarnRate': 2.1416},
#    {'amonut': 36,
#     'changeRate': 0.55,
#     'changeVal': 100,
#     'etfTabCode': 4,
#     'itemcode': '174360',
#     'itemname': 'KBSTAR 중국본토대형주CSI100',
#     'marketSum': 642,
#     'nav': 18442.0,
#     'nowVal': 18350,
#     'quant': 1969,
#     'risefall': '2',
#     'threeMonthEarnRate': -13.7524},
#    {'amonut': 302,
#     'changeRate': -0.07,
#     'changeVal': -70,
#     'etfTabCode': 6,
#     'itemcode': '114820',
#     'itemname': 'TIGER 국채3년',
#     'marketSum': 641,
#     'nav': 106764.0,
#     'nowVal': 106780,
#     'quant': 2828,
#     'risefall': '5',
#     'threeMonthEarnRate': -1.1756},
#    {'amonut': 235,
#     'changeRate': 0.55,
#     'changeVal': 55,
#     'etfTabCode': 4,
#     'itemcode': '390390',
#     'itemname': 'KODEX 미국반도체MV',
#     'marketSum': 640,
#     'nav': 9870.0,
#     'nowVal': 10080,
#     'quant': 23549,
#     'risefall': '2',
#     'threeMonthEarnRate': -7.2618},
#    {'amonut': 6197,
#     'changeRate': -0.9,
#     'changeVal': -45,
#     'etfTabCode': 3,
#     'itemcode': '123310',
#     'itemname': 'TIGER 인버스',
#     'marketSum': 636,
#     'nav': 4960.0,
#     'nowVal': 4965,
#     'quant': 1240228,
#     'risefall': '5',
#     'threeMonthEarnRate': 0.2},
#    {'amonut': 189,
#     'changeRate': 2.51,
#     'changeVal': 240,
#     'etfTabCode': 4,
#     'itemcode': '391600',
#     'itemname': 'KINDEX 미국친환경그린테마INDXX',
#     'marketSum': 627,
#     'nav': 9671.0,
#     'nowVal': 9790,
#     'quant': 19645,
#     'risefall': '2',
#     'threeMonthEarnRate': 12.6179},
#    {'amonut': 70,
#     'changeRate': -0.92,
#     'changeVal': -95,
#     'etfTabCode': 2,
#     'itemcode': '387280',
#     'itemname': 'TIGER 퓨처모빌리티액티브',
#     'marketSum': 611,
#     'nav': 10231.0,
#     'nowVal': 10200,
#     'quant': 6933,
#     'risefall': '5',
#     'threeMonthEarnRate': 0.8317},
#    {'amonut': 47,
#     'changeRate': 0.04,
#     'changeVal': 20,
#     'etfTabCode': 6,
#     'itemcode': '302190',
#     'itemname': 'TIGER 중장기국채',
#     'marketSum': 608,
#     'nav': 49007.0,
#     'nowVal': 49020,
#     'quant': 980,
#     'risefall': '2',
#     'threeMonthEarnRate': -2.5652},
#    {'amonut': 24,
#     'changeRate': 1.04,
#     'changeVal': 195,
#     'etfTabCode': 1,
#     'itemcode': '310960',
#     'itemname': 'TIGER 200TR',
#     'marketSum': 589,
#     'nav': 19032.0,
#     'nowVal': 18990,
#     'quant': 1278,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.5819},
#    {'amonut': 370,
#     'changeRate': 1.84,
#     'changeVal': 280,
#     'etfTabCode': 4,
#     'itemcode': '099140',
#     'itemname': 'KODEX 차이나H',
#     'marketSum': 574,
#     'nav': 15638.0,
#     'nowVal': 15500,
#     'quant': 24034,
#     'risefall': '2',
#     'threeMonthEarnRate': -14.9959},
#    {'amonut': 154,
#     'changeRate': 1.03,
#     'changeVal': 85,
#     'etfTabCode': 4,
#     'itemcode': '396510',
#     'itemname': 'TIGER 차이나클린에너지SOLACTIVE',
#     'marketSum': 564,
#     'nav': 8410.0,
#     'nowVal': 8350,
#     'quant': 18513,
#     'risefall': '2',
#     'threeMonthEarnRate': -13.6364},
# ...
#     'itemcode': '292340',
#     'itemname': '마이티 200커버드콜ATM레버리지',
#     'marketSum': 56,
#     'nav': 9268.0,
#     'nowVal': 9250,
#     'quant': 285,
#     'risefall': '2',
#     'threeMonthEarnRate': 8.3482},
#    {'amonut': 2,
#     'changeRate': 0.95,
#     'changeVal': 80,
#     'etfTabCode': 2,
#     'itemcode': '376250',
#     'itemname': 'ARIRANG 탄소효율그린뉴딜',
#     'marketSum': 55,
#     'nav': 8532.0,
#     'nowVal': 8535,
#     'quant': 293,
#     'risefall': '2',
#     'threeMonthEarnRate': -1.2681},
#    {'amonut': 0,
#     'changeRate': 1.99,
#     'changeVal': 215,
#     'etfTabCode': 2,
#     'itemcode': '368470',
#     'itemname': 'KINDEX Fn K-뉴딜디지털플러스',
#     'marketSum': 55,
#     'nav': 11006.0,
#     'nowVal': 11000,
#     'quant': 20,
#     'risefall': '2',
#     'threeMonthEarnRate': -2.3519},
#    {'amonut': 1,
#     'changeRate': 1.12,
#     'changeVal': 100,
#     'etfTabCode': 1,
#     'itemcode': '228820',
#     'itemname': 'TIGER KTOP30',
#     'marketSum': 54,
#     'nav': 9098.0,
#     'nowVal': 9055,
#     'quant': 148,
#     'risefall': '2',
#     'threeMonthEarnRate': -2.9428},
#    {'amonut': 64,
#     'changeRate': 2.11,
#     'changeVal': 80,
#     'etfTabCode': 4,
#     'itemcode': '105010',
#     'itemname': 'TIGER 라틴35',
#     'marketSum': 54,
#     'nav': 3863.0,
#     'nowVal': 3870,
#     'quant': 16742,
#     'risefall': '2',
#     'threeMonthEarnRate': 11.3069},
#    {'amonut': 37,
#     'changeRate': 1.1,
#     'changeVal': 55,
#     'etfTabCode': 2,
#     'itemcode': '412560',
#     'itemname': 'TIGER KRX BBIG K-뉴딜레버리지',
#     'marketSum': 53,
#     'nav': 5062.0,
#     'nowVal': 5075,
#     'quant': 7537,
#     'risefall': '2',
#     'threeMonthEarnRate': -15.2028},
#    {'amonut': 0,
#     'changeRate': 0.0,
#     'changeVal': 0,
#     'etfTabCode': 6,
#     'itemcode': '292770',
#     'itemname': 'KODEX 국채선물3년인버스',
#     'marketSum': 52,
#     'nav': 51588.0,
#     'nowVal': 51400,
#     'quant': 0,
#     'risefall': '3',
#     'threeMonthEarnRate': 1.5208},
#    {'amonut': 0,
#     'changeRate': 0.62,
#     'changeVal': 640,
#     'etfTabCode': 6,
#     'itemcode': '299070',
#     'itemname': 'KINDEX 국채선물10년인버스',
#     'marketSum': 52,
#     'nav': 104289.0,
#     'nowVal': 104595,
#     'quant': 6,
#     'risefall': '2',
#     'threeMonthEarnRate': 4.0903},
#    {'amonut': 30,
#     'changeRate': -1.03,
#     'changeVal': -60,
#     'etfTabCode': 3,
#     'itemcode': '252410',
#     'itemname': 'KBSTAR 200선물인버스',
#     'marketSum': 52,
#     'nav': 5750.0,
#     'nowVal': 5760,
#     'quant': 5314,
#     'risefall': '5',
#     'threeMonthEarnRate': 0.0},
#    {'amonut': 0,
#     'changeRate': 0.39,
#     'changeVal': 50,
#     'etfTabCode': 2,
#     'itemcode': '277640',
#     'itemname': 'TIGER 코스피대형주',
#     'marketSum': 52,
#     'nav': 13063.0,
#     'nowVal': 12930,
#     'quant': 17,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.0383},
#    {'amonut': 0,
#     'changeRate': 0.0,
#     'changeVal': 0,
#     'etfTabCode': 6,
#     'itemcode': '299080',
#     'itemname': 'KINDEX 국채선물3년인버스',
#     'marketSum': 52,
#     'nav': 103265.0,
#     'nowVal': 103055,
#     'quant': 0,
#     'risefall': '3',
#     'threeMonthEarnRate': 1.6221},
#    {'amonut': 0,
#     'changeRate': 1.22,
#     'changeVal': 155,
#     'etfTabCode': 2,
#     'itemcode': '333940',
#     'itemname': 'ARIRANG KS로우볼가중TR',
#     'marketSum': 51,
#     'nav': 12859.0,
#     'nowVal': 12855,
#     'quant': 27,
#     'risefall': '2',
#     'threeMonthEarnRate': 1.9261},
#    {'amonut': 1,
#     'changeRate': 0.2,
#     'changeVal': 20,
#     'etfTabCode': 6,
#     'itemcode': '267440',
#     'itemname': 'KBSTAR 미국장기국채선물(H)',
#     'marketSum': 51,
#     'nav': 10188.0,
#     'nowVal': 10265,
#     'quant': 170,
#     'risefall': '2',
#     'threeMonthEarnRate': -9.0546},
#    {'amonut': 699,
#     'changeRate': -1.26,
#     'changeVal': -125,
#     'etfTabCode': 3,
#     'itemcode': '306530',
#     'itemname': 'HANARO 코스닥150선물레버리지',
#     'marketSum': 51,
#     'nav': 9908.0,
#     'nowVal': 9795,
#     'quant': 70763,
#     'risefall': '5',
#     'threeMonthEarnRate': 5.1404},
#    {'amonut': 46,
#     'changeRate': 0.23,
#     'changeVal': 20,
#     'etfTabCode': 3,
#     'itemcode': '291620',
#     'itemname': 'KOSEF 코스닥150선물인버스',
#     'marketSum': 51,
#     'nav': 8543.0,
#     'nowVal': 8575,
#     'quant': 5399,
#     'risefall': '2',
#     'threeMonthEarnRate': -5.8856},
#    {'amonut': 0,
#     'changeRate': 0.66,
#     'changeVal': 55,
#     'etfTabCode': 4,
#     'itemcode': '291890',
#     'itemname': 'KODEX MSCI EM선물(H)',
#     'marketSum': 50,
#     'nav': 8444.0,
#     'nowVal': 8355,
#     'quant': 117,
#     'risefall': '2',
#     'threeMonthEarnRate': -12.2158},
#    {'amonut': 220,
#     'changeRate': 0.93,
#     'changeVal': 115,
#     'etfTabCode': 2,
#     'itemcode': '281990',
#     'itemname': 'KBSTAR 중소형고배당',
#     'marketSum': 50,
#     'nav': 12531.0,
#     'nowVal': 12465,
#     'quant': 17687,
#     'risefall': '2',
#     'threeMonthEarnRate': 11.3257},
#    {'amonut': 2,
#     'changeRate': -0.2,
#     'changeVal': -20,
#     'etfTabCode': 2,
#     'itemcode': '373490',
#     'itemname': 'KODEX K-이노베이션액티브',
#     'marketSum': 50,
#     'nav': 9960.0,
#     'nowVal': 9930,
#     'quant': 289,
#     'risefall': '5',
#     'threeMonthEarnRate': 3.3057},
#    {'amonut': 95,
#     'changeRate': -1.35,
#     'changeVal': -75,
#     'etfTabCode': 3,
#     'itemcode': '145670',
#     'itemname': 'KINDEX 인버스',
#     'marketSum': 49,
#     'nav': 5479.0,
#     'nowVal': 5470,
#     'quant': 17219,
#     'risefall': '5',
#     'threeMonthEarnRate': 0.6352},
#    {'amonut': 3,
#     'changeRate': 0.98,
#     'changeVal': 95,
#     'etfTabCode': 2,
#     'itemcode': '244660',
#     'itemname': 'KODEX 퀄리티Plus',
#     'marketSum': 49,
#     'nav': 9859.0,
#     'nowVal': 9825,
#     'quant': 402,
#     'risefall': '2',
#     'threeMonthEarnRate': 10.3982},
#    {'amonut': 0,
#     'changeRate': 0.8,
#     'changeVal': 65,
#     'etfTabCode': 1,
#     'itemcode': '391680',
#     'itemname': 'HK 하이볼액티브',
#     'marketSum': 49,
#     'nav': 8234.0,
#     'nowVal': 8185,
#     'quant': 4,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.0616},
#    {'amonut': 0,
#     'changeRate': -0.41,
#     'changeVal': -40,
#     'etfTabCode': 7,
#     'itemcode': '321410',
#     'itemname': 'KODEX 멀티에셋하이인컴(H)',
#     'marketSum': 49,
#     'nav': 9807.0,
#     'nowVal': 9820,
#     'quant': 35,
#     'risefall': '5',
#     'threeMonthEarnRate': -8.0653},
#    {'amonut': 71,
#     'changeRate': 0.67,
#     'changeVal': 50,
#     'etfTabCode': 3,
#     'itemcode': '301410',
#     'itemname': 'ARIRANG 코스닥150선물인버스',
#     'marketSum': 48,
#     'nav': 7432.0,
#     'nowVal': 7460,
#     'quant': 9613,
#     'risefall': '2',
#     'threeMonthEarnRate': -6.2026},
#    {'amonut': 1,
#     'changeRate': 1.32,
#     'changeVal': 140,
#     'etfTabCode': 1,
#     'itemcode': '295820',
#     'itemname': 'ARIRANG 200동일가중',
#     'marketSum': 48,
#     'nav': 10725.0,
#     'nowVal': 10730,
#     'quant': 149,
#     'risefall': '2',
#     'threeMonthEarnRate': 11.1225},
#    {'amonut': 3,
#     'changeRate': 0.78,
#     'changeVal': 125,
#     'etfTabCode': 2,
#     'itemcode': '139290',
#     'itemname': 'TIGER 200 경기소비재',
#     'marketSum': 48,
#     'nav': 16110.0,
#     'nowVal': 16055,
#     'quant': 188,
#     'risefall': '2',
#     'threeMonthEarnRate': 2.7584},
#    {'amonut': 63,
#     'changeRate': -0.77,
#     'changeVal': -45,
#     'etfTabCode': 3,
#     'itemcode': '253240',
#     'itemname': 'KOSEF 200선물인버스',
#     'marketSum': 48,
#     'nav': 5774.0,
#     'nowVal': 5780,
#     'quant': 10950,
#     'risefall': '5',
#     'threeMonthEarnRate': -0.0858},
#    {'amonut': 0,
#     'changeRate': 0.73,
#     'changeVal': 85,
#     'etfTabCode': 2,
#     'itemcode': '301440',
#     'itemname': 'ARIRANG 코스피중형주',
#     'marketSum': 47,
#     'nav': 11707.0,
#     'nowVal': 11725,
#     'quant': 20,
#     'risefall': '2',
#     'threeMonthEarnRate': 8.0054},
#    {'amonut': 29,
#     'changeRate': 0.11,
#     'changeVal': 45,
#     'etfTabCode': 6,
#     'itemcode': '346000',
#     'itemname': 'HANARO KAP초장기국고채',
#     'marketSum': 45,
#     'nav': 39447.0,
#     'nowVal': 39555,
#     'quant': 737,
#     'risefall': '2',
#     'threeMonthEarnRate': -7.4448},
#    {'amonut': 58,
#     'changeRate': 0.67,
#     'changeVal': 60,
#     'etfTabCode': 6,
#     'itemcode': '267450',
#     'itemname': 'KBSTAR 미국장기국채선물인버스(H)',
#     'marketSum': 45,
#     'nav': 8980.0,
#     'nowVal': 9000,
#     'quant': 6509,
#     'risefall': '2',
#     'threeMonthEarnRate': 10.1663},
#    {'amonut': 15,
#     'changeRate': 0.59,
#     'changeVal': 25,
#     'etfTabCode': 2,
#     'itemcode': '157500',
#     'itemname': 'TIGER 증권',
#     'marketSum': 45,
#     'nav': 4243.0,
#     'nowVal': 4230,
#     'quant': 3738,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.4485},
#    {'amonut': 98,
#     'changeRate': 3.13,
#     'changeVal': 295,
#     'etfTabCode': 2,
#     'itemcode': '227560',
#     'itemname': 'TIGER 200 생활소비재',
#     'marketSum': 45,
#     'nav': 9766.0,
#     'nowVal': 9730,
#     'quant': 10198,
#     'risefall': '2',
#     'threeMonthEarnRate': 6.6406},
#    {'amonut': 0,
#     'changeRate': 0.09,
#     'changeVal': 45,
#     'etfTabCode': 6,
#     'itemcode': '295020',
#     'itemname': 'KBSTAR 국채선물10년인버스',
#     'marketSum': 45,
#     'nav': 51877.0,
#     'nowVal': 51940,
#     'quant': 8,
#     'risefall': '2',
#     'threeMonthEarnRate': 4.1127},
#    {'amonut': 495,
#     'changeRate': 1.52,
#     'changeVal': 150,
#     'etfTabCode': 2,
#     'itemcode': '285010',
#     'itemname': 'KBSTAR 200중공업',
#     'marketSum': 44,
#     'nav': 10049.0,
#     'nowVal': 10015,
#     'quant': 49695,
#     'risefall': '2',
#     'threeMonthEarnRate': 18.9398},
#    {'amonut': 67,
#     'changeRate': 0.73,
#     'changeVal': 40,
#     'etfTabCode': 4,
#     'itemcode': '371870',
#     'itemname': 'KINDEX 차이나항셍테크',
#     'marketSum': 44,
#     'nav': 5563.0,
#     'nowVal': 5495,
#     'quant': 12175,
#     'risefall': '2',
#     'threeMonthEarnRate': -22.8976},
#    {'amonut': 72,
#     'changeRate': 3.72,
#     'changeVal': 440,
#     'etfTabCode': 2,
#     'itemcode': '287300',
#     'itemname': 'KBSTAR 200건설',
#     'marketSum': 42,
#     'nav': 12325.0,
#     'nowVal': 12265,
#     'quant': 5946,
#     'risefall': '2',
#     'threeMonthEarnRate': 14.1837},
#    {'amonut': 8,
#     'changeRate': 0.44,
#     'changeVal': 20,
#     'etfTabCode': 4,
#     'itemcode': '220130',
#     'itemname': 'SOL 중국본토 중소형 CSI500(합성 H)',
#     'marketSum': 41,
#     'nav': 4579.0,
#     'nowVal': 4585,
#     'quant': 1780,
#     'risefall': '2',
#     'threeMonthEarnRate': -21.9659},
#    {'amonut': 34,
#     'changeRate': 0.74,
#     'changeVal': 50,
#     'etfTabCode': 5,
#     'itemcode': '280940',
#     'itemname': 'KODEX 골드선물인버스(H)',
#     'marketSum': 41,
#     'nav': 6861.0,
#     'nowVal': 6800,
#     'quant': 5020,
#     'risefall': '2',
#     'threeMonthEarnRate': -5.4622},
#    {'amonut': 0,
#     'changeRate': 1.11,
#     'changeVal': 125,
#     'etfTabCode': 2,
#     'itemcode': '266550',
#     'itemname': 'ARIRANG 중형주저변동50',
#     'marketSum': 40,
#     'nav': 11365.0,
#     'nowVal': 11395,
#     'quant': 48,
#     'risefall': '2',
#     'threeMonthEarnRate': 13.0223},
#    {'amonut': 21,
#     'changeRate': 1.0,
#     'changeVal': 75,
#     'etfTabCode': 6,
#     'itemcode': '267500',
#     'itemname': 'KBSTAR 미국장기국채선물인버스2X(합성 H)',
#     'marketSum': 38,
#     'nav': 7592.0,
#     'nowVal': 7575,
#     'quant': 2869,
#     'risefall': '2',
#     'threeMonthEarnRate': 20.5787},
#    {'amonut': 0,
#     'changeRate': 1.18,
#     'changeVal': 175,
#     'etfTabCode': 2,
#     'itemcode': '252730',
#     'itemname': 'KBSTAR 모멘텀로우볼',
#     'marketSum': 38,
#     'nav': 15052.0,
#     'nowVal': 15025,
#     'quant': 5,
#     'risefall': '2',
#     'threeMonthEarnRate': 1.2024},
#    {'amonut': 2,
#     'changeRate': 1.34,
#     'changeVal': 120,
#     'etfTabCode': 2,
#     'itemcode': '280920',
#     'itemname': 'ARIRANG 주도업종',
#     'marketSum': 36,
#     'nav': 9102.0,
#     'nowVal': 9105,
#     'quant': 255,
#     'risefall': '2',
#     'threeMonthEarnRate': -3.3158},
#    {'amonut': 0,
#     'changeRate': 0.65,
#     'changeVal': 95,
#     'etfTabCode': 2,
#     'itemcode': '315480',
#     'itemname': 'KBSTAR 200커뮤니케이션서비스',
#     'marketSum': 35,
#     'nav': 14798.0,
#     'nowVal': 14775,
#     'quant': 47,
#     'risefall': '2',
#     'threeMonthEarnRate': -2.4215},
#    {'amonut': 0,
#     'changeRate': 0.5,
#     'changeVal': 70,
#     'etfTabCode': 2,
#     'itemcode': '333980',
#     'itemname': 'ARIRANG KS퀄리티가중TR',
#     'marketSum': 35,
#     'nav': 14192.0,
#     'nowVal': 14165,
#     'quant': 27,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.4632},
#    {'amonut': 81,
#     'changeRate': 0.2,
#     'changeVal': 10,
#     'etfTabCode': 3,
#     'itemcode': '275750',
#     'itemname': 'KBSTAR 코스닥150선물인버스',
#     'marketSum': 35,
#     'nav': 4946.0,
#     'nowVal': 4965,
#     'quant': 16336,
#     'risefall': '2',
#     'threeMonthEarnRate': -6.2441},
#    {'amonut': 1,
#     'changeRate': 1.84,
#     'changeVal': 165,
#     'etfTabCode': 2,
#     'itemcode': '278420',
#     'itemname': 'ARIRANG ESG우수기업',
#     'marketSum': 32,
#     'nav': 9117.0,
#     'nowVal': 9120,
#     'quant': 187,
#     'risefall': '2',
#     'threeMonthEarnRate': 8.5764},
#    {'amonut': 4,
#     'changeRate': -1.51,
#     'changeVal': -65,
#     'etfTabCode': 5,
#     'itemcode': '334700',
#     'itemname': 'KBSTAR 팔라듐선물인버스(H)',
#     'marketSum': 30,
#     'nav': 4208.0,
#     'nowVal': 4240,
#     'quant': 1035,
#     'risefall': '5',
#     'threeMonthEarnRate': -5.9017},
#    {'amonut': 4,
#     'changeRate': -1.27,
#     'changeVal': -125,
#     'etfTabCode': 6,
#     'itemcode': '267490',
#     'itemname': 'KBSTAR 미국장기국채선물레버리지(합성 H)',
#     'marketSum': 29,
#     'nav': 9758.0,
#     'nowVal': 9740,
#     'quant': 442,
#     'risefall': '5',
#     'threeMonthEarnRate': -18.4374},
#    {'amonut': 81,
#     'changeRate': 1.59,
#     'changeVal': 150,
#     'etfTabCode': 2,
#     'itemcode': '285020',
#     'itemname': 'KBSTAR 200철강소재',
#     'marketSum': 29,
#     'nav': 9610.0,
#     'nowVal': 9605,
#     'quant': 8491,
#     'risefall': '2',
#     'threeMonthEarnRate': 22.9746},
#    {'amonut': 44,
#     'changeRate': 2.87,
#     'changeVal': 260,
#     'etfTabCode': 2,
#     'itemcode': '309210',
#     'itemname': 'ARIRANG KRX300헬스케어',
#     'marketSum': 28,
#     'nav': 9368.0,
#     'nowVal': 9315,
#     'quant': 4853,
#     'risefall': '2',
#     'threeMonthEarnRate': 4.2602},
#    {'amonut': 1,
#     'changeRate': -0.16,
#     'changeVal': -20,
#     'etfTabCode': 1,
#     'itemcode': '301400',
#     'itemname': 'ARIRANG 코스닥150',
#     'marketSum': 25,
#     'nav': 12381.0,
#     'nowVal': 12320,
#     'quant': 115,
#     'risefall': '5',
#     'threeMonthEarnRate': 2.4813},
#    {'amonut': 0,
#     'changeRate': 2.18,
#     'changeVal': 495,
#     'etfTabCode': 2,
#     'itemcode': '217790',
#     'itemname': 'TIGER 가격조정',
#     'marketSum': 23,
#     'nav': 23179.0,
#     'nowVal': 23180,
#     'quant': 11,
#     'risefall': '2',
#     'threeMonthEarnRate': 6.0647},
#    {'amonut': 0,
#     'changeRate': 1.39,
#     'changeVal': 190,
#     'etfTabCode': 2,
#     'itemcode': '252720',
#     'itemname': 'KBSTAR 모멘텀밸류',
#     'marketSum': 21,
#     'nav': 13865.0,
#     'nowVal': 13825,
#     'quant': 6,
#     'risefall': '2',
#     'threeMonthEarnRate': 1.1506},
#    {'amonut': 1,
#     'changeRate': -0.02,
#     'changeVal': -10,
#     'etfTabCode': 6,
#     'itemcode': '295000',
#     'itemname': 'KBSTAR 국채선물10년',
#     'marketSum': 20,
#     'nav': 51181.0,
#     'nowVal': 51165,
#     'quant': 39,
#     'risefall': '5',
#     'threeMonthEarnRate': -3.7159},
#    {'amonut': 3,
#     'changeRate': 3.57,
#     'changeVal': 255,
#     'etfTabCode': 2,
#     'itemcode': '287330',
#     'itemname': 'KBSTAR 200생활소비재',
#     'marketSum': 18,
#     'nav': 7392.0,
#     'nowVal': 7395,
#     'quant': 485,
#     'risefall': '2',
#     'threeMonthEarnRate': 6.9597},
#    {'amonut': 3,
#     'changeRate': 2.66,
#     'changeVal': 290,
#     'etfTabCode': 2,
#     'itemcode': '284990',
#     'itemname': 'KBSTAR 200에너지화학',
#     'marketSum': 16,
#     'nav': 11214.0,
#     'nowVal': 11195,
#     'quant': 316,
#     'risefall': '2',
#     'threeMonthEarnRate': 1.1791},
#    {'amonut': 3,
#     'changeRate': 1.0,
#     'changeVal': 100,
#     'etfTabCode': 2,
#     'itemcode': '287310',
#     'itemname': 'KBSTAR 200경기소비재',
#     'marketSum': 10,
#     'nav': 10079.0,
#     'nowVal': 10060,
#     'quant': 380,
#     'risefall': '2',
#     'threeMonthEarnRate': 2.7763},
#    {'amonut': 0,
#     'changeRate': 2.08,
#     'changeVal': 240,
#     'etfTabCode': 2,
#     'itemcode': '287320',
#     'itemname': 'KBSTAR 200산업재',
#     'marketSum': 7,
#     'nav': 11784.0,
#     'nowVal': 11760,
#     'quant': 37,
#     'risefall': '2',
#     'threeMonthEarnRate': 18.425}]},
#  'resultCode': 'success'}

# %% [markdown]
# ### JSON 타입으로 데이터 받기

# %%
# requests 의 응답을 json 타입으로 받습니다.
etf_json = response.json()
etf_json
# Out:
# {'result': {'etfItemList': [{'amonut': 145311,
#     'changeRate': 1.0,
#     'changeVal': 345,
#     'etfTabCode': 1,
#     'itemcode': '069500',
#     'itemname': 'KODEX 200',
#     'marketSum': 47195,
#     'nav': 35084.0,
#     'nowVal': 34985,
#     'quant': 4180043,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.4674},
#    {'amonut': 107221,
#     'changeRate': 0.81,
#     'changeVal': 95,
#     'etfTabCode': 4,
#     'itemcode': '371460',
#     'itemname': 'TIGER 차이나전기차SOLACTIVE',
#     'marketSum': 29425,
#     'nav': 11894.0,
#     'nowVal': 11890,
#     'quant': 8956866,
#     'risefall': '2',
#     'threeMonthEarnRate': -25.5132},
#    {'amonut': 309205,
#     'changeRate': 1.98,
#     'changeVal': 360,
#     'etfTabCode': 3,
#     'itemcode': '122630',
#     'itemname': 'KODEX 레버리지',
#     'marketSum': 21122,
#     'nav': 18679.0,
#     'nowVal': 18585,
#     'quant': 16856345,
#     'risefall': '2',
#     'threeMonthEarnRate': -2.6183},
#    {'amonut': 8789,
#     'changeRate': 1.35,
#     'changeVal': 1000,
#     'etfTabCode': 4,
#     'itemcode': '133690',
#     'itemname': 'TIGER 미국나스닥100',
#     'marketSum': 20964,
#     'nav': 74008.0,
#     'nowVal': 75220,
#     'quant': 117485,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.9795},
#    {'amonut': 380833,
#     'changeRate': -1.85,
#     'changeVal': -50,
#     'etfTabCode': 3,
#     'itemcode': '252670',
#     'itemname': 'KODEX 200선물인버스2X',
#     'marketSum': 19202,
#     'nav': 2646.0,
#     'nowVal': 2650,
#     'quant': 141997440,
#     'risefall': '5',
#     'threeMonthEarnRate': -1.099},
#    {'amonut': 54652,
#     'changeRate': 0.95,
#     'changeVal': 330,
#     'etfTabCode': 1,
#     'itemcode': '102110',
#     'itemname': 'TIGER 200',
#     'marketSum': 18126,
#     'nav': 35137.0,
#     'nowVal': 35060,
#     'quant': 1568552,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.3681},
#    {'amonut': 98417,
#     'changeRate': 0.01,
#     'changeVal': 15,
#     'etfTabCode': 6,
#     'itemcode': '157450',
#     'itemname': 'TIGER 단기통안채',
#     'marketSum': 18098,
#     'nav': 100796.0,
#     'nowVal': 100790,
#     'quant': 976423,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.2187},
#    {'amonut': 13082,
#     'changeRate': 0.02,
#     'changeVal': 25,
#     'etfTabCode': 6,
#     'itemcode': '214980',
#     'itemname': 'KODEX 단기채권PLUS',
#     'marketSum': 17960,
#     'nav': 103846.0,
#     'nowVal': 103840,
#     'quant': 125979,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.2946},
#    {'amonut': 8935,
#     'changeRate': 1.16,
#     'changeVal': 155,
#     'etfTabCode': 4,
#     'itemcode': '360750',
#     'itemname': 'TIGER 미국S&P500',
#     'marketSum': 16097,
#     'nav': 13364.0,
#     'nowVal': 13510,
#     'quant': 665897,
#     'risefall': '2',
#     'threeMonthEarnRate': 3.3166},
#    {'amonut': 2669,
#     'changeRate': 1.88,
#     'changeVal': 165,
#     'etfTabCode': 2,
#     'itemcode': '102780',
#     'itemname': 'KODEX 삼성그룹',
#     'marketSum': 15276,
#     'nav': 8988.0,
#     'nowVal': 8965,
#     'quant': 299740,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.7315},
#    {'amonut': 280122,
#     'changeRate': 0.01,
#     'changeVal': 15,
#     'etfTabCode': 6,
#     'itemcode': '153130',
#     'itemname': 'KODEX 단기채권',
#     'marketSum': 14787,
#     'nav': 103372.0,
#     'nowVal': 103375,
#     'quant': 2709886,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.1987},
#    {'amonut': 555,
#     'changeRate': 0.02,
#     'changeVal': 25,
#     'etfTabCode': 6,
#     'itemcode': '273130',
#     'itemname': 'KODEX 종합채권(AA-이상)액티브',
#     'marketSum': 14344,
#     'nav': 103600.0,
#     'nowVal': 103640,
#     'quant': 5364,
#     'risefall': '2',
#     'threeMonthEarnRate': -2.8913},
#    {'amonut': 12383,
#     'changeRate': 1.58,
#     'changeVal': 175,
#     'etfTabCode': 4,
#     'itemcode': '381170',
#     'itemname': 'TIGER 미국테크TOP10 INDXX',
#     'marketSum': 13529,
#     'nav': 11011.0,
#     'nowVal': 11260,
#     'quant': 1106429,
#     'risefall': '2',
#     'threeMonthEarnRate': -2.1193},
#    {'amonut': 36922,
#     'changeRate': -0.13,
#     'changeVal': -25,
#     'etfTabCode': 2,
#     'itemcode': '305720',
#     'itemname': 'KODEX 2차전지산업',
#     'marketSum': 13323,
#     'nav': 19704.0,
#     'nowVal': 19650,
#     'quant': 1884877,
#     'risefall': '5',
#     'threeMonthEarnRate': 6.6144},
#    {'amonut': 32832,
#     'changeRate': -0.35,
#     'changeVal': -70,
#     'etfTabCode': 2,
#     'itemcode': '305540',
#     'itemname': 'TIGER 2차전지테마',
#     'marketSum': 13054,
#     'nav': 20174.0,
#     'nowVal': 20145,
#     'quant': 1633729,
#     'risefall': '5',
#     'threeMonthEarnRate': 7.1807},
#    {'amonut': 6840,
#     'changeRate': 1.56,
#     'changeVal': 155,
#     'etfTabCode': 4,
#     'itemcode': '381180',
#     'itemname': 'TIGER 미국필라델피아반도체나스닥',
#     'marketSum': 13024,
#     'nav': 9892.0,
#     'nowVal': 10065,
#     'quant': 683975,
#     'risefall': '2',
#     'threeMonthEarnRate': -8.013},
#    {'amonut': 4,
#     'changeRate': 1.25,
#     'changeVal': 175,
#     'etfTabCode': 1,
#     'itemcode': '310970',
#     'itemname': 'TIGER MSCI Korea TR',
#     'marketSum': 12800,
#     'nav': 14206.0,
#     'nowVal': 14175,
#     'quant': 309,
#     'risefall': '2',
#     'threeMonthEarnRate': -2.0294},
#    {'amonut': 3288,
#     'changeRate': 1.28,
#     'changeVal': 145,
#     'etfTabCode': 2,
#     'itemcode': '292150',
#     'itemname': 'TIGER TOP10',
#     'marketSum': 11777,
#     'nav': 11448.0,
#     'nowVal': 11445,
#     'quant': 289181,
#     'risefall': '2',
#     'threeMonthEarnRate': -4.3115},
#    {'amonut': 342,
#     'changeRate': 0.95,
#     'changeVal': 110,
#     'etfTabCode': 1,
#     'itemcode': '278530',
#     'itemname': 'KODEX 200TR',
#     'marketSum': 11109,
#     'nav': 11684.0,
#     'nowVal': 11645,
#     'quant': 29578,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.3026},
#    {'amonut': 3487,
#     'changeRate': 1.12,
#     'changeVal': 125,
#     'etfTabCode': 1,
#     'itemcode': '278540',
#     'itemname': 'KODEX MSCI Korea TR',
#     'marketSum': 10489,
#     'nav': 11311.0,
#     'nowVal': 11315,
#     'quant': 310150,
#     'risefall': '2',
#     'threeMonthEarnRate': -1.9282},
#    {'amonut': 6979,
#     'changeRate': 1.1,
#     'changeVal': 385,
#     'etfTabCode': 1,
#     'itemcode': '148020',
#     'itemname': 'KBSTAR 200',
#     'marketSum': 9882,
#     'nav': 35303.0,
#     'nowVal': 35230,
#     'quant': 199121,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.3105},
#    {'amonut': 84067,
#     'changeRate': -0.37,
#     'changeVal': -40,
#     'etfTabCode': 3,
#     'itemcode': '233740',
#     'itemname': 'KODEX 코스닥150레버리지',
#     'marketSum': 8903,
#     'nav': 10844.0,
#     'nowVal': 10675,
#     'quant': 7883654,
#     'risefall': '5',
#     'threeMonthEarnRate': 2.5358},
#    {'amonut': 135717,
#     'changeRate': -1.11,
#     'changeVal': -50,
#     'etfTabCode': 3,
#     'itemcode': '114800',
#     'itemname': 'KODEX 인버스',
#     'marketSum': 8358,
#     'nav': 4460.0,
#     'nowVal': 4460,
#     'quant': 30231835,
#     'risefall': '5',
#     'threeMonthEarnRate': 0.1109},
#    {'amonut': 7598,
#     'changeRate': 0.3,
#     'changeVal': 95,
#     'etfTabCode': 2,
#     'itemcode': '139260',
#     'itemname': 'TIGER 200 IT',
#     'marketSum': 8316,
#     'nav': 31709.0,
#     'nowVal': 31620,
#     'quant': 240838,
#     'risefall': '2',
#     'threeMonthEarnRate': -4.2608},
#    {'amonut': 8716,
#     'changeRate': 1.05,
#     'changeVal': 195,
#     'etfTabCode': 2,
#     'itemcode': '091180',
#     'itemname': 'KODEX 자동차',
#     'marketSum': 7321,
#     'nav': 18862.0,
#     'nowVal': 18845,
#     'quant': 465039,
#     'risefall': '2',
#     'threeMonthEarnRate': 1.7116},
#    {'amonut': 127,
#     'changeRate': 1.08,
#     'changeVal': 375,
#     'etfTabCode': 1,
#     'itemcode': '293180',
#     'itemname': 'HANARO 200',
#     'marketSum': 6633,
#     'nav': 35162.0,
#     'nowVal': 35095,
#     'quant': 3645,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.551},
#    {'amonut': 4883,
#     'changeRate': 1.11,
#     'changeVal': 385,
#     'etfTabCode': 1,
#     'itemcode': '105190',
#     'itemname': 'KINDEX 200',
#     'marketSum': 6578,
#     'nav': 35175.0,
#     'nowVal': 35085,
#     'quant': 139493,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.7852},
#    {'amonut': 24167,
#     'changeRate': 0.99,
#     'changeVal': 350,
#     'etfTabCode': 1,
#     'itemcode': '152100',
#     'itemname': 'ARIRANG 200',
#     'marketSum': 6363,
#     'nav': 35618.0,
#     'nowVal': 35545,
#     'quant': 681283,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.1114},
#    {'amonut': 1393,
#     'changeRate': 0.98,
#     'changeVal': 90,
#     'etfTabCode': 4,
#     'itemcode': '394670',
#     'itemname': 'TIGER 글로벌리튬&2차전지SOLACTIVE(합성)',
#     'marketSum': 6294,
#     'nav': 9278.0,
#     'nowVal': 9250,
#     'quant': 150402,
#     'risefall': '2',
#     'threeMonthEarnRate': -10.7648},
#    {'amonut': 253,
#     'changeRate': 1.31,
#     'changeVal': 220,
#     'etfTabCode': 2,
#     'itemcode': '315930',
#     'itemname': 'KODEX Top5PlusTR',
#     'marketSum': 6060,
#     'nav': 17070.0,
#     'nowVal': 17070,
#     'quant': 15013,
#     'risefall': '2',
#     'threeMonthEarnRate': -3.7693},
#    {'amonut': 2452,
#     'changeRate': 1.26,
#     'changeVal': 170,
#     'etfTabCode': 4,
#     'itemcode': '360200',
#     'itemname': 'KINDEX 미국S&P500',
#     'marketSum': 5736,
#     'nav': 13472.0,
#     'nowVal': 13625,
#     'quant': 181609,
#     'risefall': '2',
#     'threeMonthEarnRate': 3.3703},
#    {'amonut': 48443,
#     'changeRate': -0.12,
#     'changeVal': -15,
#     'etfTabCode': 1,
#     'itemcode': '229200',
#     'itemname': 'KODEX 코스닥150',
#     'marketSum': 5661,
#     'nav': 12378.0,
#     'nowVal': 12175,
#     'quant': 3982817,
#     'risefall': '5',
#     'threeMonthEarnRate': 1.9966},
#    {'amonut': 6844,
#     'changeRate': 0.02,
#     'changeVal': 20,
#     'etfTabCode': 6,
#     'itemcode': '196230',
#     'itemname': 'KBSTAR 단기통안채',
#     'marketSum': 5585,
#     'nav': 105104.0,
#     'nowVal': 105100,
#     'quant': 65125,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.205},
#    {'amonut': 205,
#     'changeRate': 1.06,
#     'changeVal': 445,
#     'etfTabCode': 1,
#     'itemcode': '294400',
#     'itemname': 'KOSEF 200TR',
#     'marketSum': 5361,
#     'nav': 42461.0,
#     'nowVal': 42380,
#     'quant': 4872,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.2854},
#    {'amonut': 78,
#     'changeRate': 0.02,
#     'changeVal': 20,
#     'etfTabCode': 6,
#     'itemcode': '190620',
#     'itemname': 'KINDEX 단기통안채',
#     'marketSum': 4570,
#     'nav': 100428.0,
#     'nowVal': 100430,
#     'quant': 778,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.2496},
#    {'amonut': 15792,
#     'changeRate': 1.61,
#     'changeVal': 225,
#     'etfTabCode': 2,
#     'itemcode': '364980',
#     'itemname': 'TIGER KRX2차전지K-뉴딜',
#     'marketSum': 4501,
#     'nav': 14214.0,
#     'nowVal': 14200,
#     'quant': 1121933,
#     'risefall': '2',
#     'threeMonthEarnRate': -3.7432},
#    {'amonut': 1088,
#     'changeRate': 0.56,
#     'changeVal': 115,
#     'etfTabCode': 4,
#     'itemcode': '251350',
#     'itemname': 'KODEX 선진국MSCI World',
#     'marketSum': 4483,
#     'nav': 20394.0,
#     'nowVal': 20565,
#     'quant': 53113,
#     'risefall': '2',
#     'threeMonthEarnRate': 2.5319},
#    {'amonut': 118486,
#     'changeRate': 0.32,
#     'changeVal': 15,
#     'etfTabCode': 3,
#     'itemcode': '251340',
#     'itemname': 'KODEX 코스닥150선물인버스',
#     'marketSum': 4286,
#     'nav': 4712.0,
#     'nowVal': 4725,
#     'quant': 25084202,
#     'risefall': '2',
#     'threeMonthEarnRate': -5.8},
#    {'amonut': 3456,
#     'changeRate': 1.28,
#     'changeVal': 150,
#     'etfTabCode': 4,
#     'itemcode': '379800',
#     'itemname': 'KODEX 미국S&P500TR',
#     'marketSum': 4163,
#     'nav': 11785.0,
#     'nowVal': 11910,
#     'quant': 292341,
#     'risefall': '2',
#     'threeMonthEarnRate': 3.2938},
#    {'amonut': 21967,
#     'changeRate': 1.1,
#     'changeVal': 380,
#     'etfTabCode': 1,
#     'itemcode': '069660',
#     'itemname': 'KOSEF 200',
#     'marketSum': 4020,
#     'nav': 35020.0,
#     'nowVal': 34960,
#     'quant': 630416,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.6509},
#    {'amonut': 1614,
#     'changeRate': 2.02,
#     'changeVal': 420,
#     'etfTabCode': 4,
#     'itemcode': '314250',
#     'itemname': 'KODEX 미국FANG플러스(H)',
#     'marketSum': 3979,
#     'nav': 20670.0,
#     'nowVal': 21255,
#     'quant': 76107,
#     'risefall': '2',
#     'threeMonthEarnRate': -16.7433},
#    {'amonut': 2538,
#     'changeRate': 1.33,
#     'changeVal': 170,
#     'etfTabCode': 4,
#     'itemcode': '367380',
#     'itemname': 'KINDEX 미국나스닥100',
#     'marketSum': 3976,
#     'nav': 12709.0,
#     'nowVal': 12910,
#     'quant': 198484,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.8936},
#    {'amonut': 1,
#     'changeRate': 0.01,
#     'changeVal': 5,
#     'etfTabCode': 6,
#     'itemcode': '385540',
#     'itemname': 'KBSTAR KIS종합채권(A-이상)액티브',
#     'marketSum': 3843,
#     'nav': 95587.0,
#     'nowVal': 95620,
#     'quant': 19,
#     'risefall': '2',
#     'threeMonthEarnRate': -2.7908},
#    {'amonut': 7868,
#     'changeRate': -2.49,
#     'changeVal': -245,
#     'etfTabCode': 2,
#     'itemcode': '400970',
#     'itemname': 'TIGER Fn메타버스',
#     'marketSum': 3825,
#     'nav': 9624.0,
#     'nowVal': 9610,
#     'quant': 814803,
#     'risefall': '5',
#     'threeMonthEarnRate': 0.8682},
#    {'amonut': 7613,
#     'changeRate': -1.15,
#     'changeVal': -110,
#     'etfTabCode': 2,
#     'itemcode': '401470',
#     'itemname': 'KODEX K-메타버스액티브',
#     'marketSum': 3811,
#     'nav': 9487.0,
#     'nowVal': 9480,
#     'quant': 801733,
#     'risefall': '5',
#     'threeMonthEarnRate': -4.5252},
#    {'amonut': 2680,
#     'changeRate': 0.02,
#     'changeVal': 25,
#     'etfTabCode': 6,
#     'itemcode': '148070',
#     'itemname': 'KOSEF 국고채10년',
#     'marketSum': 3400,
#     'nav': 111704.0,
#     'nowVal': 111830,
#     'quant': 23976,
#     'risefall': '2',
#     'threeMonthEarnRate': -3.716},
#    {'amonut': 150,
#     'changeRate': 0.04,
#     'changeVal': 20,
#     'etfTabCode': 6,
#     'itemcode': '272580',
#     'itemname': 'TIGER 단기채권액티브',
#     'marketSum': 3382,
#     'nav': 50478.0,
#     'nowVal': 50485,
#     'quant': 2980,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.308},
#    {'amonut': 2756,
#     'changeRate': 1.37,
#     'changeVal': 150,
#     'etfTabCode': 4,
#     'itemcode': '379810',
#     'itemname': 'KODEX 미국나스닥100TR',
#     'marketSum': 3336,
#     'nav': 10897.0,
#     'nowVal': 11065,
#     'quant': 250746,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.9529},
#    {'amonut': 3833,
#     'changeRate': 1.08,
#     'changeVal': 60,
#     'etfTabCode': 4,
#     'itemcode': '371160',
#     'itemname': 'TIGER 차이나항셍테크',
#     'marketSum': 3301,
#     'nav': 5641.0,
#     'nowVal': 5600,
#     'quant': 684234,
#     'risefall': '2',
#     'threeMonthEarnRate': -22.6257},
#    {'amonut': 2014,
#     'changeRate': 0.7,
#     'changeVal': 75,
#     'etfTabCode': 6,
#     'itemcode': '329750',
#     'itemname': 'TIGER 미국달러단기채권액티브',
#     'marketSum': 3190,
#     'nav': 10843.0,
#     'nowVal': 10850,
#     'quant': 186027,
#     'risefall': '2',
#     'threeMonthEarnRate': 4.8151},
#    {'amonut': 628,
#     'changeRate': 1.01,
#     'changeVal': 270,
#     'etfTabCode': 1,
#     'itemcode': '226490',
#     'itemname': 'KODEX 코스피',
#     'marketSum': 3154,
#     'nav': 26978.0,
#     'nowVal': 26960,
#     'quant': 23467,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.9683},
#    {'amonut': 48848,
#     'changeRate': 0.03,
#     'changeVal': 30,
#     'etfTabCode': 6,
#     'itemcode': '385550',
#     'itemname': 'KBSTAR KIS단기종합채권(AA-이상)액티브',
#     'marketSum': 3136,
#     'nav': 100816.0,
#     'nowVal': 100830,
#     'quant': 484524,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.3734},
#    {'amonut': 1307,
#     'changeRate': 0.67,
#     'changeVal': 330,
#     'etfTabCode': 4,
#     'itemcode': '143850',
#     'itemname': 'TIGER 미국S&P500선물(H)',
#     'marketSum': 3117,
#     'nav': 49689.0,
#     'nowVal': 49670,
#     'quant': 26368,
#     'risefall': '2',
#     'threeMonthEarnRate': -1.723},
#    {'amonut': 663,
#     'changeRate': 1.47,
#     'changeVal': 145,
#     'etfTabCode': 2,
#     'itemcode': '367770',
#     'itemname': 'KBSTAR Fn수소경제테마',
#     'marketSum': 2929,
#     'nav': 10000.0,
#     'nowVal': 9995,
#     'quant': 67288,
#     'risefall': '2',
#     'threeMonthEarnRate': 2.9215},
#    {'amonut': 0,
#     'changeRate': 0.82,
#     'changeVal': 115,
#     'etfTabCode': 1,
#     'itemcode': '332940',
#     'itemname': 'HANARO MSCI Korea TR',
#     'marketSum': 2844,
#     'nav': 14195.0,
#     'nowVal': 14150,
#     'quant': 51,
#     'risefall': '2',
#     'threeMonthEarnRate': -1.6124},
#    {'amonut': 289,
#     'changeRate': 1.42,
#     'changeVal': 165,
#     'etfTabCode': 2,
#     'itemcode': '290130',
#     'itemname': 'KBSTAR ESG사회책임투자',
#     'marketSum': 2844,
#     'nav': 11776.0,
#     'nowVal': 11775,
#     'quant': 24858,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.3387},
#    {'amonut': 2559,
#     'changeRate': 0.76,
#     'changeVal': 65,
#     'etfTabCode': 2,
#     'itemcode': '364960',
#     'itemname': 'TIGER KRX BBIG K-뉴딜',
#     'marketSum': 2695,
#     'nav': 8571.0,
#     'nowVal': 8570,
#     'quant': 300961,
#     'risefall': '2',
#     'threeMonthEarnRate': -7.4498},
#    {'amonut': 8545,
#     'changeRate': -0.93,
#     'changeVal': -60,
#     'etfTabCode': 2,
#     'itemcode': '329200',
#     'itemname': 'TIGER 리츠부동산인프라',
#     'marketSum': 2569,
#     'nav': 6386.0,
#     'nowVal': 6390,
#     'quant': 1337718,
#     'risefall': '5',
#     'threeMonthEarnRate': 13.8648},
#    {'amonut': 17,
#     'changeRate': 1.67,
#     'changeVal': 145,
#     'etfTabCode': 2,
#     'itemcode': '213610',
#     'itemname': 'KODEX 삼성그룹밸류',
#     'marketSum': 2493,
#     'nav': 8844.0,
#     'nowVal': 8840,
#     'quant': 1954,
#     'risefall': '2',
#     'threeMonthEarnRate': 5.3222},
#    {'amonut': 5544,
#     'changeRate': -0.78,
#     'changeVal': -275,
#     'etfTabCode': 2,
#     'itemcode': '091160',
#     'itemname': 'KODEX 반도체',
#     'marketSum': 2489,
#     'nav': 35114.0,
#     'nowVal': 35055,
#     'quant': 157860,
#     'risefall': '5',
#     'threeMonthEarnRate': 2.3275},
#    {'amonut': 1,
#     'changeRate': 0.05,
#     'changeVal': 25,
#     'etfTabCode': 7,
#     'itemcode': '357870',
#     'itemname': 'TIGER CD금리투자KIS(합성)',
#     'marketSum': 2471,
#     'nav': 50788.0,
#     'nowVal': 50805,
#     'quant': 26,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.3458},
#    {'amonut': 10808,
#     'changeRate': 2.61,
#     'changeVal': 195,
#     'etfTabCode': 2,
#     'itemcode': '091170',
#     'itemname': 'KODEX 은행',
#     'marketSum': 2400,
#     'nav': 7636.0,
#     'nowVal': 7680,
#     'quant': 1438903,
#     'risefall': '2',
#     'threeMonthEarnRate': 4.8032},
#    {'amonut': 362,
#     'changeRate': 1.38,
#     'changeVal': 135,
#     'etfTabCode': 4,
#     'itemcode': '394660',
#     'itemname': 'TIGER 글로벌자율주행&전기차SOLACTIVE',
#     'marketSum': 2398,
#     'nav': 9806.0,
#     'nowVal': 9910,
#     'quant': 36731,
#     'risefall': '2',
#     'threeMonthEarnRate': -7.3021},
#    {'amonut': 6840,
#     'changeRate': 1.72,
#     'changeVal': 215,
#     'etfTabCode': 2,
#     'itemcode': '325020',
#     'itemname': 'KODEX 배당가치',
#     'marketSum': 2350,
#     'nav': 12705.0,
#     'nowVal': 12705,
#     'quant': 541965,
#     'risefall': '2',
#     'threeMonthEarnRate': 3.2477},
#    {'amonut': 3127,
#     'changeRate': 0.0,
#     'changeVal': 0,
#     'etfTabCode': 2,
#     'itemcode': '228800',
#     'itemname': 'TIGER 여행레저',
#     'marketSum': 2311,
#     'nav': 4893.0,
#     'nowVal': 4885,
#     'quant': 642084,
#     'risefall': '3',
#     'threeMonthEarnRate': 16.7064},
#    {'amonut': 384,
#     'changeRate': -0.5,
#     'changeVal': -35,
#     'etfTabCode': 4,
#     'itemcode': '414780',
#     'itemname': 'TIGER 차이나과창판STAR50(합성)',
#     'marketSum': 2268,
#     'nav': 7070.0,
#     'nowVal': 6935,
#     'quant': 55487,
#     'risefall': '5',
#     'threeMonthEarnRate': -26.438},
#    {'amonut': 0,
#     'changeRate': 1.39,
#     'changeVal': 115,
#     'etfTabCode': 1,
#     'itemcode': '407310',
#     'itemname': 'HANARO 200 TOP10',
#     'marketSum': 2210,
#     'nav': 8400.0,
#     'nowVal': 8370,
#     'quant': 57,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.1794},
#    {'amonut': 461,
#     'changeRate': 4.03,
#     'changeVal': 880,
#     'etfTabCode': 4,
#     'itemcode': '245710',
#     'itemname': 'KINDEX 베트남VN30(합성)',
#     'marketSum': 2112,
#     'nav': 22595.0,
#     'nowVal': 22715,
#     'quant': 20559,
#     'risefall': '2',
#     'threeMonthEarnRate': -5.8837},
#    {'amonut': 274,
#     'changeRate': 1.38,
#     'changeVal': 170,
#     'etfTabCode': 4,
#     'itemcode': '368590',
#     'itemname': 'KBSTAR 미국나스닥100',
#     'marketSum': 2105,
#     'nav': 12332.0,
#     'nowVal': 12530,
#     'quant': 22081,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.9604},
#    {'amonut': 606,
#     'changeRate': -0.25,
#     'changeVal': -40,
#     'etfTabCode': 7,
#     'itemcode': '182480',
#     'itemname': 'TIGER 미국MSCI리츠(합성 H)',
#     'marketSum': 2013,
#     'nav': 15601.0,
#     'nowVal': 15785,
#     'quant': 38499,
#     'risefall': '5',
#     'threeMonthEarnRate': 6.2333},
#    {'amonut': 96,
#     'changeRate': 1.13,
#     'changeVal': 135,
#     'etfTabCode': 1,
#     'itemcode': '295040',
#     'itemname': 'SOL 200TR',
#     'marketSum': 2001,
#     'nav': 12157.0,
#     'nowVal': 12130,
#     'quant': 7980,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.3738},
#    {'amonut': 7,
#     'changeRate': 0.01,
#     'changeVal': 10,
#     'etfTabCode': 7,
#     'itemcode': '423160',
#     'itemname': 'KODEX KOFR금리액티브(합성)',
#     'marketSum': 2000,
#     'nav': 100008.0,
#     'nowVal': 100020,
#     'quant': 72,
#     'risefall': '2',
#     'threeMonthEarnRate': None},
#    {'amonut': 2830,
#     'changeRate': -0.83,
#     'changeVal': -105,
#     'etfTabCode': 2,
#     'itemcode': '161510',
#     'itemname': 'ARIRANG 고배당주',
#     'marketSum': 1977,
#     'nav': 12551.0,
#     'nowVal': 12530,
#     'quant': 228260,
#     'risefall': '5',
#     'threeMonthEarnRate': 9.9958},
#    {'amonut': 0,
#     'changeRate': 0.0,
#     'changeVal': 0,
#     'etfTabCode': 6,
#     'itemcode': '390950',
#     'itemname': 'HANARO 단기채권액티브',
#     'marketSum': 1976,
#     'nav': 100621.0,
#     'nowVal': 100595,
#     'quant': 0,
#     'risefall': '3',
#     'threeMonthEarnRate': 0.2141},
#    {'amonut': 646,
#     'changeRate': -1.41,
#     'changeVal': -125,
#     'etfTabCode': 2,
#     'itemcode': '401170',
#     'itemname': 'KBSTAR iSelect메타버스',
#     'marketSum': 1966,
#     'nav': 8745.0,
#     'nowVal': 8745,
#     'quant': 73795,
#     'risefall': '5',
#     'threeMonthEarnRate': -5.5733},
#    {'amonut': 1609,
#     'changeRate': -1.33,
#     'changeVal': -170,
#     'etfTabCode': 5,
#     'itemcode': '132030',
#     'itemname': 'KODEX 골드선물(H)',
#     'marketSum': 1896,
#     'nav': 12684.0,
#     'nowVal': 12640,
#     'quant': 127111,
#     'risefall': '5',
#     'threeMonthEarnRate': 4.7852},
#    {'amonut': 1149,
#     'changeRate': 0.47,
#     'changeVal': 35,
#     'etfTabCode': 4,
#     'itemcode': '412770',
#     'itemname': 'TIGER 글로벌메타버스액티브',
#     'marketSum': 1889,
#     'nav': 7475.0,
#     'nowVal': 7530,
#     'quant': 153504,
#     'risefall': '2',
#     'threeMonthEarnRate': -11.0914},
#    {'amonut': 380,
#     'changeRate': 1.39,
#     'changeVal': 215,
#     'etfTabCode': 4,
#     'itemcode': '275980',
#     'itemname': 'TIGER 글로벌4차산업혁신기술(합성 H)',
#     'marketSum': 1822,
#     'nav': 15463.0,
#     'nowVal': 15730,
#     'quant': 24439,
#     'risefall': '2',
#     'threeMonthEarnRate': -6.7048},
#    {'amonut': 135,
#     'changeRate': -0.05,
#     'changeVal': -10,
#     'etfTabCode': 2,
#     'itemcode': '326240',
#     'itemname': 'KBSTAR IT플러스',
#     'marketSum': 1719,
#     'nav': 18203.0,
#     'nowVal': 18205,
#     'quant': 7471,
#     'risefall': '5',
#     'threeMonthEarnRate': -3.5292},
#    {'amonut': 895,
#     'changeRate': -0.42,
#     'changeVal': -110,
#     'etfTabCode': 4,
#     'itemcode': '168580',
#     'itemname': 'KINDEX 중국본토CSI300',
#     'marketSum': 1709,
#     'nav': 26573.0,
#     'nowVal': 26285,
#     'quant': 34203,
#     'risefall': '5',
#     'threeMonthEarnRate': -15.2649},
#    {'amonut': 467,
#     'changeRate': 0.61,
#     'changeVal': 60,
#     'etfTabCode': 4,
#     'itemcode': '192090',
#     'itemname': 'TIGER 차이나CSI300',
#     'marketSum': 1673,
#     'nav': 9887.0,
#     'nowVal': 9900,
#     'quant': 47302,
#     'risefall': '2',
#     'threeMonthEarnRate': -14.3604},
#    {'amonut': 41,
#     'changeRate': -0.07,
#     'changeVal': -5,
#     'etfTabCode': 4,
#     'itemcode': '415340',
#     'itemname': 'KODEX 차이나과창판STAR50(합성)',
#     'marketSum': 1645,
#     'nav': 7163.0,
#     'nowVal': 7000,
#     'quant': 5977,
#     'risefall': '5',
#     'threeMonthEarnRate': -27.0693},
#    {'amonut': 305,
#     'changeRate': 1.33,
#     'changeVal': 155,
#     'etfTabCode': 4,
#     'itemcode': '379780',
#     'itemname': 'KBSTAR 미국S&P500',
#     'marketSum': 1640,
#     'nav': 11651.0,
#     'nowVal': 11795,
#     'quant': 26104,
#     'risefall': '2',
#     'threeMonthEarnRate': 3.3215},
#    {'amonut': 2848,
#     'changeRate': 1.09,
#     'changeVal': 35,
#     'etfTabCode': 5,
#     'itemcode': '217770',
#     'itemname': 'TIGER 원유선물인버스(H)',
#     'marketSum': 1611,
#     'nav': 3259.0,
#     'nowVal': 3255,
#     'quant': 873807,
#     'risefall': '2',
#     'threeMonthEarnRate': -27.3958},
#    {'amonut': 13,
#     'changeRate': 1.08,
#     'changeVal': 290,
#     'etfTabCode': 1,
#     'itemcode': '302450',
#     'itemname': 'KBSTAR 코스피',
#     'marketSum': 1591,
#     'nav': 27186.0,
#     'nowVal': 27190,
#     'quant': 506,
#     'risefall': '2',
#     'threeMonthEarnRate': 1.116},
#    {'amonut': 438,
#     'changeRate': 0.18,
#     'changeVal': 20,
#     'etfTabCode': 7,
#     'itemcode': '329650',
#     'itemname': 'KODEX TRF3070',
#     'marketSum': 1535,
#     'nav': 10980.0,
#     'nowVal': 11040,
#     'quant': 39790,
#     'risefall': '2',
#     'threeMonthEarnRate': -1.6511},
#    {'amonut': 157,
#     'changeRate': 0.02,
#     'changeVal': 20,
#     'etfTabCode': 6,
#     'itemcode': '130730',
#     'itemname': 'KOSEF 단기자금',
#     'marketSum': 1533,
#     'nav': 101312.0,
#     'nowVal': 101305,
#     'quant': 1550,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.3219},
#    {'amonut': 439,
#     'changeRate': 1.28,
#     'changeVal': 385,
#     'etfTabCode': 2,
#     'itemcode': '143860',
#     'itemname': 'TIGER 헬스케어',
#     'marketSum': 1524,
#     'nav': 30774.0,
#     'nowVal': 30480,
#     'quant': 14443,
#     'risefall': '2',
#     'threeMonthEarnRate': 4.3508},
#    {'amonut': 1391,
#     'changeRate': -0.82,
#     'changeVal': -70,
#     'etfTabCode': 2,
#     'itemcode': '228810',
#     'itemname': 'TIGER 미디어컨텐츠',
#     'marketSum': 1443,
#     'nav': 8539.0,
#     'nowVal': 8515,
#     'quant': 162868,
#     'risefall': '5',
#     'threeMonthEarnRate': 13.4387},
#    {'amonut': 477,
#     'changeRate': 1.55,
#     'changeVal': 355,
#     'etfTabCode': 2,
#     'itemcode': '138540',
#     'itemname': 'TIGER 현대차그룹+펀더멘털',
#     'marketSum': 1437,
#     'nav': 23414.0,
#     'nowVal': 23330,
#     'quant': 20534,
#     'risefall': '2',
#     'threeMonthEarnRate': 4.4439},
#    {'amonut': 1877,
#     'changeRate': -1.3,
#     'changeVal': -475,
#     'etfTabCode': 2,
#     'itemcode': '091230',
#     'itemname': 'TIGER 반도체',
#     'marketSum': 1418,
#     'nav': 35973.0,
#     'nowVal': 36000,
#     'quant': 52148,
#     'risefall': '5',
#     'threeMonthEarnRate': 3.0048},
#    {'amonut': 607,
#     'changeRate': 0.69,
#     'changeVal': 140,
#     'etfTabCode': 4,
#     'itemcode': '219480',
#     'itemname': 'KODEX 미국S&P500선물(H)',
#     'marketSum': 1359,
#     'nav': 20440.0,
#     'nowVal': 20435,
#     'quant': 29827,
#     'risefall': '2',
#     'threeMonthEarnRate': -1.8618},
#    {'amonut': 6479,
#     'changeRate': 1.3,
#     'changeVal': 60,
#     'etfTabCode': 5,
#     'itemcode': '271050',
#     'itemname': 'KODEX WTI원유선물인버스(H)',
#     'marketSum': 1345,
#     'nav': 4658.0,
#     'nowVal': 4670,
#     'quant': 1387680,
#     'risefall': '2',
#     'threeMonthEarnRate': -27.3444},
#    {'amonut': 1506,
#     'changeRate': 1.53,
#     'changeVal': 85,
#     'etfTabCode': 4,
#     'itemcode': '372330',
#     'itemname': 'KODEX 차이나항셍테크',
#     'marketSum': 1324,
#     'nav': 5652.0,
#     'nowVal': 5645,
#     'quant': 267739,
#     'risefall': '2',
#     'threeMonthEarnRate': -22.3464},
#    {'amonut': 24,
#     'changeRate': 1.83,
#     'changeVal': 140,
#     'etfTabCode': 2,
#     'itemcode': '150460',
#     'itemname': 'TIGER 중국소비테마',
#     'marketSum': 1300,
#     'nav': 7829.0,
#     'nowVal': 7795,
#     'quant': 3112,
#     'risefall': '2',
#     'threeMonthEarnRate': 12.7192},
#    {'amonut': 27,
#     'changeRate': -0.04,
#     'changeVal': -5,
#     'etfTabCode': 1,
#     'itemcode': '270810',
#     'itemname': 'KBSTAR 코스닥150',
#     'marketSum': 1297,
#     'nav': 12348.0,
#     'nowVal': 12190,
#     'quant': 2241,
#     'risefall': '5',
#     'threeMonthEarnRate': 2.1702},
#    {'amonut': 443,
#     'changeRate': 1.21,
#     'changeVal': 90,
#     'etfTabCode': 4,
#     'itemcode': '411420',
#     'itemname': 'KODEX 미국메타버스나스닥액티브',
#     'marketSum': 1275,
#     'nav': 7334.0,
#     'nowVal': 7500,
#     'quant': 59447,
#     'risefall': '2',
#     'threeMonthEarnRate': -8.1216},
#    {'amonut': 4,
#     'changeRate': 1.0,
#     'changeVal': 420,
#     'etfTabCode': 1,
#     'itemcode': '332930',
#     'itemname': 'HANARO 200TR',
#     'marketSum': 1271,
#     'nav': 42517.0,
#     'nowVal': 42375,
#     'quant': 107,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.4391},
#    {'amonut': 6697,
#     'changeRate': 1.7,
#     'changeVal': 105,
#     'etfTabCode': 4,
#     'itemcode': '409820',
#     'itemname': 'KODEX 미국나스닥100레버리지(합성 H)',
#     'marketSum': 1269,
#     'nav': 6076.0,
#     'nowVal': 6280,
#     'quant': 1075244,
#     'risefall': '2',
#     'threeMonthEarnRate': -14.2362},
#    {'amonut': 1390,
#     'changeRate': -0.04,
#     'changeVal': -5,
#     'etfTabCode': 1,
#     'itemcode': '232080',
#     'itemname': 'TIGER 코스닥150',
#     'marketSum': 1261,
#     'nav': 12666.0,
#     'nowVal': 12485,
#     'quant': 111504,
#     'risefall': '5',
#     'threeMonthEarnRate': 2.0408},
#    {'amonut': 634,
#     'changeRate': 1.46,
#     'changeVal': 260,
#     'etfTabCode': 4,
#     'itemcode': '309230',
#     'itemname': 'KINDEX 미국WideMoat가치주',
#     'marketSum': 1231,
#     'nav': 17888.0,
#     'nowVal': 18100,
#     'quant': 35177,
#     'risefall': '2',
#     'threeMonthEarnRate': 2.8835},
#    {'amonut': 2014,
#     'changeRate': -1.27,
#     'changeVal': -215,
#     'etfTabCode': 5,
#     'itemcode': '261220',
#     'itemname': 'KODEX WTI원유선물(H)',
#     'marketSum': 1203,
#     'nav': 16724.0,
#     'nowVal': 16710,
#     'quant': 120663,
#     'risefall': '5',
#     'threeMonthEarnRate': 24.7696},
#    {'amonut': 4784,
#     'changeRate': 2.47,
#     'changeVal': 240,
#     'etfTabCode': 4,
#     'itemcode': '423920',
#     'itemname': 'TIGER 미국필라델피아반도체레버리지(합성)',
#     'marketSum': 1182,
#     'nav': 9655.0,
#     'nowVal': 9940,
#     'quant': 487110,
#     'risefall': '2',
#     'threeMonthEarnRate': None},
#    {'amonut': 74,
#     'changeRate': -0.23,
#     'changeVal': -130,
#     'etfTabCode': 6,
#     'itemcode': '114260',
#     'itemname': 'KODEX 국고채3년',
#     'marketSum': 1182,
#     'nav': 56425.0,
#     'nowVal': 56375,
#     'quant': 1315,
#     'risefall': '5',
#     'threeMonthEarnRate': -1.2064},
#    {'amonut': 116,
#     'changeRate': -0.52,
#     'changeVal': -60,
#     'etfTabCode': 3,
#     'itemcode': '278240',
#     'itemname': 'KBSTAR 코스닥150선물레버리지',
#     'marketSum': 1161,
#     'nav': 11501.0,
#     'nowVal': 11440,
#     'quant': 10291,
#     'risefall': '5',
#     'threeMonthEarnRate': 5.553},
#    {'amonut': 30790,
#     'changeRate': -2.12,
#     'changeVal': -60,
#     'etfTabCode': 3,
#     'itemcode': '252710',
#     'itemname': 'TIGER 200선물인버스2X',
#     'marketSum': 1147,
#     'nav': 2764.0,
#     'nowVal': 2770,
#     'quant': 10968539,
#     'risefall': '5',
#     'threeMonthEarnRate': -0.5273},
#    {'amonut': 48,
#     'changeRate': 0.02,
#     'changeVal': 25,
#     'etfTabCode': 6,
#     'itemcode': '273140',
#     'itemname': 'KODEX 단기변동금리부채권액티브',
#     'marketSum': 1146,
#     'nav': 103463.0,
#     'nowVal': 103460,
#     'quant': 467,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.3687},
#    {'amonut': 636,
#     'changeRate': 1.03,
#     'changeVal': 140,
#     'etfTabCode': 1,
#     'itemcode': '328370',
#     'itemname': 'ARIRANG 코스피TR',
#     'marketSum': 1128,
#     'nav': 13749.0,
#     'nowVal': 13750,
#     'quant': 46513,
#     'risefall': '2',
#     'threeMonthEarnRate': 1.4914},
#    {'amonut': 4,
#     'changeRate': 0.17,
#     'changeVal': 175,
#     'etfTabCode': 3,
#     'itemcode': '282000',
#     'itemname': 'KBSTAR 국고채3년선물인버스',
#     'marketSum': 1125,
#     'nav': 103390.0,
#     'nowVal': 103405,
#     'quant': 48,
#     'risefall': '2',
#     'threeMonthEarnRate': 1.5144},
#    {'amonut': 2207,
#     'changeRate': 1.72,
#     'changeVal': 145,
#     'etfTabCode': 2,
#     'itemcode': '395750',
#     'itemname': 'ARIRANG ESG가치주액티브',
#     'marketSum': 1079,
#     'nav': 8569.0,
#     'nowVal': 8595,
#     'quant': 259423,
#     'risefall': '2',
#     'threeMonthEarnRate': 1.1196},
#    {'amonut': 470,
#     'changeRate': 0.4,
#     'changeVal': 315,
#     'etfTabCode': 6,
#     'itemcode': '385560',
#     'itemname': 'KBSTAR KIS국고채30년Enhanced',
#     'marketSum': 1052,
#     'nav': 79007.0,
#     'nowVal': 79130,
#     'quant': 5971,
#     'risefall': '2',
#     'threeMonthEarnRate': -14.7375},
#    {'amonut': 1618,
#     'changeRate': 4.11,
#     'changeVal': 120,
#     'etfTabCode': 2,
#     'itemcode': '139220',
#     'itemname': 'TIGER 200 건설',
#     'marketSum': 1049,
#     'nav': 3036.0,
#     'nowVal': 3040,
#     'quant': 539374,
#     'risefall': '2',
#     'threeMonthEarnRate': 14.5348},
#    {'amonut': 736,
#     'changeRate': 0.98,
#     'changeVal': 125,
#     'etfTabCode': 4,
#     'itemcode': '400570',
#     'itemname': 'KODEX 유럽탄소배출권선물ICE(H)',
#     'marketSum': 1045,
#     'nav': 12890.0,
#     'nowVal': 12900,
#     'quant': 57291,
#     'risefall': '2',
#     'threeMonthEarnRate': -8.6195},
#    {'amonut': 219,
#     'changeRate': -1.04,
#     'changeVal': -100,
#     'etfTabCode': 2,
#     'itemcode': '367760',
#     'itemname': 'KBSTAR Fn5G테크',
#     'marketSum': 1039,
#     'nav': 9486.0,
#     'nowVal': 9490,
#     'quant': 23129,
#     'risefall': '5',
#     'threeMonthEarnRate': 2.2128},
#    {'amonut': 27,
#     'changeRate': 1.18,
#     'changeVal': 90,
#     'etfTabCode': 2,
#     'itemcode': '395170',
#     'itemname': 'KODEX Fn Top10동일가중',
#     'marketSum': 1037,
#     'nav': 7768.0,
#     'nowVal': 7740,
#     'quant': 3585,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.7843},
#    {'amonut': 2,
#     'changeRate': -0.33,
#     'changeVal': -290,
#     'etfTabCode': 6,
#     'itemcode': '363570',
#     'itemname': 'KODEX 장기종합채권(AA-이상)액티브KAP',
#     'marketSum': 1022,
#     'nav': 88245.0,
#     'nowVal': 87980,
#     'quant': 28,
#     'risefall': '5',
#     'threeMonthEarnRate': -4.9379},
#    {'amonut': 0,
#     'changeRate': 0.0,
#     'changeVal': 0,
#     'etfTabCode': 6,
#     'itemcode': '363510',
#     'itemname': 'SOL KIS단기통안채',
#     'marketSum': 1018,
#     'nav': 100864.0,
#     'nowVal': 100850,
#     'quant': 0,
#     'risefall': '3',
#     'threeMonthEarnRate': 0.2086},
#    {'amonut': 530,
#     'changeRate': 0.61,
#     'changeVal': 130,
#     'etfTabCode': 4,
#     'itemcode': '245340',
#     'itemname': 'TIGER 미국다우존스30',
#     'marketSum': 975,
#     'nav': 21228.0,
#     'nowVal': 21380,
#     'quant': 25053,
#     'risefall': '2',
#     'threeMonthEarnRate': 4.7139},
#    {'amonut': 12,
#     'changeRate': 0.22,
#     'changeVal': 115,
#     'etfTabCode': 6,
#     'itemcode': '176950',
#     'itemname': 'KODEX 국채선물10년인버스',
#     'marketSum': 939,
#     'nav': 51235.0,
#     'nowVal': 51285,
#     'quant': 250,
#     'risefall': '2',
#     'threeMonthEarnRate': 3.9934},
#    {'amonut': 12,
#     'changeRate': 1.11,
#     'changeVal': 240,
#     'etfTabCode': 1,
#     'itemcode': '332500',
#     'itemname': 'KINDEX 200TR',
#     'marketSum': 936,
#     'nav': 21815.0,
#     'nowVal': 21765,
#     'quant': 569,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.5085},
#    {'amonut': 102,
#     'changeRate': 1.34,
#     'changeVal': 120,
#     'etfTabCode': 4,
#     'itemcode': '245360',
#     'itemname': 'TIGER 차이나HSCEI',
#     'marketSum': 932,
#     'nav': 9085.0,
#     'nowVal': 9050,
#     'quant': 11312,
#     'risefall': '2',
#     'threeMonthEarnRate': -14.2583},
#    {'amonut': 32,
#     'changeRate': 0.94,
#     'changeVal': 255,
#     'etfTabCode': 1,
#     'itemcode': '277630',
#     'itemname': 'TIGER 코스피',
#     'marketSum': 930,
#     'nav': 27428.0,
#     'nowVal': 27360,
#     'quant': 1192,
#     'risefall': '2',
#     'threeMonthEarnRate': 1.4465},
#    {'amonut': 8560,
#     'changeRate': 1.92,
#     'changeVal': 265,
#     'etfTabCode': 3,
#     'itemcode': '267770',
#     'itemname': 'TIGER 200선물레버리지',
#     'marketSum': 927,
#     'nav': 14078.0,
#     'nowVal': 14045,
#     'quant': 620903,
#     'risefall': '2',
#     'threeMonthEarnRate': -2.0264},
#    {'amonut': 1031,
#     'changeRate': -0.25,
#     'changeVal': -30,
#     'etfTabCode': 4,
#     'itemcode': '283580',
#     'itemname': 'KODEX 차이나CSI300',
#     'marketSum': 914,
#     'nav': 12125.0,
#     'nowVal': 12020,
#     'quant': 85737,
#     'risefall': '5',
#     'threeMonthEarnRate': -14.841},
#    {'amonut': 2094,
#     'changeRate': 0.78,
#     'changeVal': 165,
#     'etfTabCode': 4,
#     'itemcode': '204480',
#     'itemname': 'TIGER 차이나CSI300레버리지(합성)',
#     'marketSum': 911,
#     'nav': 21698.0,
#     'nowVal': 21390,
#     'quant': 97514,
#     'risefall': '2',
#     'threeMonthEarnRate': -29.567},
#    {'amonut': 34,
#     'changeRate': 0.79,
#     'changeVal': 120,
#     'etfTabCode': 2,
#     'itemcode': '322400',
#     'itemname': 'HANARO e커머스',
#     'marketSum': 911,
#     'nav': 15301.0,
#     'nowVal': 15305,
#     'quant': 2263,
#     'risefall': '2',
#     'threeMonthEarnRate': 4.1016},
#    {'amonut': 1602,
#     'changeRate': 0.67,
#     'changeVal': 75,
#     'etfTabCode': 7,
#     'itemcode': '261240',
#     'itemname': 'KODEX 미국달러선물',
#     'marketSum': 899,
#     'nav': 11239.0,
#     'nowVal': 11250,
#     'quant': 142755,
#     'risefall': '2',
#     'threeMonthEarnRate': 5.0775},
#    {'amonut': 442,
#     'changeRate': -0.07,
#     'changeVal': -45,
#     'etfTabCode': 6,
#     'itemcode': '152380',
#     'itemname': 'KODEX 국채선물10년',
#     'marketSum': 898,
#     'nav': 64222.0,
#     'nowVal': 64215,
#     'quant': 6899,
#     'risefall': '5',
#     'threeMonthEarnRate': -3.7736},
#    {'amonut': 7808,
#     'changeRate': 1.79,
#     'changeVal': 125,
#     'etfTabCode': 2,
#     'itemcode': '364970',
#     'itemname': 'TIGER KRX바이오K-뉴딜',
#     'marketSum': 891,
#     'nav': 7099.0,
#     'nowVal': 7100,
#     'quant': 1108901,
#     'risefall': '2',
#     'threeMonthEarnRate': 6.6462},
#    {'amonut': 579,
#     'changeRate': 0.25,
#     'changeVal': 30,
#     'etfTabCode': 6,
#     'itemcode': '305080',
#     'itemname': 'TIGER 미국채10년선물',
#     'marketSum': 864,
#     'nav': 11857.0,
#     'nowVal': 11830,
#     'quant': 49165,
#     'risefall': '2',
#     'threeMonthEarnRate': -1.2139},
#    {'amonut': 2228,
#     'changeRate': 2.61,
#     'changeVal': 85,
#     'etfTabCode': 2,
#     'itemcode': '117700',
#     'itemname': 'KODEX 건설',
#     'marketSum': 850,
#     'nav': 3358.0,
#     'nowVal': 3345,
#     'quant': 673555,
#     'risefall': '2',
#     'threeMonthEarnRate': 12.4573},
#    {'amonut': 779,
#     'changeRate': 0.96,
#     'changeVal': 160,
#     'etfTabCode': 4,
#     'itemcode': '304940',
#     'itemname': 'KODEX 미국나스닥100선물(H)',
#     'marketSum': 847,
#     'nav': 16488.0,
#     'nowVal': 16765,
#     'quant': 46653,
#     'risefall': '2',
#     'threeMonthEarnRate': -5.8941},
#    {'amonut': 13,
#     'changeRate': 1.17,
#     'changeVal': 150,
#     'etfTabCode': 2,
#     'itemcode': '337160',
#     'itemname': 'KODEX 200ESG',
#     'marketSum': 841,
#     'nav': 12936.0,
#     'nowVal': 12940,
#     'quant': 1024,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.1158},
#    {'amonut': 3073,
#     'changeRate': 1.56,
#     'changeVal': 50,
#     'etfTabCode': 2,
#     'itemcode': '139230',
#     'itemname': 'TIGER 200 중공업',
#     'marketSum': 832,
#     'nav': 3253.0,
#     'nowVal': 3255,
#     'quant': 951810,
#     'risefall': '2',
#     'threeMonthEarnRate': 20.1117},
#    {'amonut': 66,
#     'changeRate': 2.15,
#     'changeVal': 215,
#     'etfTabCode': 2,
#     'itemcode': '139280',
#     'itemname': 'TIGER 경기방어',
#     'marketSum': 831,
#     'nav': 10231.0,
#     'nowVal': 10230,
#     'quant': 6570,
#     'risefall': '2',
#     'threeMonthEarnRate': 9.902},
#    {'amonut': 43,
#     'changeRate': -0.02,
#     'changeVal': -25,
#     'etfTabCode': 6,
#     'itemcode': '272560',
#     'itemname': 'KBSTAR 단기국공채액티브',
#     'marketSum': 828,
#     'nav': 102468.0,
#     'nowVal': 102465,
#     'quant': 426,
#     'risefall': '5',
#     'threeMonthEarnRate': 0.0976},
#    {'amonut': 1,
#     'changeRate': 0.72,
#     'changeVal': 105,
#     'etfTabCode': 2,
#     'itemcode': '325010',
#     'itemname': 'KODEX Fn성장',
#     'marketSum': 827,
#     'nav': 14775.0,
#     'nowVal': 14770,
#     'quant': 122,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.7057},
#    {'amonut': 5727,
#     'changeRate': 3.99,
#     'changeVal': 115,
#     'etfTabCode': 2,
#     'itemcode': '228790',
#     'itemname': 'TIGER 화장품',
#     'marketSum': 815,
#     'nav': 2993.0,
#     'nowVal': 2995,
#     'quant': 1926875,
#     'risefall': '2',
#     'threeMonthEarnRate': 19.9584},
#    {'amonut': 1565,
#     'changeRate': -2.29,
#     'changeVal': -110,
#     'etfTabCode': 5,
#     'itemcode': '144600',
#     'itemname': 'KODEX 은선물(H)',
#     'marketSum': 808,
#     'nav': 4728.0,
#     'nowVal': 4700,
#     'quant': 332002,
#     'risefall': '5',
#     'threeMonthEarnRate': 1.5839},
#    {'amonut': 0,
#     'changeRate': 0.46,
#     'changeVal': 55,
#     'etfTabCode': 2,
#     'itemcode': '363580',
#     'itemname': 'KODEX 200IT TR',
#     'marketSum': 808,
#     'nav': 12048.0,
#     'nowVal': 12055,
#     'quant': 36,
#     'risefall': '2',
#     'threeMonthEarnRate': -4.4206},
#    {'amonut': 1,
#     'changeRate': 0.14,
#     'changeVal': 75,
#     'etfTabCode': 6,
#     'itemcode': '397410',
#     'itemname': 'KBSTAR 국채선물5년추종인버스',
#     'marketSum': 807,
#     'nav': 52897.0,
#     'nowVal': 52925,
#     'quant': 24,
#     'risefall': '2',
#     'threeMonthEarnRate': 2.2936},
#    {'amonut': 1334,
#     'changeRate': 0.45,
#     'changeVal': 45,
#     'etfTabCode': 2,
#     'itemcode': '417630',
#     'itemname': 'TIGER KEDI혁신기업ESG30',
#     'marketSum': 771,
#     'nav': 10033.0,
#     'nowVal': 10010,
#     'quant': 133754,
#     'risefall': '2',
#     'threeMonthEarnRate': None},
#    {'amonut': 759,
#     'changeRate': 0.49,
#     'changeVal': 60,
#     'etfTabCode': 2,
#     'itemcode': '157490',
#     'itemname': 'TIGER 소프트웨어',
#     'marketSum': 770,
#     'nav': 12206.0,
#     'nowVal': 12185,
#     'quant': 62555,
#     'risefall': '2',
#     'threeMonthEarnRate': -8.8599},
#    {'amonut': 301,
#     'changeRate': 1.39,
#     'changeVal': 400,
#     'etfTabCode': 4,
#     'itemcode': '225040',
#     'itemname': 'TIGER 미국S&P500레버리지(합성 H)',
#     'marketSum': 770,
#     'nav': 28594.0,
#     'nowVal': 29150,
#     'quant': 10401,
#     'risefall': '2',
#     'threeMonthEarnRate': -6.2908},
#    {'amonut': 1,
#     'changeRate': -0.24,
#     'changeVal': -125,
#     'etfTabCode': 6,
#     'itemcode': '298340',
#     'itemname': 'ARIRANG 국채선물3년',
#     'marketSum': 760,
#     'nav': 52078.0,
#     'nowVal': 52075,
#     'quant': 24,
#     'risefall': '5',
#     'threeMonthEarnRate': -1.0802},
#    {'amonut': 91,
#     'changeRate': 0.9,
#     'changeVal': 115,
#     'etfTabCode': 4,
#     'itemcode': '195930',
#     'itemname': 'TIGER 유로스탁스50(합성 H)',
#     'marketSum': 734,
#     'nav': 12784.0,
#     'nowVal': 12870,
#     'quant': 7212,
#     'risefall': '2',
#     'threeMonthEarnRate': -7.9726},
#    {'amonut': 0,
#     'changeRate': 1.31,
#     'changeVal': 110,
#     'etfTabCode': 1,
#     'itemcode': '411540',
#     'itemname': 'SOL 200 Top10',
#     'marketSum': 733,
#     'nav': 8590.0,
#     'nowVal': 8520,
#     'quant': 13,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.9423},
#    {'amonut': 498,
#     'changeRate': 0.0,
#     'changeVal': 0,
#     'etfTabCode': 4,
#     'itemcode': '195980',
#     'itemname': 'ARIRANG 신흥국MSCI(합성 H)',
#     'marketSum': 723,
#     'nav': 9934.0,
#     'nowVal': 9875,
#     'quant': 50433,
#     'risefall': '3',
#     'threeMonthEarnRate': -12.9956},
#    {'amonut': 470,
#     'changeRate': 0.09,
#     'changeVal': 80,
#     'etfTabCode': 6,
#     'itemcode': '365780',
#     'itemname': 'KINDEX 국고채10년',
#     'marketSum': 714,
#     'nav': 88749.0,
#     'nowVal': 88845,
#     'quant': 5305,
#     'risefall': '2',
#     'threeMonthEarnRate': -3.6368},
#    {'amonut': 1246,
#     'changeRate': 0.64,
#     'changeVal': 55,
#     'etfTabCode': 4,
#     'itemcode': '414270',
#     'itemname': 'KINDEX G2전기차&자율주행액티브',
#     'marketSum': 712,
#     'nav': 8630.0,
#     'nowVal': 8680,
#     'quant': 143912,
#     'risefall': '2',
#     'threeMonthEarnRate': None},
#    {'amonut': 39,
#     'changeRate': 0.59,
#     'changeVal': 105,
#     'etfTabCode': 4,
#     'itemcode': '298770',
#     'itemname': 'KODEX 한국대만IT프리미어',
#     'marketSum': 701,
#     'nav': 17940.0,
#     'nowVal': 17985,
#     'quant': 2217,
#     'risefall': '2',
#     'threeMonthEarnRate': -9.8791},
#    {'amonut': 230,
#     'changeRate': -0.19,
#     'changeVal': -20,
#     'etfTabCode': 2,
#     'itemcode': '385510',
#     'itemname': 'KODEX K-신재생에너지액티브',
#     'marketSum': 690,
#     'nav': 10457.0,
#     'nowVal': 10455,
#     'quant': 22147,
#     'risefall': '5',
#     'threeMonthEarnRate': 11.7428},
#    {'amonut': 272,
#     'changeRate': -0.38,
#     'changeVal': -40,
#     'etfTabCode': 2,
#     'itemcode': '385520',
#     'itemname': 'KODEX K-미래차액티브',
#     'marketSum': 690,
#     'nav': 10451.0,
#     'nowVal': 10450,
#     'quant': 26168,
#     'risefall': '5',
#     'threeMonthEarnRate': 4.743},
#    {'amonut': 73,
#     'changeRate': 1.32,
#     'changeVal': 160,
#     'etfTabCode': 2,
#     'itemcode': '266160',
#     'itemname': 'KBSTAR 고배당',
#     'marketSum': 689,
#     'nav': 12330.0,
#     'nowVal': 12300,
#     'quant': 6033,
#     'risefall': '2',
#     'threeMonthEarnRate': 2.204},
#    {'amonut': 96,
#     'changeRate': 0.33,
#     'changeVal': 30,
#     'etfTabCode': 2,
#     'itemcode': '388280',
#     'itemname': 'KBSTAR Fn컨택트대표',
#     'marketSum': 684,
#     'nav': 9146.0,
#     'nowVal': 9150,
#     'quant': 10585,
#     'risefall': '2',
#     'threeMonthEarnRate': 12.4235},
#    {'amonut': 541,
#     'changeRate': 0.55,
#     'changeVal': 45,
#     'etfTabCode': 4,
#     'itemcode': '419430',
#     'itemname': 'KODEX 차이나2차전지MSCI(합성)',
#     'marketSum': 652,
#     'nav': 8184.0,
#     'nowVal': 8155,
#     'quant': 66330,
#     'risefall': '2',
#     'threeMonthEarnRate': None},
#    {'amonut': 409,
#     'changeRate': 1.16,
#     'changeVal': 215,
#     'etfTabCode': 4,
#     'itemcode': '200250',
#     'itemname': 'KOSEF 인도Nifty50(합성)',
#     'marketSum': 649,
#     'nav': 19043.0,
#     'nowVal': 18815,
#     'quant': 21880,
#     'risefall': '2',
#     'threeMonthEarnRate': 2.1416},
#    {'amonut': 36,
#     'changeRate': 0.55,
#     'changeVal': 100,
#     'etfTabCode': 4,
#     'itemcode': '174360',
#     'itemname': 'KBSTAR 중국본토대형주CSI100',
#     'marketSum': 642,
#     'nav': 18442.0,
#     'nowVal': 18350,
#     'quant': 1969,
#     'risefall': '2',
#     'threeMonthEarnRate': -13.7524},
#    {'amonut': 302,
#     'changeRate': -0.07,
#     'changeVal': -70,
#     'etfTabCode': 6,
#     'itemcode': '114820',
#     'itemname': 'TIGER 국채3년',
#     'marketSum': 641,
#     'nav': 106764.0,
#     'nowVal': 106780,
#     'quant': 2828,
#     'risefall': '5',
#     'threeMonthEarnRate': -1.1756},
#    {'amonut': 235,
#     'changeRate': 0.55,
#     'changeVal': 55,
#     'etfTabCode': 4,
#     'itemcode': '390390',
#     'itemname': 'KODEX 미국반도체MV',
#     'marketSum': 640,
#     'nav': 9870.0,
#     'nowVal': 10080,
#     'quant': 23549,
#     'risefall': '2',
#     'threeMonthEarnRate': -7.2618},
#    {'amonut': 6197,
#     'changeRate': -0.9,
#     'changeVal': -45,
#     'etfTabCode': 3,
#     'itemcode': '123310',
#     'itemname': 'TIGER 인버스',
#     'marketSum': 636,
#     'nav': 4960.0,
#     'nowVal': 4965,
#     'quant': 1240228,
#     'risefall': '5',
#     'threeMonthEarnRate': 0.2},
#    {'amonut': 189,
#     'changeRate': 2.51,
#     'changeVal': 240,
#     'etfTabCode': 4,
#     'itemcode': '391600',
#     'itemname': 'KINDEX 미국친환경그린테마INDXX',
#     'marketSum': 627,
#     'nav': 9671.0,
#     'nowVal': 9790,
#     'quant': 19645,
#     'risefall': '2',
#     'threeMonthEarnRate': 12.6179},
#    {'amonut': 70,
#     'changeRate': -0.92,
#     'changeVal': -95,
#     'etfTabCode': 2,
#     'itemcode': '387280',
#     'itemname': 'TIGER 퓨처모빌리티액티브',
#     'marketSum': 611,
#     'nav': 10231.0,
#     'nowVal': 10200,
#     'quant': 6933,
#     'risefall': '5',
#     'threeMonthEarnRate': 0.8317},
#    {'amonut': 47,
#     'changeRate': 0.04,
#     'changeVal': 20,
#     'etfTabCode': 6,
#     'itemcode': '302190',
#     'itemname': 'TIGER 중장기국채',
#     'marketSum': 608,
#     'nav': 49007.0,
#     'nowVal': 49020,
#     'quant': 980,
#     'risefall': '2',
#     'threeMonthEarnRate': -2.5652},
#    {'amonut': 24,
#     'changeRate': 1.04,
#     'changeVal': 195,
#     'etfTabCode': 1,
#     'itemcode': '310960',
#     'itemname': 'TIGER 200TR',
#     'marketSum': 589,
#     'nav': 19032.0,
#     'nowVal': 18990,
#     'quant': 1278,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.5819},
#    {'amonut': 370,
#     'changeRate': 1.84,
#     'changeVal': 280,
#     'etfTabCode': 4,
#     'itemcode': '099140',
#     'itemname': 'KODEX 차이나H',
#     'marketSum': 574,
#     'nav': 15638.0,
#     'nowVal': 15500,
#     'quant': 24034,
#     'risefall': '2',
#     'threeMonthEarnRate': -14.9959},
#    {'amonut': 154,
#     'changeRate': 1.03,
#     'changeVal': 85,
#     'etfTabCode': 4,
#     'itemcode': '396510',
#     'itemname': 'TIGER 차이나클린에너지SOLACTIVE',
#     'marketSum': 564,
#     'nav': 8410.0,
#     'nowVal': 8350,
#     'quant': 18513,
#     'risefall': '2',
#     'threeMonthEarnRate': -13.6364},
# ...
#     'itemcode': '292340',
#     'itemname': '마이티 200커버드콜ATM레버리지',
#     'marketSum': 56,
#     'nav': 9268.0,
#     'nowVal': 9250,
#     'quant': 285,
#     'risefall': '2',
#     'threeMonthEarnRate': 8.3482},
#    {'amonut': 2,
#     'changeRate': 0.95,
#     'changeVal': 80,
#     'etfTabCode': 2,
#     'itemcode': '376250',
#     'itemname': 'ARIRANG 탄소효율그린뉴딜',
#     'marketSum': 55,
#     'nav': 8532.0,
#     'nowVal': 8535,
#     'quant': 293,
#     'risefall': '2',
#     'threeMonthEarnRate': -1.2681},
#    {'amonut': 0,
#     'changeRate': 1.99,
#     'changeVal': 215,
#     'etfTabCode': 2,
#     'itemcode': '368470',
#     'itemname': 'KINDEX Fn K-뉴딜디지털플러스',
#     'marketSum': 55,
#     'nav': 11006.0,
#     'nowVal': 11000,
#     'quant': 20,
#     'risefall': '2',
#     'threeMonthEarnRate': -2.3519},
#    {'amonut': 1,
#     'changeRate': 1.12,
#     'changeVal': 100,
#     'etfTabCode': 1,
#     'itemcode': '228820',
#     'itemname': 'TIGER KTOP30',
#     'marketSum': 54,
#     'nav': 9098.0,
#     'nowVal': 9055,
#     'quant': 148,
#     'risefall': '2',
#     'threeMonthEarnRate': -2.9428},
#    {'amonut': 64,
#     'changeRate': 2.11,
#     'changeVal': 80,
#     'etfTabCode': 4,
#     'itemcode': '105010',
#     'itemname': 'TIGER 라틴35',
#     'marketSum': 54,
#     'nav': 3863.0,
#     'nowVal': 3870,
#     'quant': 16742,
#     'risefall': '2',
#     'threeMonthEarnRate': 11.3069},
#    {'amonut': 37,
#     'changeRate': 1.1,
#     'changeVal': 55,
#     'etfTabCode': 2,
#     'itemcode': '412560',
#     'itemname': 'TIGER KRX BBIG K-뉴딜레버리지',
#     'marketSum': 53,
#     'nav': 5062.0,
#     'nowVal': 5075,
#     'quant': 7537,
#     'risefall': '2',
#     'threeMonthEarnRate': -15.2028},
#    {'amonut': 0,
#     'changeRate': 0.0,
#     'changeVal': 0,
#     'etfTabCode': 6,
#     'itemcode': '292770',
#     'itemname': 'KODEX 국채선물3년인버스',
#     'marketSum': 52,
#     'nav': 51588.0,
#     'nowVal': 51400,
#     'quant': 0,
#     'risefall': '3',
#     'threeMonthEarnRate': 1.5208},
#    {'amonut': 0,
#     'changeRate': 0.62,
#     'changeVal': 640,
#     'etfTabCode': 6,
#     'itemcode': '299070',
#     'itemname': 'KINDEX 국채선물10년인버스',
#     'marketSum': 52,
#     'nav': 104289.0,
#     'nowVal': 104595,
#     'quant': 6,
#     'risefall': '2',
#     'threeMonthEarnRate': 4.0903},
#    {'amonut': 30,
#     'changeRate': -1.03,
#     'changeVal': -60,
#     'etfTabCode': 3,
#     'itemcode': '252410',
#     'itemname': 'KBSTAR 200선물인버스',
#     'marketSum': 52,
#     'nav': 5750.0,
#     'nowVal': 5760,
#     'quant': 5314,
#     'risefall': '5',
#     'threeMonthEarnRate': 0.0},
#    {'amonut': 0,
#     'changeRate': 0.39,
#     'changeVal': 50,
#     'etfTabCode': 2,
#     'itemcode': '277640',
#     'itemname': 'TIGER 코스피대형주',
#     'marketSum': 52,
#     'nav': 13063.0,
#     'nowVal': 12930,
#     'quant': 17,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.0383},
#    {'amonut': 0,
#     'changeRate': 0.0,
#     'changeVal': 0,
#     'etfTabCode': 6,
#     'itemcode': '299080',
#     'itemname': 'KINDEX 국채선물3년인버스',
#     'marketSum': 52,
#     'nav': 103265.0,
#     'nowVal': 103055,
#     'quant': 0,
#     'risefall': '3',
#     'threeMonthEarnRate': 1.6221},
#    {'amonut': 0,
#     'changeRate': 1.22,
#     'changeVal': 155,
#     'etfTabCode': 2,
#     'itemcode': '333940',
#     'itemname': 'ARIRANG KS로우볼가중TR',
#     'marketSum': 51,
#     'nav': 12859.0,
#     'nowVal': 12855,
#     'quant': 27,
#     'risefall': '2',
#     'threeMonthEarnRate': 1.9261},
#    {'amonut': 1,
#     'changeRate': 0.2,
#     'changeVal': 20,
#     'etfTabCode': 6,
#     'itemcode': '267440',
#     'itemname': 'KBSTAR 미국장기국채선물(H)',
#     'marketSum': 51,
#     'nav': 10188.0,
#     'nowVal': 10265,
#     'quant': 170,
#     'risefall': '2',
#     'threeMonthEarnRate': -9.0546},
#    {'amonut': 699,
#     'changeRate': -1.26,
#     'changeVal': -125,
#     'etfTabCode': 3,
#     'itemcode': '306530',
#     'itemname': 'HANARO 코스닥150선물레버리지',
#     'marketSum': 51,
#     'nav': 9908.0,
#     'nowVal': 9795,
#     'quant': 70763,
#     'risefall': '5',
#     'threeMonthEarnRate': 5.1404},
#    {'amonut': 46,
#     'changeRate': 0.23,
#     'changeVal': 20,
#     'etfTabCode': 3,
#     'itemcode': '291620',
#     'itemname': 'KOSEF 코스닥150선물인버스',
#     'marketSum': 51,
#     'nav': 8543.0,
#     'nowVal': 8575,
#     'quant': 5399,
#     'risefall': '2',
#     'threeMonthEarnRate': -5.8856},
#    {'amonut': 0,
#     'changeRate': 0.66,
#     'changeVal': 55,
#     'etfTabCode': 4,
#     'itemcode': '291890',
#     'itemname': 'KODEX MSCI EM선물(H)',
#     'marketSum': 50,
#     'nav': 8444.0,
#     'nowVal': 8355,
#     'quant': 117,
#     'risefall': '2',
#     'threeMonthEarnRate': -12.2158},
#    {'amonut': 220,
#     'changeRate': 0.93,
#     'changeVal': 115,
#     'etfTabCode': 2,
#     'itemcode': '281990',
#     'itemname': 'KBSTAR 중소형고배당',
#     'marketSum': 50,
#     'nav': 12531.0,
#     'nowVal': 12465,
#     'quant': 17687,
#     'risefall': '2',
#     'threeMonthEarnRate': 11.3257},
#    {'amonut': 2,
#     'changeRate': -0.2,
#     'changeVal': -20,
#     'etfTabCode': 2,
#     'itemcode': '373490',
#     'itemname': 'KODEX K-이노베이션액티브',
#     'marketSum': 50,
#     'nav': 9960.0,
#     'nowVal': 9930,
#     'quant': 289,
#     'risefall': '5',
#     'threeMonthEarnRate': 3.3057},
#    {'amonut': 95,
#     'changeRate': -1.35,
#     'changeVal': -75,
#     'etfTabCode': 3,
#     'itemcode': '145670',
#     'itemname': 'KINDEX 인버스',
#     'marketSum': 49,
#     'nav': 5479.0,
#     'nowVal': 5470,
#     'quant': 17219,
#     'risefall': '5',
#     'threeMonthEarnRate': 0.6352},
#    {'amonut': 3,
#     'changeRate': 0.98,
#     'changeVal': 95,
#     'etfTabCode': 2,
#     'itemcode': '244660',
#     'itemname': 'KODEX 퀄리티Plus',
#     'marketSum': 49,
#     'nav': 9859.0,
#     'nowVal': 9825,
#     'quant': 402,
#     'risefall': '2',
#     'threeMonthEarnRate': 10.3982},
#    {'amonut': 0,
#     'changeRate': 0.8,
#     'changeVal': 65,
#     'etfTabCode': 1,
#     'itemcode': '391680',
#     'itemname': 'HK 하이볼액티브',
#     'marketSum': 49,
#     'nav': 8234.0,
#     'nowVal': 8185,
#     'quant': 4,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.0616},
#    {'amonut': 0,
#     'changeRate': -0.41,
#     'changeVal': -40,
#     'etfTabCode': 7,
#     'itemcode': '321410',
#     'itemname': 'KODEX 멀티에셋하이인컴(H)',
#     'marketSum': 49,
#     'nav': 9807.0,
#     'nowVal': 9820,
#     'quant': 35,
#     'risefall': '5',
#     'threeMonthEarnRate': -8.0653},
#    {'amonut': 71,
#     'changeRate': 0.67,
#     'changeVal': 50,
#     'etfTabCode': 3,
#     'itemcode': '301410',
#     'itemname': 'ARIRANG 코스닥150선물인버스',
#     'marketSum': 48,
#     'nav': 7432.0,
#     'nowVal': 7460,
#     'quant': 9613,
#     'risefall': '2',
#     'threeMonthEarnRate': -6.2026},
#    {'amonut': 1,
#     'changeRate': 1.32,
#     'changeVal': 140,
#     'etfTabCode': 1,
#     'itemcode': '295820',
#     'itemname': 'ARIRANG 200동일가중',
#     'marketSum': 48,
#     'nav': 10725.0,
#     'nowVal': 10730,
#     'quant': 149,
#     'risefall': '2',
#     'threeMonthEarnRate': 11.1225},
#    {'amonut': 3,
#     'changeRate': 0.78,
#     'changeVal': 125,
#     'etfTabCode': 2,
#     'itemcode': '139290',
#     'itemname': 'TIGER 200 경기소비재',
#     'marketSum': 48,
#     'nav': 16110.0,
#     'nowVal': 16055,
#     'quant': 188,
#     'risefall': '2',
#     'threeMonthEarnRate': 2.7584},
#    {'amonut': 63,
#     'changeRate': -0.77,
#     'changeVal': -45,
#     'etfTabCode': 3,
#     'itemcode': '253240',
#     'itemname': 'KOSEF 200선물인버스',
#     'marketSum': 48,
#     'nav': 5774.0,
#     'nowVal': 5780,
#     'quant': 10950,
#     'risefall': '5',
#     'threeMonthEarnRate': -0.0858},
#    {'amonut': 0,
#     'changeRate': 0.73,
#     'changeVal': 85,
#     'etfTabCode': 2,
#     'itemcode': '301440',
#     'itemname': 'ARIRANG 코스피중형주',
#     'marketSum': 47,
#     'nav': 11707.0,
#     'nowVal': 11725,
#     'quant': 20,
#     'risefall': '2',
#     'threeMonthEarnRate': 8.0054},
#    {'amonut': 29,
#     'changeRate': 0.11,
#     'changeVal': 45,
#     'etfTabCode': 6,
#     'itemcode': '346000',
#     'itemname': 'HANARO KAP초장기국고채',
#     'marketSum': 45,
#     'nav': 39447.0,
#     'nowVal': 39555,
#     'quant': 737,
#     'risefall': '2',
#     'threeMonthEarnRate': -7.4448},
#    {'amonut': 58,
#     'changeRate': 0.67,
#     'changeVal': 60,
#     'etfTabCode': 6,
#     'itemcode': '267450',
#     'itemname': 'KBSTAR 미국장기국채선물인버스(H)',
#     'marketSum': 45,
#     'nav': 8980.0,
#     'nowVal': 9000,
#     'quant': 6509,
#     'risefall': '2',
#     'threeMonthEarnRate': 10.1663},
#    {'amonut': 15,
#     'changeRate': 0.59,
#     'changeVal': 25,
#     'etfTabCode': 2,
#     'itemcode': '157500',
#     'itemname': 'TIGER 증권',
#     'marketSum': 45,
#     'nav': 4243.0,
#     'nowVal': 4230,
#     'quant': 3738,
#     'risefall': '2',
#     'threeMonthEarnRate': -0.4485},
#    {'amonut': 98,
#     'changeRate': 3.13,
#     'changeVal': 295,
#     'etfTabCode': 2,
#     'itemcode': '227560',
#     'itemname': 'TIGER 200 생활소비재',
#     'marketSum': 45,
#     'nav': 9766.0,
#     'nowVal': 9730,
#     'quant': 10198,
#     'risefall': '2',
#     'threeMonthEarnRate': 6.6406},
#    {'amonut': 0,
#     'changeRate': 0.09,
#     'changeVal': 45,
#     'etfTabCode': 6,
#     'itemcode': '295020',
#     'itemname': 'KBSTAR 국채선물10년인버스',
#     'marketSum': 45,
#     'nav': 51877.0,
#     'nowVal': 51940,
#     'quant': 8,
#     'risefall': '2',
#     'threeMonthEarnRate': 4.1127},
#    {'amonut': 495,
#     'changeRate': 1.52,
#     'changeVal': 150,
#     'etfTabCode': 2,
#     'itemcode': '285010',
#     'itemname': 'KBSTAR 200중공업',
#     'marketSum': 44,
#     'nav': 10049.0,
#     'nowVal': 10015,
#     'quant': 49695,
#     'risefall': '2',
#     'threeMonthEarnRate': 18.9398},
#    {'amonut': 67,
#     'changeRate': 0.73,
#     'changeVal': 40,
#     'etfTabCode': 4,
#     'itemcode': '371870',
#     'itemname': 'KINDEX 차이나항셍테크',
#     'marketSum': 44,
#     'nav': 5563.0,
#     'nowVal': 5495,
#     'quant': 12175,
#     'risefall': '2',
#     'threeMonthEarnRate': -22.8976},
#    {'amonut': 72,
#     'changeRate': 3.72,
#     'changeVal': 440,
#     'etfTabCode': 2,
#     'itemcode': '287300',
#     'itemname': 'KBSTAR 200건설',
#     'marketSum': 42,
#     'nav': 12325.0,
#     'nowVal': 12265,
#     'quant': 5946,
#     'risefall': '2',
#     'threeMonthEarnRate': 14.1837},
#    {'amonut': 8,
#     'changeRate': 0.44,
#     'changeVal': 20,
#     'etfTabCode': 4,
#     'itemcode': '220130',
#     'itemname': 'SOL 중국본토 중소형 CSI500(합성 H)',
#     'marketSum': 41,
#     'nav': 4579.0,
#     'nowVal': 4585,
#     'quant': 1780,
#     'risefall': '2',
#     'threeMonthEarnRate': -21.9659},
#    {'amonut': 34,
#     'changeRate': 0.74,
#     'changeVal': 50,
#     'etfTabCode': 5,
#     'itemcode': '280940',
#     'itemname': 'KODEX 골드선물인버스(H)',
#     'marketSum': 41,
#     'nav': 6861.0,
#     'nowVal': 6800,
#     'quant': 5020,
#     'risefall': '2',
#     'threeMonthEarnRate': -5.4622},
#    {'amonut': 0,
#     'changeRate': 1.11,
#     'changeVal': 125,
#     'etfTabCode': 2,
#     'itemcode': '266550',
#     'itemname': 'ARIRANG 중형주저변동50',
#     'marketSum': 40,
#     'nav': 11365.0,
#     'nowVal': 11395,
#     'quant': 48,
#     'risefall': '2',
#     'threeMonthEarnRate': 13.0223},
#    {'amonut': 21,
#     'changeRate': 1.0,
#     'changeVal': 75,
#     'etfTabCode': 6,
#     'itemcode': '267500',
#     'itemname': 'KBSTAR 미국장기국채선물인버스2X(합성 H)',
#     'marketSum': 38,
#     'nav': 7592.0,
#     'nowVal': 7575,
#     'quant': 2869,
#     'risefall': '2',
#     'threeMonthEarnRate': 20.5787},
#    {'amonut': 0,
#     'changeRate': 1.18,
#     'changeVal': 175,
#     'etfTabCode': 2,
#     'itemcode': '252730',
#     'itemname': 'KBSTAR 모멘텀로우볼',
#     'marketSum': 38,
#     'nav': 15052.0,
#     'nowVal': 15025,
#     'quant': 5,
#     'risefall': '2',
#     'threeMonthEarnRate': 1.2024},
#    {'amonut': 2,
#     'changeRate': 1.34,
#     'changeVal': 120,
#     'etfTabCode': 2,
#     'itemcode': '280920',
#     'itemname': 'ARIRANG 주도업종',
#     'marketSum': 36,
#     'nav': 9102.0,
#     'nowVal': 9105,
#     'quant': 255,
#     'risefall': '2',
#     'threeMonthEarnRate': -3.3158},
#    {'amonut': 0,
#     'changeRate': 0.65,
#     'changeVal': 95,
#     'etfTabCode': 2,
#     'itemcode': '315480',
#     'itemname': 'KBSTAR 200커뮤니케이션서비스',
#     'marketSum': 35,
#     'nav': 14798.0,
#     'nowVal': 14775,
#     'quant': 47,
#     'risefall': '2',
#     'threeMonthEarnRate': -2.4215},
#    {'amonut': 0,
#     'changeRate': 0.5,
#     'changeVal': 70,
#     'etfTabCode': 2,
#     'itemcode': '333980',
#     'itemname': 'ARIRANG KS퀄리티가중TR',
#     'marketSum': 35,
#     'nav': 14192.0,
#     'nowVal': 14165,
#     'quant': 27,
#     'risefall': '2',
#     'threeMonthEarnRate': 0.4632},
#    {'amonut': 81,
#     'changeRate': 0.2,
#     'changeVal': 10,
#     'etfTabCode': 3,
#     'itemcode': '275750',
#     'itemname': 'KBSTAR 코스닥150선물인버스',
#     'marketSum': 35,
#     'nav': 4946.0,
#     'nowVal': 4965,
#     'quant': 16336,
#     'risefall': '2',
#     'threeMonthEarnRate': -6.2441},
#    {'amonut': 1,
#     'changeRate': 1.84,
#     'changeVal': 165,
#     'etfTabCode': 2,
#     'itemcode': '278420',
#     'itemname': 'ARIRANG ESG우수기업',
#     'marketSum': 32,
#     'nav': 9117.0,
#     'nowVal': 9120,
#     'quant': 187,
#     'risefall': '2',
#     'threeMonthEarnRate': 8.5764},
#    {'amonut': 4,
#     'changeRate': -1.51,
#     'changeVal': -65,
#     'etfTabCode': 5,
#     'itemcode': '334700',
#     'itemname': 'KBSTAR 팔라듐선물인버스(H)',
#     'marketSum': 30,
#     'nav': 4208.0,
#     'nowVal': 4240,
#     'quant': 1035,
#     'risefall': '5',
#     'threeMonthEarnRate': -5.9017},
#    {'amonut': 4,
#     'changeRate': -1.27,
#     'changeVal': -125,
#     'etfTabCode': 6,
#     'itemcode': '267490',
#     'itemname': 'KBSTAR 미국장기국채선물레버리지(합성 H)',
#     'marketSum': 29,
#     'nav': 9758.0,
#     'nowVal': 9740,
#     'quant': 442,
#     'risefall': '5',
#     'threeMonthEarnRate': -18.4374},
#    {'amonut': 81,
#     'changeRate': 1.59,
#     'changeVal': 150,
#     'etfTabCode': 2,
#     'itemcode': '285020',
#     'itemname': 'KBSTAR 200철강소재',
#     'marketSum': 29,
#     'nav': 9610.0,
#     'nowVal': 9605,
#     'quant': 8491,
#     'risefall': '2',
#     'threeMonthEarnRate': 22.9746},
#    {'amonut': 44,
#     'changeRate': 2.87,
#     'changeVal': 260,
#     'etfTabCode': 2,
#     'itemcode': '309210',
#     'itemname': 'ARIRANG KRX300헬스케어',
#     'marketSum': 28,
#     'nav': 9368.0,
#     'nowVal': 9315,
#     'quant': 4853,
#     'risefall': '2',
#     'threeMonthEarnRate': 4.2602},
#    {'amonut': 1,
#     'changeRate': -0.16,
#     'changeVal': -20,
#     'etfTabCode': 1,
#     'itemcode': '301400',
#     'itemname': 'ARIRANG 코스닥150',
#     'marketSum': 25,
#     'nav': 12381.0,
#     'nowVal': 12320,
#     'quant': 115,
#     'risefall': '5',
#     'threeMonthEarnRate': 2.4813},
#    {'amonut': 0,
#     'changeRate': 2.18,
#     'changeVal': 495,
#     'etfTabCode': 2,
#     'itemcode': '217790',
#     'itemname': 'TIGER 가격조정',
#     'marketSum': 23,
#     'nav': 23179.0,
#     'nowVal': 23180,
#     'quant': 11,
#     'risefall': '2',
#     'threeMonthEarnRate': 6.0647},
#    {'amonut': 0,
#     'changeRate': 1.39,
#     'changeVal': 190,
#     'etfTabCode': 2,
#     'itemcode': '252720',
#     'itemname': 'KBSTAR 모멘텀밸류',
#     'marketSum': 21,
#     'nav': 13865.0,
#     'nowVal': 13825,
#     'quant': 6,
#     'risefall': '2',
#     'threeMonthEarnRate': 1.1506},
#    {'amonut': 1,
#     'changeRate': -0.02,
#     'changeVal': -10,
#     'etfTabCode': 6,
#     'itemcode': '295000',
#     'itemname': 'KBSTAR 국채선물10년',
#     'marketSum': 20,
#     'nav': 51181.0,
#     'nowVal': 51165,
#     'quant': 39,
#     'risefall': '5',
#     'threeMonthEarnRate': -3.7159},
#    {'amonut': 3,
#     'changeRate': 3.57,
#     'changeVal': 255,
#     'etfTabCode': 2,
#     'itemcode': '287330',
#     'itemname': 'KBSTAR 200생활소비재',
#     'marketSum': 18,
#     'nav': 7392.0,
#     'nowVal': 7395,
#     'quant': 485,
#     'risefall': '2',
#     'threeMonthEarnRate': 6.9597},
#    {'amonut': 3,
#     'changeRate': 2.66,
#     'changeVal': 290,
#     'etfTabCode': 2,
#     'itemcode': '284990',
#     'itemname': 'KBSTAR 200에너지화학',
#     'marketSum': 16,
#     'nav': 11214.0,
#     'nowVal': 11195,
#     'quant': 316,
#     'risefall': '2',
#     'threeMonthEarnRate': 1.1791},
#    {'amonut': 3,
#     'changeRate': 1.0,
#     'changeVal': 100,
#     'etfTabCode': 2,
#     'itemcode': '287310',
#     'itemname': 'KBSTAR 200경기소비재',
#     'marketSum': 10,
#     'nav': 10079.0,
#     'nowVal': 10060,
#     'quant': 380,
#     'risefall': '2',
#     'threeMonthEarnRate': 2.7763},
#    {'amonut': 0,
#     'changeRate': 2.08,
#     'changeVal': 240,
#     'etfTabCode': 2,
#     'itemcode': '287320',
#     'itemname': 'KBSTAR 200산업재',
#     'marketSum': 7,
#     'nav': 11784.0,
#     'nowVal': 11760,
#     'quant': 37,
#     'risefall': '2',
#     'threeMonthEarnRate': 18.425}]},
#  'resultCode': 'success'}

# %% [markdown]
# ### JSON 에서 원하는 데이터 찾기

# %%
# result > etfItemList 의 하위 구조로 목록을 찾고자 하는 데이터를 가져옵니다.
etfItemList = etf_json["result"]['etfItemList']
etfItemList
# Out:
# [{'amonut': 145311,
#   'changeRate': 1.0,
#   'changeVal': 345,
#   'etfTabCode': 1,
#   'itemcode': '069500',
#   'itemname': 'KODEX 200',
#   'marketSum': 47195,
#   'nav': 35084.0,
#   'nowVal': 34985,
#   'quant': 4180043,
#   'risefall': '2',
#   'threeMonthEarnRate': -0.4674},
#  {'amonut': 107221,
#   'changeRate': 0.81,
#   'changeVal': 95,
#   'etfTabCode': 4,
#   'itemcode': '371460',
#   'itemname': 'TIGER 차이나전기차SOLACTIVE',
#   'marketSum': 29425,
#   'nav': 11894.0,
#   'nowVal': 11890,
#   'quant': 8956866,
#   'risefall': '2',
#   'threeMonthEarnRate': -25.5132},
#  {'amonut': 309205,
#   'changeRate': 1.98,
#   'changeVal': 360,
#   'etfTabCode': 3,
#   'itemcode': '122630',
#   'itemname': 'KODEX 레버리지',
#   'marketSum': 21122,
#   'nav': 18679.0,
#   'nowVal': 18585,
#   'quant': 16856345,
#   'risefall': '2',
#   'threeMonthEarnRate': -2.6183},
#  {'amonut': 8789,
#   'changeRate': 1.35,
#   'changeVal': 1000,
#   'etfTabCode': 4,
#   'itemcode': '133690',
#   'itemname': 'TIGER 미국나스닥100',
#   'marketSum': 20964,
#   'nav': 74008.0,
#   'nowVal': 75220,
#   'quant': 117485,
#   'risefall': '2',
#   'threeMonthEarnRate': -0.9795},
#  {'amonut': 380833,
#   'changeRate': -1.85,
#   'changeVal': -50,
#   'etfTabCode': 3,
#   'itemcode': '252670',
#   'itemname': 'KODEX 200선물인버스2X',
#   'marketSum': 19202,
#   'nav': 2646.0,
#   'nowVal': 2650,
#   'quant': 141997440,
#   'risefall': '5',
#   'threeMonthEarnRate': -1.099},
#  {'amonut': 54652,
#   'changeRate': 0.95,
#   'changeVal': 330,
#   'etfTabCode': 1,
#   'itemcode': '102110',
#   'itemname': 'TIGER 200',
#   'marketSum': 18126,
#   'nav': 35137.0,
#   'nowVal': 35060,
#   'quant': 1568552,
#   'risefall': '2',
#   'threeMonthEarnRate': -0.3681},
#  {'amonut': 98417,
#   'changeRate': 0.01,
#   'changeVal': 15,
#   'etfTabCode': 6,
#   'itemcode': '157450',
#   'itemname': 'TIGER 단기통안채',
#   'marketSum': 18098,
#   'nav': 100796.0,
#   'nowVal': 100790,
#   'quant': 976423,
#   'risefall': '2',
#   'threeMonthEarnRate': 0.2187},
#  {'amonut': 13082,
#   'changeRate': 0.02,
#   'changeVal': 25,
#   'etfTabCode': 6,
#   'itemcode': '214980',
#   'itemname': 'KODEX 단기채권PLUS',
#   'marketSum': 17960,
#   'nav': 103846.0,
#   'nowVal': 103840,
#   'quant': 125979,
#   'risefall': '2',
#   'threeMonthEarnRate': 0.2946},
#  {'amonut': 8935,
#   'changeRate': 1.16,
#   'changeVal': 155,
#   'etfTabCode': 4,
#   'itemcode': '360750',
#   'itemname': 'TIGER 미국S&P500',
#   'marketSum': 16097,
#   'nav': 13364.0,
#   'nowVal': 13510,
#   'quant': 665897,
#   'risefall': '2',
#   'threeMonthEarnRate': 3.3166},
#  {'amonut': 2669,
#   'changeRate': 1.88,
#   'changeVal': 165,
#   'etfTabCode': 2,
#   'itemcode': '102780',
#   'itemname': 'KODEX 삼성그룹',
#   'marketSum': 15276,
#   'nav': 8988.0,
#   'nowVal': 8965,
#   'quant': 299740,
#   'risefall': '2',
#   'threeMonthEarnRate': 0.7315},
#  {'amonut': 280122,
#   'changeRate': 0.01,
#   'changeVal': 15,
#   'etfTabCode': 6,
#   'itemcode': '153130',
#   'itemname': 'KODEX 단기채권',
#   'marketSum': 14787,
#   'nav': 103372.0,
#   'nowVal': 103375,
#   'quant': 2709886,
#   'risefall': '2',
#   'threeMonthEarnRate': 0.1987},
#  {'amonut': 555,
#   'changeRate': 0.02,
#   'changeVal': 25,
#   'etfTabCode': 6,
#   'itemcode': '273130',
#   'itemname': 'KODEX 종합채권(AA-이상)액티브',
#   'marketSum': 14344,
#   'nav': 103600.0,
#   'nowVal': 103640,
#   'quant': 5364,
#   'risefall': '2',
#   'threeMonthEarnRate': -2.8913},
#  {'amonut': 12383,
#   'changeRate': 1.58,
#   'changeVal': 175,
#   'etfTabCode': 4,
#   'itemcode': '381170',
#   'itemname': 'TIGER 미국테크TOP10 INDXX',
#   'marketSum': 13529,
#   'nav': 11011.0,
#   'nowVal': 11260,
#   'quant': 1106429,
#   'risefall': '2',
#   'threeMonthEarnRate': -2.1193},
#  {'amonut': 36922,
#   'changeRate': -0.13,
#   'changeVal': -25,
#   'etfTabCode': 2,
#   'itemcode': '305720',
#   'itemname': 'KODEX 2차전지산업',
#   'marketSum': 13323,
#   'nav': 19704.0,
#   'nowVal': 19650,
#   'quant': 1884877,
#   'risefall': '5',
#   'threeMonthEarnRate': 6.6144},
#  {'amonut': 32832,
#   'changeRate': -0.35,
#   'changeVal': -70,
#   'etfTabCode': 2,
#   'itemcode': '305540',
#   'itemname': 'TIGER 2차전지테마',
#   'marketSum': 13054,
#   'nav': 20174.0,
#   'nowVal': 20145,
#   'quant': 1633729,
#   'risefall': '5',
#   'threeMonthEarnRate': 7.1807},
#  {'amonut': 6840,
#   'changeRate': 1.56,
#   'changeVal': 155,
#   'etfTabCode': 4,
#   'itemcode': '381180',
#   'itemname': 'TIGER 미국필라델피아반도체나스닥',
#   'marketSum': 13024,
#   'nav': 9892.0,
#   'nowVal': 10065,
#   'quant': 683975,
#   'risefall': '2',
#   'threeMonthEarnRate': -8.013},
#  {'amonut': 4,
#   'changeRate': 1.25,
#   'changeVal': 175,
#   'etfTabCode': 1,
#   'itemcode': '310970',
#   'itemname': 'TIGER MSCI Korea TR',
#   'marketSum': 12800,
#   'nav': 14206.0,
#   'nowVal': 14175,
#   'quant': 309,
#   'risefall': '2',
#   'threeMonthEarnRate': -2.0294},
#  {'amonut': 3288,
#   'changeRate': 1.28,
#   'changeVal': 145,
#   'etfTabCode': 2,
#   'itemcode': '292150',
#   'itemname': 'TIGER TOP10',
#   'marketSum': 11777,
#   'nav': 11448.0,
#   'nowVal': 11445,
#   'quant': 289181,
#   'risefall': '2',
#   'threeMonthEarnRate': -4.3115},
#  {'amonut': 342,
#   'changeRate': 0.95,
#   'changeVal': 110,
#   'etfTabCode': 1,
#   'itemcode': '278530',
#   'itemname': 'KODEX 200TR',
#   'marketSum': 11109,
#   'nav': 11684.0,
#   'nowVal': 11645,
#   'quant': 29578,
#   'risefall': '2',
#   'threeMonthEarnRate': -0.3026},
#  {'amonut': 3487,
#   'changeRate': 1.12,
#   'changeVal': 125,
#   'etfTabCode': 1,
#   'itemcode': '278540',
#   'itemname': 'KODEX MSCI Korea TR',
#   'marketSum': 10489,
#   'nav': 11311.0,
#   'nowVal': 11315,
#   'quant': 310150,
#   'risefall': '2',
#   'threeMonthEarnRate': -1.9282},
#  {'amonut': 6979,
#   'changeRate': 1.1,
#   'changeVal': 385,
#   'etfTabCode': 1,
#   'itemcode': '148020',
#   'itemname': 'KBSTAR 200',
#   'marketSum': 9882,
#   'nav': 35303.0,
#   'nowVal': 35230,
#   'quant': 199121,
#   'risefall': '2',
#   'threeMonthEarnRate': -0.3105},
#  {'amonut': 84067,
#   'changeRate': -0.37,
#   'changeVal': -40,
#   'etfTabCode': 3,
#   'itemcode': '233740',
#   'itemname': 'KODEX 코스닥150레버리지',
#   'marketSum': 8903,
#   'nav': 10844.0,
#   'nowVal': 10675,
#   'quant': 7883654,
#   'risefall': '5',
#   'threeMonthEarnRate': 2.5358},
#  {'amonut': 135717,
#   'changeRate': -1.11,
#   'changeVal': -50,
#   'etfTabCode': 3,
#   'itemcode': '114800',
#   'itemname': 'KODEX 인버스',
#   'marketSum': 8358,
#   'nav': 4460.0,
#   'nowVal': 4460,
#   'quant': 30231835,
#   'risefall': '5',
#   'threeMonthEarnRate': 0.1109},
#  {'amonut': 7598,
#   'changeRate': 0.3,
#   'changeVal': 95,
#   'etfTabCode': 2,
#   'itemcode': '139260',
#   'itemname': 'TIGER 200 IT',
#   'marketSum': 8316,
#   'nav': 31709.0,
#   'nowVal': 31620,
#   'quant': 240838,
#   'risefall': '2',
#   'threeMonthEarnRate': -4.2608},
#  {'amonut': 8716,
#   'changeRate': 1.05,
#   'changeVal': 195,
#   'etfTabCode': 2,
#   'itemcode': '091180',
#   'itemname': 'KODEX 자동차',
#   'marketSum': 7321,
#   'nav': 18862.0,
#   'nowVal': 18845,
#   'quant': 465039,
#   'risefall': '2',
#   'threeMonthEarnRate': 1.7116},
#  {'amonut': 127,
#   'changeRate': 1.08,
#   'changeVal': 375,
#   'etfTabCode': 1,
#   'itemcode': '293180',
#   'itemname': 'HANARO 200',
#   'marketSum': 6633,
#   'nav': 35162.0,
#   'nowVal': 35095,
#   'quant': 3645,
#   'risefall': '2',
#   'threeMonthEarnRate': -0.551},
#  {'amonut': 4883,
#   'changeRate': 1.11,
#   'changeVal': 385,
#   'etfTabCode': 1,
#   'itemcode': '105190',
#   'itemname': 'KINDEX 200',
#   'marketSum': 6578,
#   'nav': 35175.0,
#   'nowVal': 35085,
#   'quant': 139493,
#   'risefall': '2',
#   'threeMonthEarnRate': -0.7852},
#  {'amonut': 24167,
#   'changeRate': 0.99,
#   'changeVal': 350,
#   'etfTabCode': 1,
#   'itemcode': '152100',
#   'itemname': 'ARIRANG 200',
#   'marketSum': 6363,
#   'nav': 35618.0,
#   'nowVal': 35545,
#   'quant': 681283,
#   'risefall': '2',
#   'threeMonthEarnRate': -0.1114},
#  {'amonut': 1393,
#   'changeRate': 0.98,
#   'changeVal': 90,
#   'etfTabCode': 4,
#   'itemcode': '394670',
#   'itemname': 'TIGER 글로벌리튬&2차전지SOLACTIVE(합성)',
#   'marketSum': 6294,
#   'nav': 9278.0,
#   'nowVal': 9250,
#   'quant': 150402,
#   'risefall': '2',
#   'threeMonthEarnRate': -10.7648},
#  {'amonut': 253,
#   'changeRate': 1.31,
#   'changeVal': 220,
#   'etfTabCode': 2,
#   'itemcode': '315930',
#   'itemname': 'KODEX Top5PlusTR',
#   'marketSum': 6060,
#   'nav': 17070.0,
#   'nowVal': 17070,
#   'quant': 15013,
#   'risefall': '2',
#   'threeMonthEarnRate': -3.7693},
#  {'amonut': 2452,
#   'changeRate': 1.26,
#   'changeVal': 170,
#   'etfTabCode': 4,
#   'itemcode': '360200',
#   'itemname': 'KINDEX 미국S&P500',
#   'marketSum': 5736,
#   'nav': 13472.0,
#   'nowVal': 13625,
#   'quant': 181609,
#   'risefall': '2',
#   'threeMonthEarnRate': 3.3703},
#  {'amonut': 48443,
#   'changeRate': -0.12,
#   'changeVal': -15,
#   'etfTabCode': 1,
#   'itemcode': '229200',
#   'itemname': 'KODEX 코스닥150',
#   'marketSum': 5661,
#   'nav': 12378.0,
#   'nowVal': 12175,
#   'quant': 3982817,
#   'risefall': '5',
#   'threeMonthEarnRate': 1.9966},
#  {'amonut': 6844,
#   'changeRate': 0.02,
#   'changeVal': 20,
#   'etfTabCode': 6,
#   'itemcode': '196230',
#   'itemname': 'KBSTAR 단기통안채',
#   'marketSum': 5585,
#   'nav': 105104.0,
#   'nowVal': 105100,
#   'quant': 65125,
#   'risefall': '2',
#   'threeMonthEarnRate': 0.205},
#  {'amonut': 205,
#   'changeRate': 1.06,
#   'changeVal': 445,
#   'etfTabCode': 1,
#   'itemcode': '294400',
#   'itemname': 'KOSEF 200TR',
#   'marketSum': 5361,
#   'nav': 42461.0,
#   'nowVal': 42380,
#   'quant': 4872,
#   'risefall': '2',
#   'threeMonthEarnRate': -0.2854},
#  {'amonut': 78,
#   'changeRate': 0.02,
#   'changeVal': 20,
#   'etfTabCode': 6,
#   'itemcode': '190620',
#   'itemname': 'KINDEX 단기통안채',
#   'marketSum': 4570,
#   'nav': 100428.0,
#   'nowVal': 100430,
#   'quant': 778,
#   'risefall': '2',
#   'threeMonthEarnRate': 0.2496},
#  {'amonut': 15792,
#   'changeRate': 1.61,
#   'changeVal': 225,
#   'etfTabCode': 2,
#   'itemcode': '364980',
#   'itemname': 'TIGER KRX2차전지K-뉴딜',
#   'marketSum': 4501,
#   'nav': 14214.0,
#   'nowVal': 14200,
#   'quant': 1121933,
#   'risefall': '2',
#   'threeMonthEarnRate': -3.7432},
#  {'amonut': 1088,
#   'changeRate': 0.56,
#   'changeVal': 115,
#   'etfTabCode': 4,
#   'itemcode': '251350',
#   'itemname': 'KODEX 선진국MSCI World',
#   'marketSum': 4483,
#   'nav': 20394.0,
#   'nowVal': 20565,
#   'quant': 53113,
#   'risefall': '2',
#   'threeMonthEarnRate': 2.5319},
#  {'amonut': 118486,
#   'changeRate': 0.32,
#   'changeVal': 15,
#   'etfTabCode': 3,
#   'itemcode': '251340',
#   'itemname': 'KODEX 코스닥150선물인버스',
#   'marketSum': 4286,
#   'nav': 4712.0,
#   'nowVal': 4725,
#   'quant': 25084202,
#   'risefall': '2',
#   'threeMonthEarnRate': -5.8},
#  {'amonut': 3456,
#   'changeRate': 1.28,
#   'changeVal': 150,
#   'etfTabCode': 4,
#   'itemcode': '379800',
#   'itemname': 'KODEX 미국S&P500TR',
#   'marketSum': 4163,
#   'nav': 11785.0,
#   'nowVal': 11910,
#   'quant': 292341,
#   'risefall': '2',
#   'threeMonthEarnRate': 3.2938},
#  {'amonut': 21967,
#   'changeRate': 1.1,
#   'changeVal': 380,
#   'etfTabCode': 1,
#   'itemcode': '069660',
#   'itemname': 'KOSEF 200',
#   'marketSum': 4020,
#   'nav': 35020.0,
#   'nowVal': 34960,
#   'quant': 630416,
#   'risefall': '2',
#   'threeMonthEarnRate': -0.6509},
#  {'amonut': 1614,
#   'changeRate': 2.02,
#   'changeVal': 420,
#   'etfTabCode': 4,
#   'itemcode': '314250',
#   'itemname': 'KODEX 미국FANG플러스(H)',
#   'marketSum': 3979,
#   'nav': 20670.0,
#   'nowVal': 21255,
#   'quant': 76107,
#   'risefall': '2',
#   'threeMonthEarnRate': -16.7433},
#  {'amonut': 2538,
#   'changeRate': 1.33,
#   'changeVal': 170,
#   'etfTabCode': 4,
#   'itemcode': '367380',
#   'itemname': 'KINDEX 미국나스닥100',
#   'marketSum': 3976,
#   'nav': 12709.0,
#   'nowVal': 12910,
#   'quant': 198484,
#   'risefall': '2',
#   'threeMonthEarnRate': -0.8936},
#  {'amonut': 1,
#   'changeRate': 0.01,
#   'changeVal': 5,
#   'etfTabCode': 6,
#   'itemcode': '385540',
#   'itemname': 'KBSTAR KIS종합채권(A-이상)액티브',
#   'marketSum': 3843,
#   'nav': 95587.0,
#   'nowVal': 95620,
#   'quant': 19,
#   'risefall': '2',
#   'threeMonthEarnRate': -2.7908},
#  {'amonut': 7868,
#   'changeRate': -2.49,
#   'changeVal': -245,
#   'etfTabCode': 2,
#   'itemcode': '400970',
#   'itemname': 'TIGER Fn메타버스',
#   'marketSum': 3825,
#   'nav': 9624.0,
#   'nowVal': 9610,
#   'quant': 814803,
#   'risefall': '5',
#   'threeMonthEarnRate': 0.8682},
#  {'amonut': 7613,
#   'changeRate': -1.15,
#   'changeVal': -110,
#   'etfTabCode': 2,
#   'itemcode': '401470',
#   'itemname': 'KODEX K-메타버스액티브',
#   'marketSum': 3811,
#   'nav': 9487.0,
#   'nowVal': 9480,
#   'quant': 801733,
#   'risefall': '5',
#   'threeMonthEarnRate': -4.5252},
#  {'amonut': 2680,
#   'changeRate': 0.02,
#   'changeVal': 25,
#   'etfTabCode': 6,
#   'itemcode': '148070',
#   'itemname': 'KOSEF 국고채10년',
#   'marketSum': 3400,
#   'nav': 111704.0,
#   'nowVal': 111830,
#   'quant': 23976,
#   'risefall': '2',
#   'threeMonthEarnRate': -3.716},
#  {'amonut': 150,
#   'changeRate': 0.04,
#   'changeVal': 20,
#   'etfTabCode': 6,
#   'itemcode': '272580',
#   'itemname': 'TIGER 단기채권액티브',
#   'marketSum': 3382,
#   'nav': 50478.0,
#   'nowVal': 50485,
#   'quant': 2980,
#   'risefall': '2',
#   'threeMonthEarnRate': 0.308},
#  {'amonut': 2756,
#   'changeRate': 1.37,
#   'changeVal': 150,
#   'etfTabCode': 4,
#   'itemcode': '379810',
#   'itemname': 'KODEX 미국나스닥100TR',
#   'marketSum': 3336,
#   'nav': 10897.0,
#   'nowVal': 11065,
#   'quant': 250746,
#   'risefall': '2',
#   'threeMonthEarnRate': -0.9529},
#  {'amonut': 3833,
#   'changeRate': 1.08,
#   'changeVal': 60,
#   'etfTabCode': 4,
#   'itemcode': '371160',
#   'itemname': 'TIGER 차이나항셍테크',
#   'marketSum': 3301,
#   'nav': 5641.0,
#   'nowVal': 5600,
#   'quant': 684234,
#   'risefall': '2',
#   'threeMonthEarnRate': -22.6257},
#  {'amonut': 2014,
#   'changeRate': 0.7,
#   'changeVal': 75,
#   'etfTabCode': 6,
#   'itemcode': '329750',
#   'itemname': 'TIGER 미국달러단기채권액티브',
#   'marketSum': 3190,
#   'nav': 10843.0,
#   'nowVal': 10850,
#   'quant': 186027,
#   'risefall': '2',
#   'threeMonthEarnRate': 4.8151},
#  {'amonut': 628,
#   'changeRate': 1.01,
#   'changeVal': 270,
#   'etfTabCode': 1,
#   'itemcode': '226490',
#   'itemname': 'KODEX 코스피',
#   'marketSum': 3154,
#   'nav': 26978.0,
#   'nowVal': 26960,
#   'quant': 23467,
#   'risefall': '2',
#   'threeMonthEarnRate': 0.9683},
#  {'amonut': 48848,
#   'changeRate': 0.03,
#   'changeVal': 30,
#   'etfTabCode': 6,
#   'itemcode': '385550',
#   'itemname': 'KBSTAR KIS단기종합채권(AA-이상)액티브',
#   'marketSum': 3136,
#   'nav': 100816.0,
#   'nowVal': 100830,
#   'quant': 484524,
#   'risefall': '2',
#   'threeMonthEarnRate': 0.3734},
#  {'amonut': 1307,
#   'changeRate': 0.67,
#   'changeVal': 330,
#   'etfTabCode': 4,
#   'itemcode': '143850',
#   'itemname': 'TIGER 미국S&P500선물(H)',
#   'marketSum': 3117,
#   'nav': 49689.0,
#   'nowVal': 49670,
#   'quant': 26368,
#   'risefall': '2',
#   'threeMonthEarnRate': -1.723},
#  {'amonut': 663,
#   'changeRate': 1.47,
#   'changeVal': 145,
#   'etfTabCode': 2,
#   'itemcode': '367770',
#   'itemname': 'KBSTAR Fn수소경제테마',
#   'marketSum': 2929,
#   'nav': 10000.0,
#   'nowVal': 9995,
#   'quant': 67288,
#   'risefall': '2',
#   'threeMonthEarnRate': 2.9215},
#  {'amonut': 0,
#   'changeRate': 0.82,
#   'changeVal': 115,
#   'etfTabCode': 1,
#   'itemcode': '332940',
#   'itemname': 'HANARO MSCI Korea TR',
#   'marketSum': 2844,
#   'nav': 14195.0,
#   'nowVal': 14150,
#   'quant': 51,
#   'risefall': '2',
#   'threeMonthEarnRate': -1.6124},
#  {'amonut': 289,
#   'changeRate': 1.42,
#   'changeVal': 165,
#   'etfTabCode': 2,
#   'itemcode': '290130',
#   'itemname': 'KBSTAR ESG사회책임투자',
#   'marketSum': 2844,
#   'nav': 11776.0,
#   'nowVal': 11775,
#   'quant': 24858,
#   'risefall': '2',
#   'threeMonthEarnRate': -0.3387},
#  {'amonut': 2559,
#   'changeRate': 0.76,
#   'changeVal': 65,
#   'etfTabCode': 2,
#   'itemcode': '364960',
#   'itemname': 'TIGER KRX BBIG K-뉴딜',
#   'marketSum': 2695,
#   'nav': 8571.0,
#   'nowVal': 8570,
#   'quant': 300961,
#   'risefall': '2',
#   'threeMonthEarnRate': -7.4498},
#  {'amonut': 8545,
#   'changeRate': -0.93,
#   'changeVal': -60,
#   'etfTabCode': 2,
#   'itemcode': '329200',
#   'itemname': 'TIGER 리츠부동산인프라',
#   'marketSum': 2569,
#   'nav': 6386.0,
#   'nowVal': 6390,
#   'quant': 1337718,
#   'risefall': '5',
#   'threeMonthEarnRate': 13.8648},
#  {'amonut': 17,
#   'changeRate': 1.67,
#   'changeVal': 145,
#   'etfTabCode': 2,
#   'itemcode': '213610',
#   'itemname': 'KODEX 삼성그룹밸류',
#   'marketSum': 2493,
#   'nav': 8844.0,
#   'nowVal': 8840,
#   'quant': 1954,
#   'risefall': '2',
#   'threeMonthEarnRate': 5.3222},
#  {'amonut': 5544,
#   'changeRate': -0.78,
#   'changeVal': -275,
#   'etfTabCode': 2,
#   'itemcode': '091160',
#   'itemname': 'KODEX 반도체',
#   'marketSum': 2489,
#   'nav': 35114.0,
#   'nowVal': 35055,
#   'quant': 157860,
#   'risefall': '5',
#   'threeMonthEarnRate': 2.3275},
#  {'amonut': 1,
#   'changeRate': 0.05,
#   'changeVal': 25,
#   'etfTabCode': 7,
#   'itemcode': '357870',
#   'itemname': 'TIGER CD금리투자KIS(합성)',
#   'marketSum': 2471,
#   'nav': 50788.0,
#   'nowVal': 50805,
#   'quant': 26,
#   'risefall': '2',
#   'threeMonthEarnRate': 0.3458},
#  {'amonut': 10808,
#   'changeRate': 2.61,
#   'changeVal': 195,
#   'etfTabCode': 2,
#   'itemcode': '091170',
#   'itemname': 'KODEX 은행',
#   'marketSum': 2400,
#   'nav': 7636.0,
#   'nowVal': 7680,
#   'quant': 1438903,
#   'risefall': '2',
#   'threeMonthEarnRate': 4.8032},
#  {'amonut': 362,
#   'changeRate': 1.38,
#   'changeVal': 135,
#   'etfTabCode': 4,
#   'itemcode': '394660',
#   'itemname': 'TIGER 글로벌자율주행&전기차SOLACTIVE',
#   'marketSum': 2398,
#   'nav': 9806.0,
#   'nowVal': 9910,
#   'quant': 36731,
#   'risefall': '2',
#   'threeMonthEarnRate': -7.3021},
#  {'amonut': 6840,
#   'changeRate': 1.72,
#   'changeVal': 215,
#   'etfTabCode': 2,
#   'itemcode': '325020',
#   'itemname': 'KODEX 배당가치',
#   'marketSum': 2350,
#   'nav': 12705.0,
#   'nowVal': 12705,
#   'quant': 541965,
#   'risefall': '2',
#   'threeMonthEarnRate': 3.2477},
#  {'amonut': 3127,
#   'changeRate': 0.0,
#   'changeVal': 0,
#   'etfTabCode': 2,
#   'itemcode': '228800',
#   'itemname': 'TIGER 여행레저',
#   'marketSum': 2311,
#   'nav': 4893.0,
#   'nowVal': 4885,
#   'quant': 642084,
#   'risefall': '3',
#   'threeMonthEarnRate': 16.7064},
#  {'amonut': 384,
#   'changeRate': -0.5,
#   'changeVal': -35,
#   'etfTabCode': 4,
#   'itemcode': '414780',
#   'itemname': 'TIGER 차이나과창판STAR50(합성)',
#   'marketSum': 2268,
#   'nav': 7070.0,
#   'nowVal': 6935,
#   'quant': 55487,
#   'risefall': '5',
#   'threeMonthEarnRate': -26.438},
#  {'amonut': 0,
#   'changeRate': 1.39,
#   'changeVal': 115,
#   'etfTabCode': 1,
#   'itemcode': '407310',
#   'itemname': 'HANARO 200 TOP10',
#   'marketSum': 2210,
#   'nav': 8400.0,
#   'nowVal': 8370,
#   'quant': 57,
#   'risefall': '2',
#   'threeMonthEarnRate': -0.1794},
#  {'amonut': 461,
#   'changeRate': 4.03,
#   'changeVal': 880,
#   'etfTabCode': 4,
#   'itemcode': '245710',
#   'itemname': 'KINDEX 베트남VN30(합성)',
#   'marketSum': 2112,
#   'nav': 22595.0,
#   'nowVal': 22715,
#   'quant': 20559,
#   'risefall': '2',
#   'threeMonthEarnRate': -5.8837},
#  {'amonut': 274,
#   'changeRate': 1.38,
#   'changeVal': 170,
#   'etfTabCode': 4,
#   'itemcode': '368590',
#   'itemname': 'KBSTAR 미국나스닥100',
#   'marketSum': 2105,
#   'nav': 12332.0,
#   'nowVal': 12530,
#   'quant': 22081,
#   'risefall': '2',
#   'threeMonthEarnRate': -0.9604},
#  {'amonut': 606,
#   'changeRate': -0.25,
#   'changeVal': -40,
#   'etfTabCode': 7,
#   'itemcode': '182480',
#   'itemname': 'TIGER 미국MSCI리츠(합성 H)',
#   'marketSum': 2013,
#   'nav': 15601.0,
#   'nowVal': 15785,
#   'quant': 38499,
#   'risefall': '5',
#   'threeMonthEarnRate': 6.2333},
#  {'amonut': 96,
#   'changeRate': 1.13,
#   'changeVal': 135,
#   'etfTabCode': 1,
#   'itemcode': '295040',
#   'itemname': 'SOL 200TR',
#   'marketSum': 2001,
#   'nav': 12157.0,
#   'nowVal': 12130,
#   'quant': 7980,
#   'risefall': '2',
#   'threeMonthEarnRate': -0.3738},
#  {'amonut': 7,
#   'changeRate': 0.01,
#   'changeVal': 10,
#   'etfTabCode': 7,
#   'itemcode': '423160',
#   'itemname': 'KODEX KOFR금리액티브(합성)',
#   'marketSum': 2000,
#   'nav': 100008.0,
#   'nowVal': 100020,
#   'quant': 72,
#   'risefall': '2',
#   'threeMonthEarnRate': None},
#  {'amonut': 2830,
#   'changeRate': -0.83,
#   'changeVal': -105,
#   'etfTabCode': 2,
#   'itemcode': '161510',
#   'itemname': 'ARIRANG 고배당주',
#   'marketSum': 1977,
#   'nav': 12551.0,
#   'nowVal': 12530,
#   'quant': 228260,
#   'risefall': '5',
#   'threeMonthEarnRate': 9.9958},
#  {'amonut': 0,
#   'changeRate': 0.0,
#   'changeVal': 0,
#   'etfTabCode': 6,
#   'itemcode': '390950',
#   'itemname': 'HANARO 단기채권액티브',
#   'marketSum': 1976,
#   'nav': 100621.0,
#   'nowVal': 100595,
#   'quant': 0,
#   'risefall': '3',
#   'threeMonthEarnRate': 0.2141},
#  {'amonut': 646,
#   'changeRate': -1.41,
#   'changeVal': -125,
#   'etfTabCode': 2,
#   'itemcode': '401170',
#   'itemname': 'KBSTAR iSelect메타버스',
#   'marketSum': 1966,
#   'nav': 8745.0,
#   'nowVal': 8745,
#   'quant': 73795,
#   'risefall': '5',
#   'threeMonthEarnRate': -5.5733},
#  {'amonut': 1609,
#   'changeRate': -1.33,
#   'changeVal': -170,
#   'etfTabCode': 5,
#   'itemcode': '132030',
#   'itemname': 'KODEX 골드선물(H)',
#   'marketSum': 1896,
#   'nav': 12684.0,
#   'nowVal': 12640,
#   'quant': 127111,
#   'risefall': '5',
#   'threeMonthEarnRate': 4.7852},
#  {'amonut': 1149,
#   'changeRate': 0.47,
#   'changeVal': 35,
#   'etfTabCode': 4,
#   'itemcode': '412770',
#   'itemname': 'TIGER 글로벌메타버스액티브',
#   'marketSum': 1889,
#   'nav': 7475.0,
#   'nowVal': 7530,
#   'quant': 153504,
#   'risefall': '2',
#   'threeMonthEarnRate': -11.0914},
#  {'amonut': 380,
#   'changeRate': 1.39,
#   'changeVal': 215,
#   'etfTabCode': 4,
#   'itemcode': '275980',
#   'itemname': 'TIGER 글로벌4차산업혁신기술(합성 H)',
#   'marketSum': 1822,
#   'nav': 15463.0,
#   'nowVal': 15730,
#   'quant': 24439,
#   'risefall': '2',
#   'threeMonthEarnRate': -6.7048},
#  {'amonut': 135,
#   'changeRate': -0.05,
#   'changeVal': -10,
#   'etfTabCode': 2,
#   'itemcode': '326240',
#   'itemname': 'KBSTAR IT플러스',
#   'marketSum': 1719,
#   'nav': 18203.0,
#   'nowVal': 18205,
#   'quant': 7471,
#   'risefall': '5',
#   'threeMonthEarnRate': -3.5292},
#  {'amonut': 895,
#   'changeRate': -0.42,
#   'changeVal': -110,
#   'etfTabCode': 4,
#   'itemcode': '168580',
#   'itemname': 'KINDEX 중국본토CSI300',
#   'marketSum': 1709,
#   'nav': 26573.0,
#   'nowVal': 26285,
#   'quant': 34203,
#   'risefall': '5',
#   'threeMonthEarnRate': -15.2649},
#  {'amonut': 467,
#   'changeRate': 0.61,
#   'changeVal': 60,
#   'etfTabCode': 4,
#   'itemcode': '192090',
#   'itemname': 'TIGER 차이나CSI300',
#   'marketSum': 1673,
#   'nav': 9887.0,
#   'nowVal': 9900,
#   'quant': 47302,
#   'risefall': '2',
#   'threeMonthEarnRate': -14.3604},
#  {'amonut': 41,
#   'changeRate': -0.07,
#   'changeVal': -5,
#   'etfTabCode': 4,
#   'itemcode': '415340',
#   'itemname': 'KODEX 차이나과창판STAR50(합성)',
#   'marketSum': 1645,
#   'nav': 7163.0,
#   'nowVal': 7000,
#   'quant': 5977,
#   'risefall': '5',
#   'threeMonthEarnRate': -27.0693},
#  {'amonut': 305,
#   'changeRate': 1.33,
#   'changeVal': 155,
#   'etfTabCode': 4,
#   'itemcode': '379780',
#   'itemname': 'KBSTAR 미국S&P500',
#   'marketSum': 1640,
#   'nav': 11651.0,
#   'nowVal': 11795,
#   'quant': 26104,
#   'risefall': '2',
#   'threeMonthEarnRate': 3.3215},
#  {'amonut': 2848,
#   'changeRate': 1.09,
#   'changeVal': 35,
#   'etfTabCode': 5,
#   'itemcode': '217770',
#   'itemname': 'TIGER 원유선물인버스(H)',
#   'marketSum': 1611,
#   'nav': 3259.0,
#   'nowVal': 3255,
#   'quant': 873807,
#   'risefall': '2',
#   'threeMonthEarnRate': -27.3958},
#  {'amonut': 13,
#   'changeRate': 1.08,
#   'changeVal': 290,
#   'etfTabCode': 1,
#   'itemcode': '302450',
#   'itemname': 'KBSTAR 코스피',
#   'marketSum': 1591,
#   'nav': 27186.0,
#   'nowVal': 27190,
#   'quant': 506,
#   'risefall': '2',
#   'threeMonthEarnRate': 1.116},
#  {'amonut': 438,
#   'changeRate': 0.18,
#   'changeVal': 20,
#   'etfTabCode': 7,
#   'itemcode': '329650',
#   'itemname': 'KODEX TRF3070',
#   'marketSum': 1535,
#   'nav': 10980.0,
#   'nowVal': 11040,
#   'quant': 39790,
#   'risefall': '2',
#   'threeMonthEarnRate': -1.6511},
#  {'amonut': 157,
#   'changeRate': 0.02,
#   'changeVal': 20,
#   'etfTabCode': 6,
#   'itemcode': '130730',
#   'itemname': 'KOSEF 단기자금',
#   'marketSum': 1533,
#   'nav': 101312.0,
#   'nowVal': 101305,
#   'quant': 1550,
#   'risefall': '2',
#   'threeMonthEarnRate': 0.3219},
#  {'amonut': 439,
#   'changeRate': 1.28,
#   'changeVal': 385,
#   'etfTabCode': 2,
#   'itemcode': '143860',
#   'itemname': 'TIGER 헬스케어',
#   'marketSum': 1524,
#   'nav': 30774.0,
#   'nowVal': 30480,
#   'quant': 14443,
#   'risefall': '2',
#   'threeMonthEarnRate': 4.3508},
#  {'amonut': 1391,
#   'changeRate': -0.82,
#   'changeVal': -70,
#   'etfTabCode': 2,
#   'itemcode': '228810',
#   'itemname': 'TIGER 미디어컨텐츠',
#   'marketSum': 1443,
#   'nav': 8539.0,
#   'nowVal': 8515,
#   'quant': 162868,
#   'risefall': '5',
#   'threeMonthEarnRate': 13.4387},
#  {'amonut': 477,
#   'changeRate': 1.55,
#   'changeVal': 355,
#   'etfTabCode': 2,
#   'itemcode': '138540',
#   'itemname': 'TIGER 현대차그룹+펀더멘털',
#   'marketSum': 1437,
#   'nav': 23414.0,
#   'nowVal': 23330,
#   'quant': 20534,
#   'risefall': '2',
#   'threeMonthEarnRate': 4.4439},
#  {'amonut': 1877,
#   'changeRate': -1.3,
#   'changeVal': -475,
#   'etfTabCode': 2,
#   'itemcode': '091230',
#   'itemname': 'TIGER 반도체',
#   'marketSum': 1418,
#   'nav': 35973.0,
#   'nowVal': 36000,
#   'quant': 52148,
#   'risefall': '5',
#   'threeMonthEarnRate': 3.0048},
#  {'amonut': 607,
#   'changeRate': 0.69,
#   'changeVal': 140,
#   'etfTabCode': 4,
#   'itemcode': '219480',
#   'itemname': 'KODEX 미국S&P500선물(H)',
#   'marketSum': 1359,
#   'nav': 20440.0,
#   'nowVal': 20435,
#   'quant': 29827,
#   'risefall': '2',
#   'threeMonthEarnRate': -1.8618},
#  {'amonut': 6479,
#   'changeRate': 1.3,
#   'changeVal': 60,
#   'etfTabCode': 5,
#   'itemcode': '271050',
#   'itemname': 'KODEX WTI원유선물인버스(H)',
#   'marketSum': 1345,
#   'nav': 4658.0,
#   'nowVal': 4670,
#   'quant': 1387680,
#   'risefall': '2',
#   'threeMonthEarnRate': -27.3444},
#  {'amonut': 1506,
#   'changeRate': 1.53,
#   'changeVal': 85,
#   'etfTabCode': 4,
#   'itemcode': '372330',
#   'itemname': 'KODEX 차이나항셍테크',
#   'marketSum': 1324,
#   'nav': 5652.0,
#   'nowVal': 5645,
#   'quant': 267739,
#   'risefall': '2',
#   'threeMonthEarnRate': -22.3464},
#  {'amonut': 24,
#   'changeRate': 1.83,
#   'changeVal': 140,
#   'etfTabCode': 2,
#   'itemcode': '150460',
#   'itemname': 'TIGER 중국소비테마',
#   'marketSum': 1300,
#   'nav': 7829.0,
#   'nowVal': 7795,
#   'quant': 3112,
#   'risefall': '2',
#   'threeMonthEarnRate': 12.7192},
#  {'amonut': 27,
#   'changeRate': -0.04,
#   'changeVal': -5,
#   'etfTabCode': 1,
#   'itemcode': '270810',
#   'itemname': 'KBSTAR 코스닥150',
#   'marketSum': 1297,
#   'nav': 12348.0,
#   'nowVal': 12190,
#   'quant': 2241,
#   'risefall': '5',
#   'threeMonthEarnRate': 2.1702},
#  {'amonut': 443,
#   'changeRate': 1.21,
#   'changeVal': 90,
#   'etfTabCode': 4,
#   'itemcode': '411420',
#   'itemname': 'KODEX 미국메타버스나스닥액티브',
#   'marketSum': 1275,
#   'nav': 7334.0,
#   'nowVal': 7500,
#   'quant': 59447,
#   'risefall': '2',
#   'threeMonthEarnRate': -8.1216},
#  {'amonut': 4,
#   'changeRate': 1.0,
#   'changeVal': 420,
#   'etfTabCode': 1,
#   'itemcode': '332930',
#   'itemname': 'HANARO 200TR',
#   'marketSum': 1271,
#   'nav': 42517.0,
#   'nowVal': 42375,
#   'quant': 107,
#   'risefall': '2',
#   'threeMonthEarnRate': -0.4391},
#  {'amonut': 6697,
#   'changeRate': 1.7,
#   'changeVal': 105,
#   'etfTabCode': 4,
#   'itemcode': '409820',
#   'itemname': 'KODEX 미국나스닥100레버리지(합성 H)',
#   'marketSum': 1269,
#   'nav': 6076.0,
#   'nowVal': 6280,
#   'quant': 1075244,
#   'risefall': '2',
#   'threeMonthEarnRate': -14.2362},
#  {'amonut': 1390,
#   'changeRate': -0.04,
#   'changeVal': -5,
#   'etfTabCode': 1,
#   'itemcode': '232080',
#   'itemname': 'TIGER 코스닥150',
#   'marketSum': 1261,
#   'nav': 12666.0,
#   'nowVal': 12485,
#   'quant': 111504,
#   'risefall': '5',
#   'threeMonthEarnRate': 2.0408},
#  {'amonut': 634,
#   'changeRate': 1.46,
#   'changeVal': 260,
#   'etfTabCode': 4,
#   'itemcode': '309230',
#   'itemname': 'KINDEX 미국WideMoat가치주',
#   'marketSum': 1231,
#   'nav': 17888.0,
#   'nowVal': 18100,
#   'quant': 35177,
#   'risefall': '2',
#   'threeMonthEarnRate': 2.8835},
#  {'amonut': 2014,
#   'changeRate': -1.27,
#   'changeVal': -215,
#   'etfTabCode': 5,
#   'itemcode': '261220',
#   'itemname': 'KODEX WTI원유선물(H)',
#   'marketSum': 1203,
#   'nav': 16724.0,
#   'nowVal': 16710,
#   'quant': 120663,
#   'risefall': '5',
#   'threeMonthEarnRate': 24.7696},
#  {'amonut': 4784,
#   'changeRate': 2.47,
#   'changeVal': 240,
#   'etfTabCode': 4,
#   'itemcode': '423920',
#   'itemname': 'TIGER 미국필라델피아반도체레버리지(합성)',
#   'marketSum': 1182,
#   'nav': 9655.0,
#   'nowVal': 9940,
#   'quant': 487110,
#   'risefall': '2',
#   'threeMonthEarnRate': None},
#  {'amonut': 74,
#   'changeRate': -0.23,
#   'changeVal': -130,
#   'etfTabCode': 6,
#   'itemcode': '114260',
#   'itemname': 'KODEX 국고채3년',
#   'marketSum': 1182,
#   'nav': 56425.0,
#   'nowVal': 56375,
#   'quant': 1315,
#   'risefall': '5',
#   'threeMonthEarnRate': -1.2064},
#  {'amonut': 116,
#   'changeRate': -0.52,
#   'changeVal': -60,
#   'etfTabCode': 3,
#   'itemcode': '278240',
#   'itemname': 'KBSTAR 코스닥150선물레버리지',
#   'marketSum': 1161,
#   'nav': 11501.0,
#   'nowVal': 11440,
#   'quant': 10291,
#   'risefall': '5',
#   'threeMonthEarnRate': 5.553},
#  {'amonut': 30790,
#   'changeRate': -2.12,
#   'changeVal': -60,
#   'etfTabCode': 3,
#   'itemcode': '252710',
#   'itemname': 'TIGER 200선물인버스2X',
#   'marketSum': 1147,
#   'nav': 2764.0,
#   'nowVal': 2770,
#   'quant': 10968539,
#   'risefall': '5',
#   'threeMonthEarnRate': -0.5273},
#  {'amonut': 48,
#   'changeRate': 0.02,
#   'changeVal': 25,
#   'etfTabCode': 6,
#   'itemcode': '273140',
#   'itemname': 'KODEX 단기변동금리부채권액티브',
#   'marketSum': 1146,
#   'nav': 103463.0,
#   'nowVal': 103460,
#   'quant': 467,
#   'risefall': '2',
#   'threeMonthEarnRate': 0.3687},
#  {'amonut': 636,
#   'changeRate': 1.03,
#   'changeVal': 140,
#   'etfTabCode': 1,
#   'itemcode': '328370',
#   'itemname': 'ARIRANG 코스피TR',
#   'marketSum': 1128,
#   'nav': 13749.0,
#   'nowVal': 13750,
#   'quant': 46513,
#   'risefall': '2',
#   'threeMonthEarnRate': 1.4914},
#  {'amonut': 4,
#   'changeRate': 0.17,
#   'changeVal': 175,
#   'etfTabCode': 3,
#   'itemcode': '282000',
#   'itemname': 'KBSTAR 국고채3년선물인버스',
#   'marketSum': 1125,
#   'nav': 103390.0,
#   'nowVal': 103405,
#   'quant': 48,
#   'risefall': '2',
#   'threeMonthEarnRate': 1.5144},
#  {'amonut': 2207,
#   'changeRate': 1.72,
#   'changeVal': 145,
#   'etfTabCode': 2,
#   'itemcode': '395750',
#   'itemname': 'ARIRANG ESG가치주액티브',
#   'marketSum': 1079,
#   'nav': 8569.0,
#   'nowVal': 8595,
#   'quant': 259423,
#   'risefall': '2',
#   'threeMonthEarnRate': 1.1196},
#  {'amonut': 470,
#   'changeRate': 0.4,
#   'changeVal': 315,
#   'etfTabCode': 6,
#   'itemcode': '385560',
#   'itemname': 'KBSTAR KIS국고채30년Enhanced',
#   'marketSum': 1052,
#   'nav': 79007.0,
#   'nowVal': 79130,
#   'quant': 5971,
#   'risefall': '2',
#   'threeMonthEarnRate': -14.7375},
#  {'amonut': 1618,
#   'changeRate': 4.11,
#   'changeVal': 120,
#   'etfTabCode': 2,
#   'itemcode': '139220',
#   'itemname': 'TIGER 200 건설',
#   'marketSum': 1049,
#   'nav': 3036.0,
#   'nowVal': 3040,
#   'quant': 539374,
#   'risefall': '2',
#   'threeMonthEarnRate': 14.5348},
#  {'amonut': 736,
#   'changeRate': 0.98,
#   'changeVal': 125,
#   'etfTabCode': 4,
#   'itemcode': '400570',
#   'itemname': 'KODEX 유럽탄소배출권선물ICE(H)',
#   'marketSum': 1045,
#   'nav': 12890.0,
#   'nowVal': 12900,
#   'quant': 57291,
#   'risefall': '2',
#   'threeMonthEarnRate': -8.6195},
#  {'amonut': 219,
#   'changeRate': -1.04,
#   'changeVal': -100,
#   'etfTabCode': 2,
#   'itemcode': '367760',
#   'itemname': 'KBSTAR Fn5G테크',
#   'marketSum': 1039,
#   'nav': 9486.0,
#   'nowVal': 9490,
#   'quant': 23129,
#   'risefall': '5',
#   'threeMonthEarnRate': 2.2128},
#  {'amonut': 27,
#   'changeRate': 1.18,
#   'changeVal': 90,
#   'etfTabCode': 2,
#   'itemcode': '395170',
#   'itemname': 'KODEX Fn Top10동일가중',
#   'marketSum': 1037,
#   'nav': 7768.0,
#   'nowVal': 7740,
#   'quant': 3585,
#   'risefall': '2',
#   'threeMonthEarnRate': 0.7843},
#  {'amonut': 2,
#   'changeRate': -0.33,
#   'changeVal': -290,
#   'etfTabCode': 6,
#   'itemcode': '363570',
#   'itemname': 'KODEX 장기종합채권(AA-이상)액티브KAP',
#   'marketSum': 1022,
#   'nav': 88245.0,
#   'nowVal': 87980,
#   'quant': 28,
#   'risefall': '5',
#   'threeMonthEarnRate': -4.9379},
#  {'amonut': 0,
#   'changeRate': 0.0,
#   'changeVal': 0,
#   'etfTabCode': 6,
#   'itemcode': '363510',
#   'itemname': 'SOL KIS단기통안채',
#   'marketSum': 1018,
#   'nav': 100864.0,
#   'nowVal': 100850,
#   'quant': 0,
#   'risefall': '3',
#   'threeMonthEarnRate': 0.2086},
#  {'amonut': 530,
#   'changeRate': 0.61,
#   'changeVal': 130,
#   'etfTabCode': 4,
#   'itemcode': '245340',
#   'itemname': 'TIGER 미국다우존스30',
#   'marketSum': 975,
#   'nav': 21228.0,
#   'nowVal': 21380,
#   'quant': 25053,
#   'risefall': '2',
#   'threeMonthEarnRate': 4.7139},
#  {'amonut': 12,
#   'changeRate': 0.22,
#   'changeVal': 115,
#   'etfTabCode': 6,
#   'itemcode': '176950',
#   'itemname': 'KODEX 국채선물10년인버스',
#   'marketSum': 939,
#   'nav': 51235.0,
#   'nowVal': 51285,
#   'quant': 250,
#   'risefall': '2',
#   'threeMonthEarnRate': 3.9934},
#  {'amonut': 12,
#   'changeRate': 1.11,
#   'changeVal': 240,
#   'etfTabCode': 1,
#   'itemcode': '332500',
#   'itemname': 'KINDEX 200TR',
#   'marketSum': 936,
#   'nav': 21815.0,
#   'nowVal': 21765,
#   'quant': 569,
#   'risefall': '2',
#   'threeMonthEarnRate': -0.5085},
#  {'amonut': 102,
#   'changeRate': 1.34,
#   'changeVal': 120,
#   'etfTabCode': 4,
#   'itemcode': '245360',
#   'itemname': 'TIGER 차이나HSCEI',
#   'marketSum': 932,
#   'nav': 9085.0,
#   'nowVal': 9050,
#   'quant': 11312,
#   'risefall': '2',
#   'threeMonthEarnRate': -14.2583},
#  {'amonut': 32,
#   'changeRate': 0.94,
#   'changeVal': 255,
#   'etfTabCode': 1,
#   'itemcode': '277630',
#   'itemname': 'TIGER 코스피',
#   'marketSum': 930,
#   'nav': 27428.0,
#   'nowVal': 27360,
#   'quant': 1192,
#   'risefall': '2',
#   'threeMonthEarnRate': 1.4465},
#  {'amonut': 8560,
#   'changeRate': 1.92,
#   'changeVal': 265,
#   'etfTabCode': 3,
#   'itemcode': '267770',
#   'itemname': 'TIGER 200선물레버리지',
#   'marketSum': 927,
#   'nav': 14078.0,
#   'nowVal': 14045,
#   'quant': 620903,
#   'risefall': '2',
#   'threeMonthEarnRate': -2.0264},
#  {'amonut': 1031,
#   'changeRate': -0.25,
#   'changeVal': -30,
#   'etfTabCode': 4,
#   'itemcode': '283580',
#   'itemname': 'KODEX 차이나CSI300',
#   'marketSum': 914,
#   'nav': 12125.0,
#   'nowVal': 12020,
#   'quant': 85737,
#   'risefall': '5',
#   'threeMonthEarnRate': -14.841},
#  {'amonut': 2094,
#   'changeRate': 0.78,
#   'changeVal': 165,
#   'etfTabCode': 4,
#   'itemcode': '204480',
#   'itemname': 'TIGER 차이나CSI300레버리지(합성)',
#   'marketSum': 911,
#   'nav': 21698.0,
#   'nowVal': 21390,
#   'quant': 97514,
#   'risefall': '2',
#   'threeMonthEarnRate': -29.567},
#  {'amonut': 34,
#   'changeRate': 0.79,
#   'changeVal': 120,
#   'etfTabCode': 2,
#   'itemcode': '322400',
#   'itemname': 'HANARO e커머스',
#   'marketSum': 911,
#   'nav': 15301.0,
#   'nowVal': 15305,
#   'quant': 2263,
#   'risefall': '2',
#   'threeMonthEarnRate': 4.1016},
#  {'amonut': 1602,
#   'changeRate': 0.67,
#   'changeVal': 75,
#   'etfTabCode': 7,
#   'itemcode': '261240',
#   'itemname': 'KODEX 미국달러선물',
#   'marketSum': 899,
#   'nav': 11239.0,
#   'nowVal': 11250,
#   'quant': 142755,
#   'risefall': '2',
#   'threeMonthEarnRate': 5.0775},
#  {'amonut': 442,
#   'changeRate': -0.07,
#   'changeVal': -45,
#   'etfTabCode': 6,
#   'itemcode': '152380',
#   'itemname': 'KODEX 국채선물10년',
#   'marketSum': 898,
#   'nav': 64222.0,
#   'nowVal': 64215,
#   'quant': 6899,
#   'risefall': '5',
#   'threeMonthEarnRate': -3.7736},
#  {'amonut': 7808,
#   'changeRate': 1.79,
#   'changeVal': 125,
#   'etfTabCode': 2,
#   'itemcode': '364970',
#   'itemname': 'TIGER KRX바이오K-뉴딜',
#   'marketSum': 891,
#   'nav': 7099.0,
#   'nowVal': 7100,
#   'quant': 1108901,
#   'risefall': '2',
#   'threeMonthEarnRate': 6.6462},
#  {'amonut': 579,
#   'changeRate': 0.25,
#   'changeVal': 30,
#   'etfTabCode': 6,
#   'itemcode': '305080',
#   'itemname': 'TIGER 미국채10년선물',
#   'marketSum': 864,
#   'nav': 11857.0,
#   'nowVal': 11830,
#   'quant': 49165,
#   'risefall': '2',
#   'threeMonthEarnRate': -1.2139},
#  {'amonut': 2228,
#   'changeRate': 2.61,
#   'changeVal': 85,
#   'etfTabCode': 2,
#   'itemcode': '117700',
#   'itemname': 'KODEX 건설',
#   'marketSum': 850,
#   'nav': 3358.0,
#   'nowVal': 3345,
#   'quant': 673555,
#   'risefall': '2',
#   'threeMonthEarnRate': 12.4573},
#  {'amonut': 779,
#   'changeRate': 0.96,
#   'changeVal': 160,
#   'etfTabCode': 4,
#   'itemcode': '304940',
#   'itemname': 'KODEX 미국나스닥100선물(H)',
#   'marketSum': 847,
#   'nav': 16488.0,
#   'nowVal': 16765,
#   'quant': 46653,
#   'risefall': '2',
#   'threeMonthEarnRate': -5.8941},
#  {'amonut': 13,
#   'changeRate': 1.17,
#   'changeVal': 150,
#   'etfTabCode': 2,
#   'itemcode': '337160',
#   'itemname': 'KODEX 200ESG',
#   'marketSum': 841,
#   'nav': 12936.0,
#   'nowVal': 12940,
#   'quant': 1024,
#   'risefall': '2',
#   'threeMonthEarnRate': -0.1158},
#  {'amonut': 3073,
#   'changeRate': 1.56,
#   'changeVal': 50,
#   'etfTabCode': 2,
#   'itemcode': '139230',
#   'itemname': 'TIGER 200 중공업',
#   'marketSum': 832,
#   'nav': 3253.0,
#   'nowVal': 3255,
#   'quant': 951810,
#   'risefall': '2',
#   'threeMonthEarnRate': 20.1117},
#  {'amonut': 66,
#   'changeRate': 2.15,
#   'changeVal': 215,
#   'etfTabCode': 2,
#   'itemcode': '139280',
#   'itemname': 'TIGER 경기방어',
#   'marketSum': 831,
#   'nav': 10231.0,
#   'nowVal': 10230,
#   'quant': 6570,
#   'risefall': '2',
#   'threeMonthEarnRate': 9.902},
#  {'amonut': 43,
#   'changeRate': -0.02,
#   'changeVal': -25,
#   'etfTabCode': 6,
#   'itemcode': '272560',
#   'itemname': 'KBSTAR 단기국공채액티브',
#   'marketSum': 828,
#   'nav': 102468.0,
#   'nowVal': 102465,
#   'quant': 426,
#   'risefall': '5',
#   'threeMonthEarnRate': 0.0976},
#  {'amonut': 1,
#   'changeRate': 0.72,
#   'changeVal': 105,
#   'etfTabCode': 2,
#   'itemcode': '325010',
#   'itemname': 'KODEX Fn성장',
#   'marketSum': 827,
#   'nav': 14775.0,
#   'nowVal': 14770,
#   'quant': 122,
#   'risefall': '2',
#   'threeMonthEarnRate': -0.7057},
#  {'amonut': 5727,
#   'changeRate': 3.99,
#   'changeVal': 115,
#   'etfTabCode': 2,
#   'itemcode': '228790',
#   'itemname': 'TIGER 화장품',
#   'marketSum': 815,
#   'nav': 2993.0,
#   'nowVal': 2995,
#   'quant': 1926875,
#   'risefall': '2',
#   'threeMonthEarnRate': 19.9584},
#  {'amonut': 1565,
#   'changeRate': -2.29,
#   'changeVal': -110,
#   'etfTabCode': 5,
#   'itemcode': '144600',
#   'itemname': 'KODEX 은선물(H)',
#   'marketSum': 808,
#   'nav': 4728.0,
#   'nowVal': 4700,
#   'quant': 332002,
#   'risefall': '5',
#   'threeMonthEarnRate': 1.5839},
#  {'amonut': 0,
#   'changeRate': 0.46,
#   'changeVal': 55,
#   'etfTabCode': 2,
#   'itemcode': '363580',
#   'itemname': 'KODEX 200IT TR',
#   'marketSum': 808,
#   'nav': 12048.0,
#   'nowVal': 12055,
#   'quant': 36,
#   'risefall': '2',
#   'threeMonthEarnRate': -4.4206},
#  {'amonut': 1,
#   'changeRate': 0.14,
#   'changeVal': 75,
#   'etfTabCode': 6,
#   'itemcode': '397410',
#   'itemname': 'KBSTAR 국채선물5년추종인버스',
#   'marketSum': 807,
#   'nav': 52897.0,
#   'nowVal': 52925,
#   'quant': 24,
#   'risefall': '2',
#   'threeMonthEarnRate': 2.2936},
#  {'amonut': 1334,
#   'changeRate': 0.45,
#   'changeVal': 45,
#   'etfTabCode': 2,
#   'itemcode': '417630',
#   'itemname': 'TIGER KEDI혁신기업ESG30',
#   'marketSum': 771,
#   'nav': 10033.0,
#   'nowVal': 10010,
#   'quant': 133754,
#   'risefall': '2',
#   'threeMonthEarnRate': None},
#  {'amonut': 759,
#   'changeRate': 0.49,
#   'changeVal': 60,
#   'etfTabCode': 2,
#   'itemcode': '157490',
#   'itemname': 'TIGER 소프트웨어',
#   'marketSum': 770,
#   'nav': 12206.0,
#   'nowVal': 12185,
#   'quant': 62555,
#   'risefall': '2',
#   'threeMonthEarnRate': -8.8599},
#  {'amonut': 301,
#   'changeRate': 1.39,
#   'changeVal': 400,
#   'etfTabCode': 4,
#   'itemcode': '225040',
#   'itemname': 'TIGER 미국S&P500레버리지(합성 H)',
#   'marketSum': 770,
#   'nav': 28594.0,
#   'nowVal': 29150,
#   'quant': 10401,
#   'risefall': '2',
#   'threeMonthEarnRate': -6.2908},
#  {'amonut': 1,
#   'changeRate': -0.24,
#   'changeVal': -125,
#   'etfTabCode': 6,
#   'itemcode': '298340',
#   'itemname': 'ARIRANG 국채선물3년',
#   'marketSum': 760,
#   'nav': 52078.0,
#   'nowVal': 52075,
#   'quant': 24,
#   'risefall': '5',
#   'threeMonthEarnRate': -1.0802},
#  {'amonut': 91,
#   'changeRate': 0.9,
#   'changeVal': 115,
#   'etfTabCode': 4,
#   'itemcode': '195930',
#   'itemname': 'TIGER 유로스탁스50(합성 H)',
#   'marketSum': 734,
#   'nav': 12784.0,
#   'nowVal': 12870,
#   'quant': 7212,
#   'risefall': '2',
#   'threeMonthEarnRate': -7.9726},
#  {'amonut': 0,
#   'changeRate': 1.31,
#   'changeVal': 110,
#   'etfTabCode': 1,
#   'itemcode': '411540',
#   'itemname': 'SOL 200 Top10',
#   'marketSum': 733,
#   'nav': 8590.0,
#   'nowVal': 8520,
#   'quant': 13,
#   'risefall': '2',
#   'threeMonthEarnRate': -0.9423},
#  {'amonut': 498,
#   'changeRate': 0.0,
#   'changeVal': 0,
#   'etfTabCode': 4,
#   'itemcode': '195980',
#   'itemname': 'ARIRANG 신흥국MSCI(합성 H)',
#   'marketSum': 723,
#   'nav': 9934.0,
#   'nowVal': 9875,
#   'quant': 50433,
#   'risefall': '3',
#   'threeMonthEarnRate': -12.9956},
#  {'amonut': 470,
#   'changeRate': 0.09,
#   'changeVal': 80,
#   'etfTabCode': 6,
#   'itemcode': '365780',
#   'itemname': 'KINDEX 국고채10년',
#   'marketSum': 714,
#   'nav': 88749.0,
#   'nowVal': 88845,
#   'quant': 5305,
#   'risefall': '2',
#   'threeMonthEarnRate': -3.6368},
#  {'amonut': 1246,
#   'changeRate': 0.64,
#   'changeVal': 55,
#   'etfTabCode': 4,
#   'itemcode': '414270',
#   'itemname': 'KINDEX G2전기차&자율주행액티브',
#   'marketSum': 712,
#   'nav': 8630.0,
#   'nowVal': 8680,
#   'quant': 143912,
#   'risefall': '2',
#   'threeMonthEarnRate': None},
#  {'amonut': 39,
#   'changeRate': 0.59,
#   'changeVal': 105,
#   'etfTabCode': 4,
#   'itemcode': '298770',
#   'itemname': 'KODEX 한국대만IT프리미어',
#   'marketSum': 701,
#   'nav': 17940.0,
#   'nowVal': 17985,
#   'quant': 2217,
#   'risefall': '2',
#   'threeMonthEarnRate': -9.8791},
#  {'amonut': 230,
#   'changeRate': -0.19,
#   'changeVal': -20,
#   'etfTabCode': 2,
#   'itemcode': '385510',
#   'itemname': 'KODEX K-신재생에너지액티브',
#   'marketSum': 690,
#   'nav': 10457.0,
#   'nowVal': 10455,
#   'quant': 22147,
#   'risefall': '5',
#   'threeMonthEarnRate': 11.7428},
#  {'amonut': 272,
#   'changeRate': -0.38,
#   'changeVal': -40,
#   'etfTabCode': 2,
#   'itemcode': '385520',
#   'itemname': 'KODEX K-미래차액티브',
#   'marketSum': 690,
#   'nav': 10451.0,
#   'nowVal': 10450,
#   'quant': 26168,
#   'risefall': '5',
#   'threeMonthEarnRate': 4.743},
#  {'amonut': 73,
#   'changeRate': 1.32,
#   'changeVal': 160,
#   'etfTabCode': 2,
#   'itemcode': '266160',
#   'itemname': 'KBSTAR 고배당',
#   'marketSum': 689,
#   'nav': 12330.0,
#   'nowVal': 12300,
#   'quant': 6033,
#   'risefall': '2',
#   'threeMonthEarnRate': 2.204},
#  {'amonut': 96,
#   'changeRate': 0.33,
#   'changeVal': 30,
#   'etfTabCode': 2,
#   'itemcode': '388280',
#   'itemname': 'KBSTAR Fn컨택트대표',
#   'marketSum': 684,
#   'nav': 9146.0,
#   'nowVal': 9150,
#   'quant': 10585,
#   'risefall': '2',
#   'threeMonthEarnRate': 12.4235},
#  {'amonut': 541,
#   'changeRate': 0.55,
#   'changeVal': 45,
#   'etfTabCode': 4,
#   'itemcode': '419430',
#   'itemname': 'KODEX 차이나2차전지MSCI(합성)',
#   'marketSum': 652,
#   'nav': 8184.0,
#   'nowVal': 8155,
#   'quant': 66330,
#   'risefall': '2',
#   'threeMonthEarnRate': None},
#  {'amonut': 409,
#   'changeRate': 1.16,
#   'changeVal': 215,
#   'etfTabCode': 4,
#   'itemcode': '200250',
#   'itemname': 'KOSEF 인도Nifty50(합성)',
#   'marketSum': 649,
#   'nav': 19043.0,
#   'nowVal': 18815,
#   'quant': 21880,
#   'risefall': '2',
#   'threeMonthEarnRate': 2.1416},
#  {'amonut': 36,
#   'changeRate': 0.55,
#   'changeVal': 100,
#   'etfTabCode': 4,
#   'itemcode': '174360',
#   'itemname': 'KBSTAR 중국본토대형주CSI100',
#   'marketSum': 642,
#   'nav': 18442.0,
#   'nowVal': 18350,
#   'quant': 1969,
#   'risefall': '2',
#   'threeMonthEarnRate': -13.7524},
#  {'amonut': 302,
#   'changeRate': -0.07,
#   'changeVal': -70,
#   'etfTabCode': 6,
#   'itemcode': '114820',
#   'itemname': 'TIGER 국채3년',
#   'marketSum': 641,
#   'nav': 106764.0,
#   'nowVal': 106780,
#   'quant': 2828,
#   'risefall': '5',
#   'threeMonthEarnRate': -1.1756},
#  {'amonut': 235,
#   'changeRate': 0.55,
#   'changeVal': 55,
#   'etfTabCode': 4,
#   'itemcode': '390390',
#   'itemname': 'KODEX 미국반도체MV',
#   'marketSum': 640,
#   'nav': 9870.0,
#   'nowVal': 10080,
#   'quant': 23549,
#   'risefall': '2',
#   'threeMonthEarnRate': -7.2618},
#  {'amonut': 6197,
#   'changeRate': -0.9,
#   'changeVal': -45,
#   'etfTabCode': 3,
#   'itemcode': '123310',
#   'itemname': 'TIGER 인버스',
#   'marketSum': 636,
#   'nav': 4960.0,
#   'nowVal': 4965,
#   'quant': 1240228,
#   'risefall': '5',
#   'threeMonthEarnRate': 0.2},
#  {'amonut': 189,
#   'changeRate': 2.51,
#   'changeVal': 240,
#   'etfTabCode': 4,
#   'itemcode': '391600',
#   'itemname': 'KINDEX 미국친환경그린테마INDXX',
#   'marketSum': 627,
#   'nav': 9671.0,
#   'nowVal': 9790,
#   'quant': 19645,
#   'risefall': '2',
#   'threeMonthEarnRate': 12.6179},
#  {'amonut': 70,
#   'changeRate': -0.92,
#   'changeVal': -95,
#   'etfTabCode': 2,
#   'itemcode': '387280',
#   'itemname': 'TIGER 퓨처모빌리티액티브',
#   'marketSum': 611,
#   'nav': 10231.0,
#   'nowVal': 10200,
#   'quant': 6933,
#   'risefall': '5',
#   'threeMonthEarnRate': 0.8317},
#  {'amonut': 47,
#   'changeRate': 0.04,
#   'changeVal': 20,
#   'etfTabCode': 6,
#   'itemcode': '302190',
#   'itemname': 'TIGER 중장기국채',
#   'marketSum': 608,
#   'nav': 49007.0,
#   'nowVal': 49020,
#   'quant': 980,
#   'risefall': '2',
#   'threeMonthEarnRate': -2.5652},
#  {'amonut': 24,
#   'changeRate': 1.04,
#   'changeVal': 195,
#   'etfTabCode': 1,
#   'itemcode': '310960',
#   'itemname': 'TIGER 200TR',
#   'marketSum': 589,
#   'nav': 19032.0,
#   'nowVal': 18990,
#   'quant': 1278,
#   'risefall': '2',
#   'threeMonthEarnRate': -0.5819},
#  {'amonut': 370,
#   'changeRate': 1.84,
#   'changeVal': 280,
#   'etfTabCode': 4,
#   'itemcode': '099140',
#   'itemname': 'KODEX 차이나H',
#   'marketSum': 574,
#   'nav': 15638.0,
#   'nowVal': 15500,
#   'quant': 24034,
#   'risefall': '2',
#   'threeMonthEarnRate': -14.9959},
#  {'amonut': 154,
#   'changeRate': 1.03,
#   'changeVal': 85,
#   'etfTabCode': 4,
#   'itemcode': '396510',
#   'itemname': 'TIGER 차이나클린에너지SOLACTIVE',
#   'marketSum': 564,
#   'nav': 8410.0,
#   'nowVal': 8350,
#   'quant': 18513,
#   'risefall': '2',
#   'threeMonthEarnRate': -13.6364},
#  {'amonut': 11268,
#   'changeRate': 2.93,
#   'changeVal': 285,
#   'etfTabCode': 4,
#   'itemcode': '418660',
#   'itemname': 'TIGER 미국나스닥100레버리지(합성)',
#   'marketSum': 561,
#   'nav': 9693.0,
#   'nowVal': 10020,
#   'quant': 1143518,
#   'risefall': '2',
#   'threeMonthEarnRate': None},
#  {'amonut': 106,
#   'changeRate': 0.84,
#   'changeVal': 60,
#   'etfTabCode': 4,
#   'itemcode': '371470',
#   'itemname': 'TIGER 차이나바이오테크SOLACTIVE',
#   'marketSum': 559,
#   'nav': 7253.0,
#   'nowVal': 7235,
#   'quant': 14806,
#   'risefall': '2',
#   'threeMonthEarnRate': -15.737},
#  {'amonut': 63,
#   'changeRate': 1.69,
#   'changeVal': 170,
#   'etfTabCode': 4,
#   'itemcode': '387270',
#   'itemname': 'TIGER 글로벌BBIG액티브',
#   'marketSum': 554,
#   'nav': 10051.0,
#   'nowVal': 10200,
#   'quant': 6151,
#   'risefall': '2',
#   'threeMonthEarnRate': -4.6578},
#  {'amonut': 130,
#   'changeRate': 1.32,
#   'changeVal': 220,
#   'etfTabCode': 4,
#   'itemcode': '354350',
#   'itemname': 'HANARO 글로벌럭셔리S&P(합성)',
#   'marketSum': 543,
#   'nav': 16665.0,
#   'nowVal': 16915,
#   'quant': 7819,
#   'risefall': '2',
#   'threeMonthEarnRate': -7.0435},
#  {'amonut': 3547,
#   'changeRate': 2.36,
#   'changeVal': 220,
#   'etfTabCode': 2,
#   'itemcode': '117680',
#   'itemname': 'KODEX 철강',
#   'marketSum': 542,
#   'nav': 9562.0,
#   'nowVal': 9560,
#   'quant': 371908,
#   'risefall': '2',
#   'threeMonthEarnRate': 21.4195},
#  {'amonut': 33,
#   'changeRate': -0.15,
#   'changeVal': -155,
#   'etfTabCode': 6,
#   'itemcode': '136340',
#   'itemname': 'KBSTAR 중기우량회사채',
#   'marketSum': 533,
#   'nav': 102586.0,
#   'nowVal': 102555,
#   'quant': 327,
#   'risefall': '5',
#   'threeMonthEarnRate': -1.1359},
#  {'amonut': 521,
#   'changeRate': 3.18,
#   'changeVal': 345,
#   'etfTabCode': 4,
#   'itemcode': '256440',
#   'itemname': 'KINDEX 인도네시아MSCI(합성)',
#   'marketSum': 526,
#   'nav': 11218.0,
#   'nowVal': 11195,
#   'quant': 47342,
#   'risefall': '2',
#   'threeMonthEarnRate': 16.7294},
#  {'amonut': 2668,
#   'changeRate': -0.52,
#   'changeVal': -45,
#   'etfTabCode': 2,
#   'itemcode': '396500',
#   'itemname': 'TIGER Fn반도체TOP10',
#   'marketSum': 525,
#   'nav': 8675.0,
#   'nowVal': 8680,
#   'quant': 308141,
#   'risefall': '5',
#   'threeMonthEarnRate': -4.2842},
#  {'amonut': 1402,
#   'changeRate': -0.38,
#   'changeVal': -45,
#   'etfTabCode': 3,
#   'itemcode': '233160',
#   'itemname': 'TIGER 코스닥150 레버리지',
#   'marketSum': 525,
#   'nav': 11683.0,
#   'nowVal': 11660,
#   'quant': 120408,
#   'risefall': '5',
#   'threeMonthEarnRate': 4.7427},
#  {'amonut': 84,
#   'changeRate': -0.67,
#   'changeVal': -40,
#   'etfTabCode': 7,
#   'itemcode': '341850',
#   'itemname': 'TIGER 리츠부동산인프라채권TR KIS',
#   'marketSum': 514,
#   'nav': 5919.0,
#   'nowVal': 5910,
#   'quant': 14278,
#   'risefall': '5',
#   'threeMonthEarnRate': 8.05},
#  {'amonut': 88,
#   'changeRate': 1.12,
#   'changeVal': 100,
#   'etfTabCode': 4,
#   'itemcode': '371450',
#   'itemname': 'TIGER 글로벌클라우드컴퓨팅INDXX',
#   'marketSum': 511,
#   'nav': 8943.0,
#   'nowVal': 9060,
#   'quant': 9872,
#   'risefall': '2',
#   'threeMonthEarnRate': -2.5028},
#  {'amonut': 223,
#   'changeRate': -1.01,
#   'changeVal': -105,
#   'etfTabCode': 3,
#   'itemcode': '306520',
#   'itemname': 'HANARO 200선물인버스',
#   'marketSum': 510,
#   'nav': 10290.0,
#   'nowVal': 10295,
#   'quant': 21521,
#   'risefall': '5',
#   'threeMonthEarnRate': 0.0962},
#  {'amonut': 115,
#   'changeRate': 1.93,
#   'changeVal': 280,
#   'etfTabCode': 2,
#   'itemcode': '315960',
#   'itemname': 'KBSTAR 대형고배당10TR',
#   'marketSum': 502,
#   'nav': 14777.0,
#   'nowVal': 14775,
#   'quant': 7896,
#   'risefall': '2',
#   'threeMonthEarnRate': -5.0443},
#  {'amonut': 1408,
#   'changeRate': -0.03,
#   'changeVal': -25,
#   'etfTabCode': 6,
#   'itemcode': '419890',
#   'itemname': '히어로즈 단기채권ESG액티브',
#   'marketSum': 500,
#   'nav': 99976.0,
#   'nowVal': 99960,
#   'quant': 14089,
#   'risefall': '5',
#   'threeMonthEarnRate': None},
#  {'amonut': 44,
#   'changeRate': 1.05,
#   'changeVal': 95,
#   'etfTabCode': 1,
#   'itemcode': '385720',
#   'itemname': 'TIMEFOLIO Kstock액티브',
#   'marketSum': 496,
#   'nav': 9191.0,
#   'nowVal': 9180,
#   'quant': 4903,
#   'risefall': '2',
#   'threeMonthEarnRate': 1.8497},
#  {'amonut': 805,
#   'changeRate': 1.59,
#   'changeVal': 40,
#   'etfTabCode': 4,
# ...
#   'risefall': '5',
#   'threeMonthEarnRate': -0.4628},
#  {'amonut': 0,
#   'changeRate': -0.43,
#   'changeVal': -35,
#   'etfTabCode': 2,
#   'itemcode': '380340',
#   'itemname': 'KINDEX Fn5G플러스',
#   'marketSum': 57,
#   'nav': 8208.0,
#   'nowVal': 8200,
#   'quant': 103,
#   'risefall': '5',
#   'threeMonthEarnRate': -1.1351},
#  {'amonut': 31,
#   'changeRate': 1.84,
#   'changeVal': 230,
#   'etfTabCode': 5,
#   'itemcode': '334690',
#   'itemname': 'KBSTAR 팔라듐선물(H)',
#   'marketSum': 57,
#   'nav': 12952.0,
#   'nowVal': 12745,
#   'quant': 2489,
#   'risefall': '2',
#   'threeMonthEarnRate': -5.3687},
#  {'amonut': 0,
#   'changeRate': 0.92,
#   'changeVal': 80,
#   'etfTabCode': 2,
#   'itemcode': '404470',
#   'itemname': 'HANARO KRX기후변화솔루션',
#   'marketSum': 57,
#   'nav': 8824.0,
#   'nowVal': 8795,
#   'quant': 53,
#   'risefall': '2',
#   'threeMonthEarnRate': 1.3233},
#  {'amonut': 0,
#   'changeRate': 0.62,
#   'changeVal': 70,
#   'etfTabCode': 2,
#   'itemcode': '140580',
#   'itemname': 'KBSTAR 우량업종',
#   'marketSum': 57,
#   'nav': 11546.0,
#   'nowVal': 11410,
#   'quant': 3,
#   'risefall': '2',
#   'threeMonthEarnRate': 7.9305},
#  {'amonut': 0,
#   'changeRate': 1.1,
#   'changeVal': 135,
#   'etfTabCode': 2,
#   'itemcode': '215620',
#   'itemname': 'HK S&P코리아로우볼',
#   'marketSum': 56,
#   'nav': 12343.0,
#   'nowVal': 12355,
#   'quant': 11,
#   'risefall': '2',
#   'threeMonthEarnRate': 8.8518},
#  {'amonut': 2,
#   'changeRate': 1.82,
#   'changeVal': 165,
#   'etfTabCode': 3,
#   'itemcode': '292340',
#   'itemname': '마이티 200커버드콜ATM레버리지',
#   'marketSum': 56,
#   'nav': 9268.0,
#   'nowVal': 9250,
#   'quant': 285,
#   'risefall': '2',
#   'threeMonthEarnRate': 8.3482},
#  {'amonut': 2,
#   'changeRate': 0.95,
#   'changeVal': 80,
#   'etfTabCode': 2,
#   'itemcode': '376250',
#   'itemname': 'ARIRANG 탄소효율그린뉴딜',
#   'marketSum': 55,
#   'nav': 8532.0,
#   'nowVal': 8535,
#   'quant': 293,
#   'risefall': '2',
#   'threeMonthEarnRate': -1.2681},
#  {'amonut': 0,
#   'changeRate': 1.99,
#   'changeVal': 215,
#   'etfTabCode': 2,
#   'itemcode': '368470',
#   'itemname': 'KINDEX Fn K-뉴딜디지털플러스',
#   'marketSum': 55,
#   'nav': 11006.0,
#   'nowVal': 11000,
#   'quant': 20,
#   'risefall': '2',
#   'threeMonthEarnRate': -2.3519},
#  {'amonut': 1,
#   'changeRate': 1.12,
#   'changeVal': 100,
#   'etfTabCode': 1,
#   'itemcode': '228820',
#   'itemname': 'TIGER KTOP30',
#   'marketSum': 54,
#   'nav': 9098.0,
#   'nowVal': 9055,
#   'quant': 148,
#   'risefall': '2',
#   'threeMonthEarnRate': -2.9428},
#  {'amonut': 64,
#   'changeRate': 2.11,
#   'changeVal': 80,
#   'etfTabCode': 4,
#   'itemcode': '105010',
#   'itemname': 'TIGER 라틴35',
#   'marketSum': 54,
#   'nav': 3863.0,
#   'nowVal': 3870,
#   'quant': 16742,
#   'risefall': '2',
#   'threeMonthEarnRate': 11.3069},
#  {'amonut': 37,
#   'changeRate': 1.1,
#   'changeVal': 55,
#   'etfTabCode': 2,
#   'itemcode': '412560',
#   'itemname': 'TIGER KRX BBIG K-뉴딜레버리지',
#   'marketSum': 53,
#   'nav': 5062.0,
#   'nowVal': 5075,
#   'quant': 7537,
#   'risefall': '2',
#   'threeMonthEarnRate': -15.2028},
#  {'amonut': 0,
#   'changeRate': 0.0,
#   'changeVal': 0,
#   'etfTabCode': 6,
#   'itemcode': '292770',
#   'itemname': 'KODEX 국채선물3년인버스',
#   'marketSum': 52,
#   'nav': 51588.0,
#   'nowVal': 51400,
#   'quant': 0,
#   'risefall': '3',
#   'threeMonthEarnRate': 1.5208},
#  {'amonut': 0,
#   'changeRate': 0.62,
#   'changeVal': 640,
#   'etfTabCode': 6,
#   'itemcode': '299070',
#   'itemname': 'KINDEX 국채선물10년인버스',
#   'marketSum': 52,
#   'nav': 104289.0,
#   'nowVal': 104595,
#   'quant': 6,
#   'risefall': '2',
#   'threeMonthEarnRate': 4.0903},
#  {'amonut': 30,
#   'changeRate': -1.03,
#   'changeVal': -60,
#   'etfTabCode': 3,
#   'itemcode': '252410',
#   'itemname': 'KBSTAR 200선물인버스',
#   'marketSum': 52,
#   'nav': 5750.0,
#   'nowVal': 5760,
#   'quant': 5314,
#   'risefall': '5',
#   'threeMonthEarnRate': 0.0},
#  {'amonut': 0,
#   'changeRate': 0.39,
#   'changeVal': 50,
#   'etfTabCode': 2,
#   'itemcode': '277640',
#   'itemname': 'TIGER 코스피대형주',
#   'marketSum': 52,
#   'nav': 13063.0,
#   'nowVal': 12930,
#   'quant': 17,
#   'risefall': '2',
#   'threeMonthEarnRate': -0.0383},
#  {'amonut': 0,
#   'changeRate': 0.0,
#   'changeVal': 0,
#   'etfTabCode': 6,
#   'itemcode': '299080',
#   'itemname': 'KINDEX 국채선물3년인버스',
#   'marketSum': 52,
#   'nav': 103265.0,
#   'nowVal': 103055,
#   'quant': 0,
#   'risefall': '3',
#   'threeMonthEarnRate': 1.6221},
#  {'amonut': 0,
#   'changeRate': 1.22,
#   'changeVal': 155,
#   'etfTabCode': 2,
#   'itemcode': '333940',
#   'itemname': 'ARIRANG KS로우볼가중TR',
#   'marketSum': 51,
#   'nav': 12859.0,
#   'nowVal': 12855,
#   'quant': 27,
#   'risefall': '2',
#   'threeMonthEarnRate': 1.9261},
#  {'amonut': 1,
#   'changeRate': 0.2,
#   'changeVal': 20,
#   'etfTabCode': 6,
#   'itemcode': '267440',
#   'itemname': 'KBSTAR 미국장기국채선물(H)',
#   'marketSum': 51,
#   'nav': 10188.0,
#   'nowVal': 10265,
#   'quant': 170,
#   'risefall': '2',
#   'threeMonthEarnRate': -9.0546},
#  {'amonut': 699,
#   'changeRate': -1.26,
#   'changeVal': -125,
#   'etfTabCode': 3,
#   'itemcode': '306530',
#   'itemname': 'HANARO 코스닥150선물레버리지',
#   'marketSum': 51,
#   'nav': 9908.0,
#   'nowVal': 9795,
#   'quant': 70763,
#   'risefall': '5',
#   'threeMonthEarnRate': 5.1404},
#  {'amonut': 46,
#   'changeRate': 0.23,
#   'changeVal': 20,
#   'etfTabCode': 3,
#   'itemcode': '291620',
#   'itemname': 'KOSEF 코스닥150선물인버스',
#   'marketSum': 51,
#   'nav': 8543.0,
#   'nowVal': 8575,
#   'quant': 5399,
#   'risefall': '2',
#   'threeMonthEarnRate': -5.8856},
#  {'amonut': 0,
#   'changeRate': 0.66,
#   'changeVal': 55,
#   'etfTabCode': 4,
#   'itemcode': '291890',
#   'itemname': 'KODEX MSCI EM선물(H)',
#   'marketSum': 50,
#   'nav': 8444.0,
#   'nowVal': 8355,
#   'quant': 117,
#   'risefall': '2',
#   'threeMonthEarnRate': -12.2158},
#  {'amonut': 220,
#   'changeRate': 0.93,
#   'changeVal': 115,
#   'etfTabCode': 2,
#   'itemcode': '281990',
#   'itemname': 'KBSTAR 중소형고배당',
#   'marketSum': 50,
#   'nav': 12531.0,
#   'nowVal': 12465,
#   'quant': 17687,
#   'risefall': '2',
#   'threeMonthEarnRate': 11.3257},
#  {'amonut': 2,
#   'changeRate': -0.2,
#   'changeVal': -20,
#   'etfTabCode': 2,
#   'itemcode': '373490',
#   'itemname': 'KODEX K-이노베이션액티브',
#   'marketSum': 50,
#   'nav': 9960.0,
#   'nowVal': 9930,
#   'quant': 289,
#   'risefall': '5',
#   'threeMonthEarnRate': 3.3057},
#  {'amonut': 95,
#   'changeRate': -1.35,
#   'changeVal': -75,
#   'etfTabCode': 3,
#   'itemcode': '145670',
#   'itemname': 'KINDEX 인버스',
#   'marketSum': 49,
#   'nav': 5479.0,
#   'nowVal': 5470,
#   'quant': 17219,
#   'risefall': '5',
#   'threeMonthEarnRate': 0.6352},
#  {'amonut': 3,
#   'changeRate': 0.98,
#   'changeVal': 95,
#   'etfTabCode': 2,
#   'itemcode': '244660',
#   'itemname': 'KODEX 퀄리티Plus',
#   'marketSum': 49,
#   'nav': 9859.0,
#   'nowVal': 9825,
#   'quant': 402,
#   'risefall': '2',
#   'threeMonthEarnRate': 10.3982},
#  {'amonut': 0,
#   'changeRate': 0.8,
#   'changeVal': 65,
#   'etfTabCode': 1,
#   'itemcode': '391680',
#   'itemname': 'HK 하이볼액티브',
#   'marketSum': 49,
#   'nav': 8234.0,
#   'nowVal': 8185,
#   'quant': 4,
#   'risefall': '2',
#   'threeMonthEarnRate': -0.0616},
#  {'amonut': 0,
#   'changeRate': -0.41,
#   'changeVal': -40,
#   'etfTabCode': 7,
#   'itemcode': '321410',
#   'itemname': 'KODEX 멀티에셋하이인컴(H)',
#   'marketSum': 49,
#   'nav': 9807.0,
#   'nowVal': 9820,
#   'quant': 35,
#   'risefall': '5',
#   'threeMonthEarnRate': -8.0653},
#  {'amonut': 71,
#   'changeRate': 0.67,
#   'changeVal': 50,
#   'etfTabCode': 3,
#   'itemcode': '301410',
#   'itemname': 'ARIRANG 코스닥150선물인버스',
#   'marketSum': 48,
#   'nav': 7432.0,
#   'nowVal': 7460,
#   'quant': 9613,
#   'risefall': '2',
#   'threeMonthEarnRate': -6.2026},
#  {'amonut': 1,
#   'changeRate': 1.32,
#   'changeVal': 140,
#   'etfTabCode': 1,
#   'itemcode': '295820',
#   'itemname': 'ARIRANG 200동일가중',
#   'marketSum': 48,
#   'nav': 10725.0,
#   'nowVal': 10730,
#   'quant': 149,
#   'risefall': '2',
#   'threeMonthEarnRate': 11.1225},
#  {'amonut': 3,
#   'changeRate': 0.78,
#   'changeVal': 125,
#   'etfTabCode': 2,
#   'itemcode': '139290',
#   'itemname': 'TIGER 200 경기소비재',
#   'marketSum': 48,
#   'nav': 16110.0,
#   'nowVal': 16055,
#   'quant': 188,
#   'risefall': '2',
#   'threeMonthEarnRate': 2.7584},
#  {'amonut': 63,
#   'changeRate': -0.77,
#   'changeVal': -45,
#   'etfTabCode': 3,
#   'itemcode': '253240',
#   'itemname': 'KOSEF 200선물인버스',
#   'marketSum': 48,
#   'nav': 5774.0,
#   'nowVal': 5780,
#   'quant': 10950,
#   'risefall': '5',
#   'threeMonthEarnRate': -0.0858},
#  {'amonut': 0,
#   'changeRate': 0.73,
#   'changeVal': 85,
#   'etfTabCode': 2,
#   'itemcode': '301440',
#   'itemname': 'ARIRANG 코스피중형주',
#   'marketSum': 47,
#   'nav': 11707.0,
#   'nowVal': 11725,
#   'quant': 20,
#   'risefall': '2',
#   'threeMonthEarnRate': 8.0054},
#  {'amonut': 29,
#   'changeRate': 0.11,
#   'changeVal': 45,
#   'etfTabCode': 6,
#   'itemcode': '346000',
#   'itemname': 'HANARO KAP초장기국고채',
#   'marketSum': 45,
#   'nav': 39447.0,
#   'nowVal': 39555,
#   'quant': 737,
#   'risefall': '2',
#   'threeMonthEarnRate': -7.4448},
#  {'amonut': 58,
#   'changeRate': 0.67,
#   'changeVal': 60,
#   'etfTabCode': 6,
#   'itemcode': '267450',
#   'itemname': 'KBSTAR 미국장기국채선물인버스(H)',
#   'marketSum': 45,
#   'nav': 8980.0,
#   'nowVal': 9000,
#   'quant': 6509,
#   'risefall': '2',
#   'threeMonthEarnRate': 10.1663},
#  {'amonut': 15,
#   'changeRate': 0.59,
#   'changeVal': 25,
#   'etfTabCode': 2,
#   'itemcode': '157500',
#   'itemname': 'TIGER 증권',
#   'marketSum': 45,
#   'nav': 4243.0,
#   'nowVal': 4230,
#   'quant': 3738,
#   'risefall': '2',
#   'threeMonthEarnRate': -0.4485},
#  {'amonut': 98,
#   'changeRate': 3.13,
#   'changeVal': 295,
#   'etfTabCode': 2,
#   'itemcode': '227560',
#   'itemname': 'TIGER 200 생활소비재',
#   'marketSum': 45,
#   'nav': 9766.0,
#   'nowVal': 9730,
#   'quant': 10198,
#   'risefall': '2',
#   'threeMonthEarnRate': 6.6406},
#  {'amonut': 0,
#   'changeRate': 0.09,
#   'changeVal': 45,
#   'etfTabCode': 6,
#   'itemcode': '295020',
#   'itemname': 'KBSTAR 국채선물10년인버스',
#   'marketSum': 45,
#   'nav': 51877.0,
#   'nowVal': 51940,
#   'quant': 8,
#   'risefall': '2',
#   'threeMonthEarnRate': 4.1127},
#  {'amonut': 495,
#   'changeRate': 1.52,
#   'changeVal': 150,
#   'etfTabCode': 2,
#   'itemcode': '285010',
#   'itemname': 'KBSTAR 200중공업',
#   'marketSum': 44,
#   'nav': 10049.0,
#   'nowVal': 10015,
#   'quant': 49695,
#   'risefall': '2',
#   'threeMonthEarnRate': 18.9398},
#  {'amonut': 67,
#   'changeRate': 0.73,
#   'changeVal': 40,
#   'etfTabCode': 4,
#   'itemcode': '371870',
#   'itemname': 'KINDEX 차이나항셍테크',
#   'marketSum': 44,
#   'nav': 5563.0,
#   'nowVal': 5495,
#   'quant': 12175,
#   'risefall': '2',
#   'threeMonthEarnRate': -22.8976},
#  {'amonut': 72,
#   'changeRate': 3.72,
#   'changeVal': 440,
#   'etfTabCode': 2,
#   'itemcode': '287300',
#   'itemname': 'KBSTAR 200건설',
#   'marketSum': 42,
#   'nav': 12325.0,
#   'nowVal': 12265,
#   'quant': 5946,
#   'risefall': '2',
#   'threeMonthEarnRate': 14.1837},
#  {'amonut': 8,
#   'changeRate': 0.44,
#   'changeVal': 20,
#   'etfTabCode': 4,
#   'itemcode': '220130',
#   'itemname': 'SOL 중국본토 중소형 CSI500(합성 H)',
#   'marketSum': 41,
#   'nav': 4579.0,
#   'nowVal': 4585,
#   'quant': 1780,
#   'risefall': '2',
#   'threeMonthEarnRate': -21.9659},
#  {'amonut': 34,
#   'changeRate': 0.74,
#   'changeVal': 50,
#   'etfTabCode': 5,
#   'itemcode': '280940',
#   'itemname': 'KODEX 골드선물인버스(H)',
#   'marketSum': 41,
#   'nav': 6861.0,
#   'nowVal': 6800,
#   'quant': 5020,
#   'risefall': '2',
#   'threeMonthEarnRate': -5.4622},
#  {'amonut': 0,
#   'changeRate': 1.11,
#   'changeVal': 125,
#   'etfTabCode': 2,
#   'itemcode': '266550',
#   'itemname': 'ARIRANG 중형주저변동50',
#   'marketSum': 40,
#   'nav': 11365.0,
#   'nowVal': 11395,
#   'quant': 48,
#   'risefall': '2',
#   'threeMonthEarnRate': 13.0223},
#  {'amonut': 21,
#   'changeRate': 1.0,
#   'changeVal': 75,
#   'etfTabCode': 6,
#   'itemcode': '267500',
#   'itemname': 'KBSTAR 미국장기국채선물인버스2X(합성 H)',
#   'marketSum': 38,
#   'nav': 7592.0,
#   'nowVal': 7575,
#   'quant': 2869,
#   'risefall': '2',
#   'threeMonthEarnRate': 20.5787},
#  {'amonut': 0,
#   'changeRate': 1.18,
#   'changeVal': 175,
#   'etfTabCode': 2,
#   'itemcode': '252730',
#   'itemname': 'KBSTAR 모멘텀로우볼',
#   'marketSum': 38,
#   'nav': 15052.0,
#   'nowVal': 15025,
#   'quant': 5,
#   'risefall': '2',
#   'threeMonthEarnRate': 1.2024},
#  {'amonut': 2,
#   'changeRate': 1.34,
#   'changeVal': 120,
#   'etfTabCode': 2,
#   'itemcode': '280920',
#   'itemname': 'ARIRANG 주도업종',
#   'marketSum': 36,
#   'nav': 9102.0,
#   'nowVal': 9105,
#   'quant': 255,
#   'risefall': '2',
#   'threeMonthEarnRate': -3.3158},
#  {'amonut': 0,
#   'changeRate': 0.65,
#   'changeVal': 95,
#   'etfTabCode': 2,
#   'itemcode': '315480',
#   'itemname': 'KBSTAR 200커뮤니케이션서비스',
#   'marketSum': 35,
#   'nav': 14798.0,
#   'nowVal': 14775,
#   'quant': 47,
#   'risefall': '2',
#   'threeMonthEarnRate': -2.4215},
#  {'amonut': 0,
#   'changeRate': 0.5,
#   'changeVal': 70,
#   'etfTabCode': 2,
#   'itemcode': '333980',
#   'itemname': 'ARIRANG KS퀄리티가중TR',
#   'marketSum': 35,
#   'nav': 14192.0,
#   'nowVal': 14165,
#   'quant': 27,
#   'risefall': '2',
#   'threeMonthEarnRate': 0.4632},
#  {'amonut': 81,
#   'changeRate': 0.2,
#   'changeVal': 10,
#   'etfTabCode': 3,
#   'itemcode': '275750',
#   'itemname': 'KBSTAR 코스닥150선물인버스',
#   'marketSum': 35,
#   'nav': 4946.0,
#   'nowVal': 4965,
#   'quant': 16336,
#   'risefall': '2',
#   'threeMonthEarnRate': -6.2441},
#  {'amonut': 1,
#   'changeRate': 1.84,
#   'changeVal': 165,
#   'etfTabCode': 2,
#   'itemcode': '278420',
#   'itemname': 'ARIRANG ESG우수기업',
#   'marketSum': 32,
#   'nav': 9117.0,
#   'nowVal': 9120,
#   'quant': 187,
#   'risefall': '2',
#   'threeMonthEarnRate': 8.5764},
#  {'amonut': 4,
#   'changeRate': -1.51,
#   'changeVal': -65,
#   'etfTabCode': 5,
#   'itemcode': '334700',
#   'itemname': 'KBSTAR 팔라듐선물인버스(H)',
#   'marketSum': 30,
#   'nav': 4208.0,
#   'nowVal': 4240,
#   'quant': 1035,
#   'risefall': '5',
#   'threeMonthEarnRate': -5.9017},
#  {'amonut': 4,
#   'changeRate': -1.27,
#   'changeVal': -125,
#   'etfTabCode': 6,
#   'itemcode': '267490',
#   'itemname': 'KBSTAR 미국장기국채선물레버리지(합성 H)',
#   'marketSum': 29,
#   'nav': 9758.0,
#   'nowVal': 9740,
#   'quant': 442,
#   'risefall': '5',
#   'threeMonthEarnRate': -18.4374},
#  {'amonut': 81,
#   'changeRate': 1.59,
#   'changeVal': 150,
#   'etfTabCode': 2,
#   'itemcode': '285020',
#   'itemname': 'KBSTAR 200철강소재',
#   'marketSum': 29,
#   'nav': 9610.0,
#   'nowVal': 9605,
#   'quant': 8491,
#   'risefall': '2',
#   'threeMonthEarnRate': 22.9746},
#  {'amonut': 44,
#   'changeRate': 2.87,
#   'changeVal': 260,
#   'etfTabCode': 2,
#   'itemcode': '309210',
#   'itemname': 'ARIRANG KRX300헬스케어',
#   'marketSum': 28,
#   'nav': 9368.0,
#   'nowVal': 9315,
#   'quant': 4853,
#   'risefall': '2',
#   'threeMonthEarnRate': 4.2602},
#  {'amonut': 1,
#   'changeRate': -0.16,
#   'changeVal': -20,
#   'etfTabCode': 1,
#   'itemcode': '301400',
#   'itemname': 'ARIRANG 코스닥150',
#   'marketSum': 25,
#   'nav': 12381.0,
#   'nowVal': 12320,
#   'quant': 115,
#   'risefall': '5',
#   'threeMonthEarnRate': 2.4813},
#  {'amonut': 0,
#   'changeRate': 2.18,
#   'changeVal': 495,
#   'etfTabCode': 2,
#   'itemcode': '217790',
#   'itemname': 'TIGER 가격조정',
#   'marketSum': 23,
#   'nav': 23179.0,
#   'nowVal': 23180,
#   'quant': 11,
#   'risefall': '2',
#   'threeMonthEarnRate': 6.0647},
#  {'amonut': 0,
#   'changeRate': 1.39,
#   'changeVal': 190,
#   'etfTabCode': 2,
#   'itemcode': '252720',
#   'itemname': 'KBSTAR 모멘텀밸류',
#   'marketSum': 21,
#   'nav': 13865.0,
#   'nowVal': 13825,
#   'quant': 6,
#   'risefall': '2',
#   'threeMonthEarnRate': 1.1506},
#  {'amonut': 1,
#   'changeRate': -0.02,
#   'changeVal': -10,
#   'etfTabCode': 6,
#   'itemcode': '295000',
#   'itemname': 'KBSTAR 국채선물10년',
#   'marketSum': 20,
#   'nav': 51181.0,
#   'nowVal': 51165,
#   'quant': 39,
#   'risefall': '5',
#   'threeMonthEarnRate': -3.7159},
#  {'amonut': 3,
#   'changeRate': 3.57,
#   'changeVal': 255,
#   'etfTabCode': 2,
#   'itemcode': '287330',
#   'itemname': 'KBSTAR 200생활소비재',
#   'marketSum': 18,
#   'nav': 7392.0,
#   'nowVal': 7395,
#   'quant': 485,
#   'risefall': '2',
#   'threeMonthEarnRate': 6.9597},
#  {'amonut': 3,
#   'changeRate': 2.66,
#   'changeVal': 290,
#   'etfTabCode': 2,
#   'itemcode': '284990',
#   'itemname': 'KBSTAR 200에너지화학',
#   'marketSum': 16,
#   'nav': 11214.0,
#   'nowVal': 11195,
#   'quant': 316,
#   'risefall': '2',
#   'threeMonthEarnRate': 1.1791},
#  {'amonut': 3,
#   'changeRate': 1.0,
#   'changeVal': 100,
#   'etfTabCode': 2,
#   'itemcode': '287310',
#   'itemname': 'KBSTAR 200경기소비재',
#   'marketSum': 10,
#   'nav': 10079.0,
#   'nowVal': 10060,
#   'quant': 380,
#   'risefall': '2',
#   'threeMonthEarnRate': 2.7763},
#  {'amonut': 0,
#   'changeRate': 2.08,
#   'changeVal': 240,
#   'etfTabCode': 2,
#   'itemcode': '287320',
#   'itemname': 'KBSTAR 200산업재',
#   'marketSum': 7,
#   'nav': 11784.0,
#   'nowVal': 11760,
#   'quant': 37,
#   'risefall': '2',
#   'threeMonthEarnRate': 18.425}]

# %% [markdown]
# ## 데이터프레임 변환
# ### JSON 데이터를 pandas 의 데이터프레임 형태로 만들기

# %%
# 키-값 형태의 데이터를 데이터프레임으로 만듭니다.
df = pd.DataFrame(etfItemList)
df
# Out:
#     itemcode  etfTabCode               itemname  nowVal risefall  changeVal  \
# 0     069500           1              KODEX 200   34985        2        345
# 1     371460           4  TIGER 차이나전기차SOLACTIVE   11890        2         95
# 2     122630           3             KODEX 레버리지   18585        2        360
# 3     133690           4         TIGER 미국나스닥100   75220        2       1000
# 4     252670           3       KODEX 200선물인버스2X    2650        5        -50
# ..       ...         ...                    ...     ...      ...        ...
# 550   295000           6         KBSTAR 국채선물10년   51165        5        -10
# 551   287330           2        KBSTAR 200생활소비재    7395        2        255
# 552   284990           2        KBSTAR 200에너지화학   11195        2        290
# 553   287310           2        KBSTAR 200경기소비재   10060        2        100
# 554   287320           2          KBSTAR 200산업재   11760        2        240
#
#      changeRate      nav  threeMonthEarnRate      quant  amonut  marketSum
# 0          1.00  35084.0             -0.4674    4180043  145311      47195
# 1          0.81  11894.0            -25.5132    8956866  107221      29425
# 2          1.98  18679.0             -2.6183   16856345  309205      21122
# 3          1.35  74008.0             -0.9795     117485    8789      20964
# 4         -1.85   2646.0             -1.0990  141997440  380833      19202
# ..          ...      ...                 ...        ...     ...        ...
# 550       -0.02  51181.0             -3.7159         39       1         20
# 551        3.57   7392.0              6.9597        485       3         18
# 552        2.66  11214.0              1.1791        316       3         16
# 553        1.00  10079.0              2.7763        380       3         10
# 554        2.08  11784.0             18.4250         37       0          7
#
# [555 rows x 12 columns]

# %% [markdown]
# ### 데이터 확인

# %%
# 데이터 프레임으로 잘 만들어 졌는지 상단 데이터의 일부만 미리보기 합니다.
df.head()
# Out:
#   itemcode  etfTabCode               itemname  nowVal risefall  changeVal  \
# 0   069500           1              KODEX 200   34985        2        345
# 1   371460           4  TIGER 차이나전기차SOLACTIVE   11890        2         95
# 2   122630           3             KODEX 레버리지   18585        2        360
# 3   133690           4         TIGER 미국나스닥100   75220        2       1000
# 4   252670           3       KODEX 200선물인버스2X    2650        5        -50
#
#    changeRate      nav  threeMonthEarnRate      quant  amonut  marketSum
# 0        1.00  35084.0             -0.4674    4180043  145311      47195
# 1        0.81  11894.0            -25.5132    8956866  107221      29425
# 2        1.98  18679.0             -2.6183   16856345  309205      21122
# 3        1.35  74008.0             -0.9795     117485    8789      20964
# 4       -1.85   2646.0             -1.0990  141997440  380833      19202

# %%
# 데이터 프레임으로 잘 만들어 졌는지 하단 데이터의 일부만 미리보기 합니다.
df.tail()
# Out:
#     itemcode  etfTabCode         itemname  nowVal risefall  changeVal  \
# 550   295000           6   KBSTAR 국채선물10년   51165        5        -10
# 551   287330           2  KBSTAR 200생활소비재    7395        2        255
# 552   284990           2  KBSTAR 200에너지화학   11195        2        290
# 553   287310           2  KBSTAR 200경기소비재   10060        2        100
# 554   287320           2    KBSTAR 200산업재   11760        2        240
#
#      changeRate      nav  threeMonthEarnRate  quant  amonut  marketSum
# 550       -0.02  51181.0             -3.7159     39       1         20
# 551        3.57   7392.0              6.9597    485       3         18
# 552        2.66  11214.0              1.1791    316       3         16
# 553        1.00  10079.0              2.7763    380       3         10
# 554        2.08  11784.0             18.4250     37       0          7

# %% [markdown]
# ## 파일 저장
# ### 파일명 만들기

# %%
# 파이썬 표준라이브러리인 datetime을 불러옵니다.
# 날짜를 만들어 저장하기 위해 오늘 날짜를 구합니다.
import datetime
#datetime.datetime.today().strftime??
today = datetime.datetime.today()
today = today.strftime("%Y-%m-%d")

today
# Out:
# Object `strftime` not found.
# '2022-04-28'

# %%
# f-string 방식으로 파일명을 만들어 줍니다.
# eft_날짜_raw.csv 형태로 만듭니다.
file_name = f"eft_{today}_raw.csv"

# %% [markdown]
# ### 파일로 저장하고 불러오기

# %%
# csv 형태로 저장합니다. index 가 저장되지 않도록 합니다.
df.to_csv(file_name, index=False)

# %%
# 저장된 csv 파일을 읽어옵니다.
# itemcode 숫자 앞의 0 이 지워진다면 dtype={"itemcode": np.object} 로 타입을 지정해 주면 문자형태로 읽어옵니다.
pd.read_csv(file_name, dtype={"itemcode": np.object})
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   This is separate from the ipykernel package so we can avoid doing imports until
#     itemcode  etfTabCode               itemname  nowVal  risefall  changeVal  \
# 0     069500           1              KODEX 200   34985         2        345
# 1     371460           4  TIGER 차이나전기차SOLACTIVE   11890         2         95
# 2     122630           3             KODEX 레버리지   18585         2        360
# 3     133690           4         TIGER 미국나스닥100   75220         2       1000
# 4     252670           3       KODEX 200선물인버스2X    2650         5        -50
# ..       ...         ...                    ...     ...       ...        ...
# 550   295000           6         KBSTAR 국채선물10년   51165         5        -10
# 551   287330           2        KBSTAR 200생활소비재    7395         2        255
# 552   284990           2        KBSTAR 200에너지화학   11195         2        290
# 553   287310           2        KBSTAR 200경기소비재   10060         2        100
# 554   287320           2          KBSTAR 200산업재   11760         2        240
#
#      changeRate      nav  threeMonthEarnRate      quant  amonut  marketSum
# 0          1.00  35084.0             -0.4674    4180043  145311      47195
# 1          0.81  11894.0            -25.5132    8956866  107221      29425
# 2          1.98  18679.0             -2.6183   16856345  309205      21122
# 3          1.35  74008.0             -0.9795     117485    8789      20964
# 4         -1.85   2646.0             -1.0990  141997440  380833      19202
# ..          ...      ...                 ...        ...     ...        ...
# 550       -0.02  51181.0             -3.7159         39       1         20
# 551        3.57   7392.0              6.9597        485       3         18
# 552        2.66  11214.0              1.1791        316       3         16
# 553        1.00  10079.0              2.7763        380       3         10
# 554        2.08  11784.0             18.4250         37       0          7
#
# [555 rows x 12 columns]

# %%
from google.colab import drive

drive.mount('/content/gdrive')
path = "/content/gdrive/My Drive/Colab Notebooks/IBK투자증권/finance-data-analysis-main"
df.to_csv(f"{path}/{file_name}", index=False)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df.to_csv(f"{path}/file_name", index=False)
